# %% [markdown]
# <a href="https://colab.research.google.com/github/ARoDias/DataMiningProject_CTCT_2024Analysis/blob/main/Feature_selection_and_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Feature_selection and Clustering notebook
#
# This notebook answers the following research question:
# * **RQ4:** What distinct clusters are evident in student performances based on different types of assessment points?
#
# And selects features for the following research question:
# * **RQ5:** Can student performance in one theme of the CTCT course predict outcomes in subsequent themes?
#
# ## Important:
# Create a folder called **inputs** and store files there to load.

# %% [markdown]
# # 1. Importing Libraries

# %%
# Data Manipulation Libraries
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations on large multi-dimensional arrays and matrices

# Visualization Libraries
import matplotlib.pyplot as plt  # Plotting library for creating static, animated, and interactive visualizations

# Machine Learning - Preprocessing and Model Evaluation
from sklearn.feature_selection import VarianceThreshold, mutual_info_classif  # Feature selection
from sklearn.ensemble import RandomForestClassifier  # Classification using Random Forests
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, KBinsDiscretizer, StandardScaler  # Preprocessing tools
from sklearn.impute import SimpleImputer  # Missing value imputation
from sklearn.tree import DecisionTreeClassifier  # Classification using Decision Trees
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score  # Clustering evaluation metrics
from sklearn.cluster import KMeans, AgglomerativeClustering  # Clustering algorithms
from sklearn.decomposition import PCA  # Principal Component Analysis for dimensionality reduction

# Additional Imports for Regression Feature Selection
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_classif, mutual_info_regression  # Feature selection for regression using F-test
from sklearn.ensemble import RandomForestRegressor  # Regression using Random Forests
from sklearn.linear_model import Lasso  # Lasso regression for feature selection
from sklearn.tree import DecisionTreeRegressor  # Regression using Decision Trees

# Hierarchical Clustering Performance Enhancement
import scipy.cluster.hierarchy as sch  # Additional hierarchical clustering methods

# Integration with Google Colaboratory
from google.colab import files  # File upload and download functionality for Google Colab
from pathlib import Path  # Object-oriented filesystem paths

# Document Generation
# !pip install python-docx  # Install python-docx for creating and updating Microsoft Word (.docx) files
from docx import Document  # Library for creating and updating Microsoft Word (.docx) files

# Date and Time Utilities
from datetime import datetime  # Utilities for date and time manipulation

# Data Serialization
import pickle  # Serialization and deserialization of Python objects
import os  # Operating system dependent functionality
from io import StringIO  # In-memory file-like object for text I/O
import shutil  # High-level file operations like copying and removal

# Display Utilities for Jupyter Notebooks
from IPython.display import display as ipy_display  # Display utilities for Jupyter notebooks

print("Libraries imported successfully.")

if not os.path.exists('inputs'):
    os.makedirs('inputs')
# Out:
# Requirement already satisfied: python-docx in /usr/local/lib/python3.10/dist-packages (1.1.2)
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.9.4)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.12.2)
# Libraries imported successfully.

# %% [markdown]
# # 2. Auxiliary Methods

# %% [markdown]
# ## 2.1 For loading files, data verification and preparation:

# %% [markdown]
# ###### load_compose_feather_files

# %%
# Function to load Feather files with only numbers in the filename from a specified directory, excluding keys from datasets
def load_compose_feather_files(datasets, path='inputs'):
    # Get a list of Feather files in the directory with only numbers in the filename
    files = [f for f in os.listdir(path) if f.endswith('.feather') and f[:-8].isdigit() and not f.startswith('dataset_')]
    compose_datasets = {}

    # Load the compose datasets
    for file in files:
        # Extract the index from the file name
        index = int(file.replace('.feather', ''))
        # Check if the index is already in datasets to avoid duplication
        if index not in datasets:
            # Read the Feather file into a DataFrame
            compose_datasets[index] = pd.read_feather(os.path.join(path, file))

    return compose_datasets

# %% [markdown]
# ######  ensure_unique_columns

# %%
def ensure_unique_columns(df):
    # Append the column name with an increasing count if duplicate column names are found
    cols = pd.Series(df.columns)
    for dup in cols[cols.duplicated()].unique():
        cols[cols[cols == dup].index.values.tolist()] = [dup + '_' + str(i) if i != 0 else dup for i in range(sum(cols == dup))]
    df.columns = cols
    return df

# %% [markdown]
# ######  combine_datasets

# %%
def combine_datasets(datasets):
    combined_df = pd.DataFrame()

    for year, df in datasets.items():
        # Ensure the DataFrame index is unique
        df = df.reset_index(drop=True)
        # Ensure the DataFrame columns are unique
        df = ensure_unique_columns(df)
        # Add a 'Year' column to identify the year
        df['Year'] = year
        # Concatenate the DataFrame to the combined DataFrame
        combined_df = pd.concat([combined_df, df], ignore_index=True)

    return combined_df

# %% [markdown]
# ###### Update Dataset and Dictionary of Lists with IDs of activities
# update_column_names(dataset, activity_dict, sync_columns) & update_all_lists(all_lists, year, column_mapping)

# %%
# Function to update column names based on a mapping
def update_column_names(dataset, activity_dict, sync_columns):
    """
    Updates the column names of the dataset based on a mapping from the activity dictionary.

    Args:
    - dataset (pd.DataFrame): The dataset whose columns need to be updated.
    - activity_dict (dict): Dictionary containing mappings of old column names to new names and additional info.
    - sync_columns (list): List of columns that need to be checked and potentially updated.

    Returns:
    - dataset (pd.DataFrame): The dataset with updated column names.
    - column_mapping (dict): A dictionary mapping original column names to their updated names.

    Functionality:
    - For each column in `sync_columns`, it checks if there is a corresponding entry in `activity_dict`.
    - Depending on the type of activity, the column name is updated to its mapped value or retained as is.
    - The updated column names are applied to the dataset.
    """
    column_mapping = {}
    for col in sync_columns:
        if col in activity_dict:
            activity_info = activity_dict[col]
            activity_type = activity_info[2]
            if activity_type in ['A', 'B', 'C', 'SPA']:
                column_mapping[col] = str(activity_info[0])
            else:
                column_mapping[col] = col  # Keep the original column if not evaluated
        else:
            column_mapping[col] = col  # Keep the original column if not in the dictionary

    # Apply the mapping to the columns
    new_columns = [column_mapping.get(col, col) for col in dataset.columns]
    dataset.columns = new_columns
    return dataset, column_mapping

# Function to update all relevant lists with the new column names
def update_all_lists(all_lists, year, column_mapping):
    """
    Updates all relevant lists in the `all_lists` dictionary to reflect the updated column names.

    Args:
    - all_lists (dict): The dictionary containing various lists of columns for each dataset year.
    - year (int or str): The year corresponding to the dataset being updated.
    - column_mapping (dict): A dictionary mapping original column names to their updated names.

    Returns:
    - updated_lists (dict): The updated dictionary with all lists reflecting the new column names.

    Functionality:
    - The function iterates through various lists in `all_lists` and updates each list's column names based on `column_mapping`.
    - It handles different categories of lists, including basic lists, weekly and participation lists, activity type lists, and created columns.
    """
    updated_lists = all_lists[str(year)].copy()

    # Update basic lists
    for list_name in updated_lists['basic_lists']:
        updated_lists['basic_lists'][list_name] = [column_mapping.get(col, col) for col in updated_lists['basic_lists'][list_name]]

    # Update weekly and participation lists
    for list_name in updated_lists['weekly_and_participation_lists']:
        if isinstance(updated_lists['weekly_and_participation_lists'][list_name], dict):
            updated_lists['weekly_and_participation_lists'][list_name] = {
                k: [column_mapping.get(col, col) for col in v]
                for k, v in updated_lists['weekly_and_participation_lists'][list_name].items()
            }
        else:
            updated_lists['weekly_and_participation_lists'][list_name] = [
                column_mapping.get(col, col) for col in updated_lists['weekly_and_participation_lists'][list_name]
            ]

    # Update activity type lists
    for list_name in updated_lists['activity_type_lists']:
        updated_lists['activity_type_lists'][list_name] = [
            column_mapping.get(col, col) for col in updated_lists['activity_type_lists'][list_name]
        ]

    # Update created columns lists
    for list_name in updated_lists['created_columns']:
        updated_lists['created_columns'][list_name] = [
            column_mapping.get(col, col) for col in updated_lists['created_columns'][list_name]
        ]

    return updated_lists

# %% [markdown]
# ## 2.2 For notebook output manipulation:

# %% [markdown]
# ###### print_to_doc

# %%
# Custom print function to capture output to a Word document
def print_to_doc(*args, **kwargs):
    """
    This function captures the output and appends it to a Word document.

    Args:
    - *args: Variable length argument list. The arguments will be concatenated into a single string.
    - **kwargs: Arbitrary keyword arguments. This function does not use kwargs directly, but allows them for flexibility.

    Functionality:
    - The function joins all positional arguments into a single string separated by spaces.
    - The resulting text is added as a new paragraph to the global Word document object `doc`.
    """
    text = ' '.join(map(str, args))
    doc.add_paragraph(text)

# %% [markdown]
# ###### custom_display

# %%
# Custom display function to capture output to a Word document
def custom_display(*args, **kwargs):
    """
    This function captures display output and either saves it to a Word document or displays it using IPython's display function.

    Args:
    - *args: Variable length argument list. These are the objects to be displayed or saved.
    - **kwargs: Arbitrary keyword arguments. These are passed through to the display function if needed.

    Functionality:
    - If `output_to_docx` is set to 1, the function saves the display output to the Word document:
        - If the argument is a DataFrame, it converts it to a string and captures the output.
        - Otherwise, it converts the argument to a string directly.
        - The resulting text is added as a new paragraph to the global Word document object `doc`.
    - If `output_to_docx` is not set to 1, it uses the IPython display function (`ipy_display`) to show the output as usual.
    """
    if output_to_docx == 1:
        for arg in args:
            if isinstance(arg, pd.DataFrame):
                # Convert DataFrame to a string representation for saving
                buf = StringIO()
                arg.to_string(buf)
                text = buf.getvalue()
            else:
                # Convert other types of arguments to string
                text = str(arg)
            doc.add_paragraph(text)
    else:
        # Display using IPython's display function
        ipy_display(*args, **kwargs)

# %% [markdown]
# ###### save_document

# %%
# Function to save the document with the current date
def save_document(filename='feature_selection.docx'):
    """
    Saves the current Word document with a specified filename and appends the current date and time.

    Args:
    - filename (str): The name of the file to save the document as. Defaults to 'feature_selection.docx'.

    Functionality:
    - Appends a paragraph with the current date and time to the document.
    - Saves the document to the specified filename.
    - Prints a confirmation message to the console with the filename.
    """
    current_date = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    doc.add_paragraph(f"Document saved on {current_date}")
    doc.save(filename)
    print(f"Document saved as {filename}")

# %% [markdown]
# ###### combine_selected_features

# %%
def combine_selected_features(selected_features):
    """
    Combine selected features across all years into a single set for each method.

    Args:
    - selected_features (dict): Dictionary of selected features for each year and method.

    Returns:
    - combined_features (dict): Combined features for each method across all years.
    """
    combined_features = {}
    for year_features in selected_features.values():
        for method, features in year_features.items():
            if method not in combined_features:
                combined_features[method] = set(features)
            else:
                combined_features[method].update(features)

    # Convert sets to lists
    combined_features = {method: list(features) for method, features in combined_features.items()}
    return combined_features

# %% [markdown]
# ###### save_combined_features_to_feather

# %%
def save_combined_features_to_feather(selected_features, combined_df, target_column, output_dir, filename_suffix, exclusion_type):
    """
    Save the combined selected features to a Feather file with the target column as the last column,
    and print information about the DataFrame being saved.

    Args:
    - selected_features (dict): Dictionary of combined selected features for each method.
    - combined_df (pd.DataFrame): The combined dataset containing all features.
    - target_column (str): The target column to be included as the last column.
    - output_dir (str or Path): Directory where the Feather files should be saved.
    - filename_suffix (str): Suffix to append to the filenames.
    - exclusion_type (str): The type of exclusion used for this selection.

    Returns:
    - None
    """
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    for method, features in selected_features.items():
        if features:
            # Ensure the target column is not in the features list
            features = [feature for feature in features if feature != target_column]

            # Append the target column at the end
            features_with_target = features + [target_column]

            # Check if all selected features are in the combined_df
            missing_features = [f for f in features_with_target if f not in combined_df.columns]
            if missing_features:
                print(f"Warning: The following features are missing in combined_df for method {method}: {missing_features}")
                features_with_target = [f for f in features_with_target if f in combined_df.columns]

            # Subset the DataFrame with the selected features
            df_selected = combined_df[features_with_target]

            # Ensure the target column is the last column
            if df_selected.columns[-1] != target_column:
                print(f"Adjusting column order to ensure {target_column} is the last column.")
                df_selected = df_selected[features + [target_column]]

            # Print information about the DataFrame being saved
            print(f"Saving DataFrame for method '{method}' with exclusion type '{exclusion_type}':")
            print(f"- Number of features: {len(features)}")
            print(f"- Shape of DataFrame: {df_selected.shape}")
            print(f"- First few columns: {df_selected.columns[:5].tolist()}...")

            # Construct the output path using Path object
            output_path = output_dir / f"{filename_suffix}_{method}_{exclusion_type}.feather"

            # Save to Feather file
            df_selected.reset_index(drop=True).to_feather(output_path)

            # Verify that the file was saved correctly
            loaded_df = pd.read_feather(output_path)
            if loaded_df.columns[-1] == target_column:
                print(f"Success: Saved {output_path} with {target_column} as the last column.")
            else:
                print(f"Error: {target_column} is not the last column in {output_path}. Last column is {loaded_df.columns[-1]}")
        else:
            print(f"No features selected for method {method}, skipping Feather file creation.")

# %% [markdown]
# ###### save_selected_features_to_feather

# %%
def save_selected_features_to_feather(selected_features, combined_df, target_column, output_dir, filename_suffix, exclusion_type):
    """
    Save the selected features to Feather files with the target column as the last column.

    Args:
    - selected_features (dict): Dictionary of selected features for each method.
    - combined_df (pd.DataFrame): The combined dataset containing all features.
    - target_column (str): The target column to be included as the last column.
    - output_dir (str or Path): Directory where the Feather files should be saved.
    - filename_suffix (str): Suffix to append to the filenames.
    - exclusion_type (str): The type of exclusion used for this selection.

    Returns:
    - None
    """
    output_dir = Path(output_dir)
    output_dir.mkdir(parents=True, exist_ok=True)

    for method, features in selected_features.items():
        if features:
            # Ensure the target column is not in the features list
            features = [feature for feature in features if feature != target_column]

            # Append the target column at the end
            features_with_target = features + [target_column]

            # Check if all selected features are in the combined_df
            missing_features = [f for f in features_with_target if f not in combined_df.columns]
            if missing_features:
                print(f"Warning: The following features are missing in combined_df for method {method}: {missing_features}")
                features_with_target = [f for f in features_with_target if f in combined_df.columns]

            # Subset the DataFrame with the selected features
            df_selected = combined_df[features_with_target]

            # Ensure the target column is the last column
            if df_selected.columns[-1] != target_column:
                print(f"Adjusting column order to ensure {target_column} is the last column.")
                df_selected = df_selected[features + [target_column]]

            # Construct the output path using Path object
            output_path = output_dir / f"{filename_suffix}_{method}_{exclusion_type}.feather"

            # Save to Feather file
            df_selected.reset_index(drop=True).to_feather(output_path)

            # Verify that the file was saved correctly
            loaded_df = pd.read_feather(output_path)
            if loaded_df.columns[-1] == target_column:
                print(f"Success: Saved {output_path} with {target_column} as the last column.")
            else:
                print(f"Error: {target_column} is not the last column in {output_path}. Last column is {loaded_df.columns[-1]}")
        else:
            print(f"No features selected for method {method}, skipping Feather file creation.")

# %% [markdown]
# ###### create_and_save_datasets

# %%
def create_and_save_datasets(combined_df, exclude_columns, target_column, output_dir, filename_suffix="combined_df"):
    """
    Create a dataset with selected features (excluding specified columns) and save it to a Feather file.

    Args:
    - combined_df (pd.DataFrame): The combined dataset containing all features.
    - exclude_columns (dict): Dictionary where keys are years and values are sets of columns to exclude.
    - target_column (str): The target column to be included as the last column.
    - output_dir (str or Path): Directory where the Feather files should be saved.
    - filename_suffix (str): Suffix to append to the filenames.

    Returns:
    - None
    """
    # Ensure output_dir is a Path object
    output_dir = Path(output_dir)

    # Ensure the output directory exists
    output_dir.mkdir(parents=True, exist_ok=True)

    # Flatten all columns to exclude across all years
    all_columns_to_exclude = set()
    for columns in exclude_columns.values():
        all_columns_to_exclude.update(columns)

    # Select all columns except those to be excluded
    selected_features = [col for col in combined_df.columns if col not in all_columns_to_exclude]

    # Ensure target column is the last column
    if target_column in selected_features:
        selected_features.remove(target_column)
    selected_features.append(target_column)

    # Subset the DataFrame with the selected features
    df_selected = combined_df[selected_features]

    # Construct the output path using Path object and include target_column in the filename
    output_path = output_dir / f"{filename_suffix}_{target_column}.feather"

    # Save to Feather file
    df_selected.reset_index(drop=True).to_feather(output_path)
    print(f"Saved selected features to {output_path}.")

# %% [markdown]
# ###### print_activity_details_for_year

# %%
def print_activity_details_for_year(dataset_params, year, activity_keys):
    """
    Print details of specified activities for a given year.

    Args:
    - dataset_params (dict): A dictionary containing parameters for datasets, where each key represents a year.
    - year (int or str): The year for which activity details are to be printed.
    - activity_keys (list): A list of keys identifying specific activities within the activity dictionary.

    Functionality:
    - The function checks if the specified year exists in the dataset parameters.
    - If the year exists, it retrieves the activity dictionary for that year and iterates over the provided activity keys.
    - For each key, it checks if the key is present in the activity dictionary:
        - If found, it prints the activity details associated with the key.
        - If not found, it prints a message indicating that the activity was not found.
    - If the year is not found in `dataset_params`, it prints a message stating that no data is available for that year.
    """
    if year in dataset_params:
        activity_dict = dataset_params[year].get('activity_dictionary', {})
        print(f"Activities for {year}:")
        for key in activity_keys:
            if key in activity_dict:
                activity_data = activity_dict[key]
                print(f"  Activity {key}: {activity_data}")
            else:
                print(f"  Activity {key}: Not found")
    else:
        print(f"No data available for the year {year}")

# %% [markdown]
# ######  get_activity_index

# %%
def get_activity_index(dataset_params, year, activity_key):
    """
    Retrieve the index of a specific activity for a given year.

    Args:
    - dataset_params (dict): A dictionary containing parameters for datasets, where each key represents a year.
    - year (int or str): The year for which the activity index is to be retrieved.
    - activity_key (str): The key identifying the specific activity within the activity dictionary.

    Returns:
    - The index of the activity if found, or None if the activity or year is not present in the dataset.

    Functionality:
    - The function attempts to retrieve the activity index from the activity dictionary for the specified year.
    - It uses a try-except block to catch any `KeyError` that occurs if the year or activity key is not found.
    - If the key exists, it returns the index (typically the first element of the activity data).
    - If not found, it returns None.
    """
    try:
        return dataset_params[year]['activity_dictionary'][activity_key][0]
    except KeyError:
        return None

# %% [markdown]
# ###### get_activity_name

# %%
def get_activity_name(dataset_params, year, activity_key):
    """
    Retrieve the name of a specific activity for a given year.

    Args:
    - dataset_params (dict): A dictionary containing parameters for datasets, where each key represents a year.
    - year (int or str): The year for which the activity name is to be retrieved.
    - activity_key (str): The key identifying the specific activity within the activity dictionary.

    Returns:
    - The name of the activity if found, or None if the activity or year is not present in the dataset.

    Functionality:
    - The function attempts to retrieve the activity name from the activity dictionary for the specified year.
    - It uses a try-except block to catch any `KeyError` that occurs if the year or activity key is not found.
    - If the key exists, it returns the name (typically the second element of the activity data).
    - If not found, it returns None.
    """
    try:
        return dataset_params[year]['activity_dictionary'][activity_key][1]
    except KeyError:
        return None

# %% [markdown]
# ###### get_activity_name_by_id

# %%
def get_activity_name_by_id(activity_id, dataset_params, year):
    """
    Retrieve the name of an activity by its ID for a given year.

    Args:
    - activity_id (int or str): The ID of the activity to find.
    - dataset_params (dict): A dictionary containing parameters for datasets, where each key represents a year.
    - year (int or str): The year for which the activity name is to be retrieved.

    Returns:
    - The name of the activity corresponding to the given ID, or None if not found.

    Functionality:
    - The function iterates over the items in the activity dictionary for the specified year.
    - It checks if the ID of each activity matches the provided `activity_id`.
    - If a match is found, it returns the name of the activity (the second element in the dictionary entry).
    - If no match is found, it returns None.
    """
    for value in dataset_params[str(year)]['activity_dictionary'].values():
        if value[0] == activity_id:
            return value[1]
    return None

# %% [markdown]
# ###### print_activity_details_for_year_by_id

# %%
def print_activity_details_for_year_by_id(dataset_params, year, activity_ids):
    """
    Print details of activities for a given year based on their IDs.

    Args:
    - dataset_params (dict): A dictionary containing parameters for datasets, where each key represents a year.
    - year (int or str): The year for which activity details are to be printed.
    - activity_ids (list): A list of IDs identifying specific activities within the activity dictionary.

    Functionality:
    - The function checks if the specified year exists in the dataset parameters.
    - If the year exists, it retrieves the activity dictionary for that year and iterates over the provided activity IDs.
    - For each ID, it uses `get_activity_name_by_id` to find the corresponding activity name:
        - If found, it prints the activity ID and name.
        - If not found, it prints a message indicating that the activity ID was not found.
    - If the year is not found in `dataset_params`, it prints a message stating that no data is available for that year.
    """
    if str(year) in dataset_params:
        activity_dict = dataset_params[str(year)].get('activity_dictionary', {})
        print(f"Activities for {year}:")
        for activity_id in activity_ids:
            activity_name = get_activity_name_by_id(int(activity_id), activity_dict, int(year))
            if activity_name:
                print(f"  Activity ID {activity_id}: {activity_name}")
            else:
                print(f"  Activity ID {activity_id}: Not found")
    else:
        print(f"No data available for the year {year}")

# %% [markdown]
# ###### check_missing_values

# %%
def check_missing_values(datasets):
    """
    Check and print the missing values for each dataset in a collection of datasets.

    Args:
    - datasets (dict): A dictionary where keys are years (or other identifiers) and values are DataFrames representing datasets.

    Functionality:
    - The function iterates over each dataset in the `datasets` dictionary.
    - For each dataset, it calculates the sum of missing values for each column.
    - If there are columns with missing values, it prints the count of missing values per column.
    """
    for key, dataset in datasets.items():
        print(f"Missing values for {key} dataset:")
        missing_values = dataset.isnull().sum()
        # Filter and print only columns with missing values
        print(missing_values[missing_values > 0])

# %% [markdown]
# ### Convert activity IDs to names (from lists)

# %% [markdown]
# ###### convert_feature_ids_to_activity_names

# %%
def convert_feature_ids_to_activity_names(selected_features, dataset_params):
    """
    Convert feature IDs to activity names using the provided dataset parameters.

    Args:
    - selected_features (dict or pd.Index): A dictionary of selected features for each year and method, or an Index object.
    - dataset_params (dict): A dictionary containing dataset parameters, including activity dictionaries for each year.

    Returns:
    - converted_features (dict or list): A dictionary with feature IDs converted to activity names, or a list if input is an Index.

    Functionality:
    - The function checks if `selected_features` is a dictionary or an Index.
    - If it's a dictionary, it iterates over each year and method, converting feature IDs to activity names using the dataset parameters.
    - If it's an Index, it assumes the selected features are for a single year and converts them similarly.
    """
    def get_activity_name_by_id(activity_id, dataset_params, year):
        """
        Helper function to get the activity name given its ID, year, and dataset parameters.
        """
        for value in dataset_params[str(year)]['activity_dictionary'].values():
            if str(value[0]) == str(activity_id):
                return value[1]
        return None

    if isinstance(selected_features, dict):
        converted_features = {}
        for year, methods in selected_features.items():
            if str(year) not in dataset_params:
                print(f"Year {year} not found in dataset_params.")
                continue

            converted_features[year] = {}

            for method, features in methods.items():
                converted_names = []
                for feature in features:
                    if feature.isdigit():
                        activity_name = get_activity_name_by_id(int(feature), dataset_params, int(year))
                        if activity_name:
                            converted_names.append(activity_name)
                        else:
                            converted_names.append(f"ID_{feature}_Not_Found")
                    else:
                        converted_names.append(feature)
                converted_features[year][method] = converted_names

        return converted_features

    elif isinstance(selected_features, pd.Index):
        converted_names = []
        year = list(dataset_params.keys())[0]  # Assumes first year if multiple years exist
        for feature in selected_features:
            if feature.isdigit():
                activity_name = get_activity_name_by_id(int(feature), dataset_params, int(year))
                if activity_name:
                    converted_names.append(activity_name)
                else:
                    converted_names.append(f"ID_{feature}_Not_Found")
            else:
                converted_names.append(feature)
        return converted_names

# %% [markdown]
# ###### convert_feature_ids_to_activity_names_complete

# %%
def convert_feature_ids_to_activity_names_complete(selected_features, dataset_params):
    """
    Convert feature IDs to activity names using the dataset parameters for multiple years and methods.

    Args:
    - selected_features (dict): A dictionary of selected features for each method.
    - dataset_params (dict): A dictionary containing parameters and activity dictionaries for each year.

    Returns:
    - converted_features (dict): A dictionary with converted feature names.

    Functionality:
    - The function extracts activity dictionaries for each year from `dataset_params`.
    - It iterates over each method and its features in `selected_features`.
    - For each feature, it searches through the activity dictionaries for a matching ID.
    - If found, it appends the activity name to `converted_features`. If not found, it appends 'Unknown'.
    """
    # Extract activity dictionaries from dataset_params
    activity_dictionaries = {
        str(year): params['activity_dictionary'] for year, params in dataset_params.items()
    }

    converted_features = {}

    # Iterate through each dataset (identified by key, such as year)
    for key, methods in selected_features.items():
        converted_features[key] = {}

        for method, features in methods.items():
            converted_names = []
            for feature in features:
                # Identify the year from the method string, e.g., 'RF_2022' -> '2022'
                year = method.split('_')[-1]
                activity_dict = activity_dictionaries.get(year, {})

                # Attempt to find the activity name by ID in the relevant activity dictionary
                activity_name = None
                for activity_info in activity_dict.values():
                    if str(activity_info[0]) == feature:
                        activity_name = activity_info[1]
                        break

                # Append the activity name or 'Unknown' if not found
                if activity_name:
                    converted_names.append(activity_name)
                else:
                    converted_names.append(f'Unknown (ID: {feature})')

            converted_features[key][method] = converted_names

    return converted_features

# %% [markdown]
# ## 2.3 For filtering specific instances:

# %% [markdown]
# ###### filter_missing_and_zero_final_grade

# %%
def filter_missing_and_zero_final_grade(datasets):
    """
    Filter out rows with missing or zero values in the 'FinalGrade' column from each dataset.

    Args:
    - datasets (dict): A dictionary where keys are years (or other identifiers) and values are DataFrames representing datasets.

    Returns:
    - filtered_datasets (dict): A dictionary with the same structure as the input, but with datasets filtered.

    Functionality:
    - The function iterates over each dataset in `datasets`.
    - For each dataset, it drops rows where the 'FinalGrade' column is missing (NaN).
    - Then, it further filters out rows where 'FinalGrade' is zero.
    - It prints the number of rows before and after filtering, and the number of rows dropped.
    """
    filtered_datasets = {}
    for year, dataset in datasets.items():
        # Drop rows with NaN in 'FinalGrade' and where 'FinalGrade' is 0
        filtered_dataset = dataset.dropna(subset=['FinalGrade'])
        filtered_dataset = filtered_dataset[filtered_dataset['FinalGrade'] != 0]
        filtered_datasets[year] = filtered_dataset
        # Print the results of the filtering process
        print(f"After filtering, {year} dataset has {len(filtered_dataset)} rows. Before had {len(dataset)}. Dropped {len(dataset) - len(filtered_dataset)} instances/students.")
    return filtered_datasets

# %% [markdown]
# ###### filter_dataset_by_activities

# %%
def filter_dataset_by_activities(dataset, known_activities, target_column='FinalGradeInteger', additional_columns=None):
    """
    Filter the dataset to retain only specified target column, additional columns, and columns related to known activities.

    Args:
    - dataset (pd.DataFrame): The dataset to be filtered.
    - known_activities (list): List of tuples where each tuple contains an activity ID and its description.
    - target_column (str): The target column to retain in the dataset. Default is 'FinalGradeInteger'.
    - additional_columns (list): Additional columns to retain in the dataset. Default is None.

    Returns:
    - filtered_dataset (pd.DataFrame): The dataset filtered to include only the specified columns.

    Functionality:
    - The function extracts activity IDs from `known_activities`.
    - It constructs a list of columns to retain, including the target column, additional columns, and any columns in the dataset matching the activity IDs.
    - The dataset is then filtered to include only these columns and returned.
    """
    if additional_columns is None:
        additional_columns = []

    # Extract activity IDs from the known_activities list
    activity_ids = [activity_id for activity_id, _ in known_activities]

    # Create a list of columns to retain
    columns_to_retain = [target_column] + additional_columns + [col for col in dataset.columns if col in activity_ids]

    # Filter the dataset
    filtered_dataset = dataset[columns_to_retain]

    return filtered_dataset

# %% [markdown]
# ###### filter_known_activities

# %%
def filter_known_activities(activity_dict):
    """
    Filter out activities with 'Unknown' as their description from a given activity dictionary.

    Args:
    - activity_dict (dict): A dictionary where keys are method names (e.g., 'MI', 'RF', 'DT') and values are lists of tuples.
                            Each tuple contains an activity ID and its description.

    Returns:
    - known_activities (list): A list of tuples with activity IDs and descriptions, excluding those with 'Unknown'.

    Functionality:
    - The function iterates over each method and its activities in `activity_dict`.
    - It appends activities that do not have 'Unknown' as their description to the `known_activities` list.
    - The result is a list of activities that have valid descriptions.
    """
    known_activities = []
    for activities in activity_dict.values():
        for activity_id, activity_desc in activities:
            if activity_desc != 'Unknown':
                known_activities.append((activity_id, activity_desc))
    return known_activities

# %% [markdown]
# # 3. Load Files

# %% [markdown]
# ## 3.1. Change Printing Mode

# %%
# Change Printing Mode
output_to_docx = 0 # Control output (0 for notebook, 1 for docx)

# %%
# Load Files

# Initialize a Word document to capture output
doc = Document()

if output_to_docx == 1:
    print = print_to_doc
    display = custom_display

# Ensure Charts directory exists
if not os.path.exists('Charts'):
    os.makedirs('Charts')

output_dir = 'output'
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
os.makedirs('output/feather_files', exist_ok=True)

# Load datasets and other files
dataset_years = [2016, 2017, 2018, 2019, 2022, 2023, 2024]
datasets = {}

for year in dataset_years:
    file_path = f'inputs/dataset_{year}.feather'
    datasets[year] = pd.read_feather(file_path)

# Load the additional compose datasets
compose_datasets = load_compose_feather_files(datasets)

activities = pd.read_feather('inputs/activities.feather')
activities2 = pd.read_feather('inputs/activities2.feather')
summary = pd.read_feather('inputs/summary.feather')

# Load additional lists and parameters
with open('inputs/all_lists.pkl', 'rb') as file:
    all_lists = pickle.load(file)
with open('inputs/all_lists_id.pkl', 'rb') as file:
    all_lists_id = pickle.load(file)
with open('inputs/dataset_params.pkl', 'rb') as file:
    dataset_params = pickle.load(file)

file_path = f'inputs/dataset_no_missing.feather'
dataset_complete = pd.read_feather(file_path)

print("Datasets and other files loaded successfully.")
# Out:
# Datasets and other files loaded successfully.

# %%
doc.add_heading('Information about the loaded datasets', 1)

# %%
doc.add_heading('dataset_complete', 2)
print("dataset_complete = the loaded combined dataset with all years removing columns with with all missing values atored in inputs/dataset_no_missing.feather file resulting from data_preparation")
dataset_complete.info()
# Out:
# dataset_complete = the loaded combined dataset with all years removing columns with with all missing values atored in inputs/dataset_no_missing.feather file resulting from data_preparation
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7890 entries, 0 to 7889
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Course             7890 non-null   object
#  1   Class              7890 non-null   object
#  2   Sex                7890 non-null   category
#  3   1                  7890 non-null   int64
#  4   12                 7890 non-null   int64
#  5   20                 7890 non-null   int64
#  6   10                 7890 non-null   int64
#  7   11                 7890 non-null   int64
#  8   32                 7890 non-null   int64
#  9   38                 7890 non-null   int64
#  10  42                 7890 non-null   int64
#  11  35                 7890 non-null   int64
#  12  50                 7890 non-null   int64
#  13  30                 7890 non-null   int64
#  14  31                 7890 non-null   int64
#  15  36                 7890 non-null   int64
#  16  34                 7890 non-null   int64
#  17  72                 7890 non-null   int64
#  18  SPA1               7890 non-null   int64
#  19  SPA2               7890 non-null   int64
#  20  SPA3               7890 non-null   int64
#  21  Bon                7890 non-null   int64
#  22  PP1_1              7890 non-null   int64
#  23  PP1_2              7890 non-null   int64
#  24  PP1_3              7890 non-null   int64
#  25  PP2_1              7890 non-null   int64
#  26  PP2_2              7890 non-null   int64
#  27  PP2_3              7890 non-null   int64
#  28  PP3_1              7890 non-null   int64
#  29  PP3_2              7890 non-null   int64
#  30  PP3_3              7890 non-null   int64
#  31  PTP1               7890 non-null   int64
#  32  PTP2               7890 non-null   int64
#  33  PTP3               7890 non-null   int64
#  34  FinalGradeInteger  7890 non-null   int64
#  35  Total_AP           7890 non-null   float64
#  36  Total_PP           7890 non-null   float64
#  37  Total_SPA          7890 non-null   float64
#  38  Total_Bon          7890 non-null   float64
#  39  Year               7890 non-null   object
# dtypes: category(1), float64(4), int64(32), object(3)
# memory usage: 2.4+ MB

# %%
doc.add_heading('compose_datasets', 2)
for key, dataset in compose_datasets.items():
    print(f"Key: {key}")
    print(dataset.columns)
# Out:
# Key: 242
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', 'FinalGrade'],
#       dtype='object')
# Key: 6769
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', '2', '5', '8', '9', '78',
#        '123', 'PP3_5'],
#       dtype='object')
# Key: 6835
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', '1_8'],
#       dtype='object')
# Key: 3453
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', 'PP4_3'],
#       dtype='object')
# Key: 5660
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', '7', '39', '41', '59',
#        '60', '61', '74', '82', '62', '65', '76', '68', 'SPA4', 'PP4_4',
#        'PP4_5'],
#       dtype='object')
# Key: 3500
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', '18'],
#       dtype='object')
# Key: 6711
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', '133', '134', '135',
#        '137', '138', '144', '139', '140', '2_11', '142'],
#       dtype='object')
# Key: 1179
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', '28', '77', 'PP4_1',
#        'PP4_2', 'PTP4'],
#       dtype='object')
# Key: 6721
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', '1_5', '105', 'BonCoord'],
#       dtype='object')
# Key: 1055
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', 'freq'],
#       dtype='object')
# Key: 3409
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', '3', '24', '22', '4',
#        '16', '58', '54', '51', '52', '53', '55', '56', '124', '125', '126',
#        '127', '128', '129', '130', '131', '132', '83', '94', '86', '87', '88',
#        '89', '91', '93', '95', '106', '103', '96', '97', '101', '102', '104',
#        'PP5_1', 'PP5_2', 'PP5_3'],
#       dtype='object')
# Key: 2290
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', 'Commuting'],
#       dtype='object')
# Key: 1121
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', '25'],
#       dtype='object')
# Key: 6781
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', '1_11', '147', '146'],
#       dtype='object')
# Key: 4578
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', '4_2'],
#       dtype='object')
# Key: 0
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year'],
#       dtype='object')
# Key: 2230
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', '23'],
#       dtype='object')
# Key: 5590
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', 'PP1_4', 'PP2_4'],
#       dtype='object')
# Key: 4481
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', '19', '15', '27', '29',
#        '45', '46', '69', '70', '71', '73', '49', '75', '66', '63', '64', '33',
#        '37', '44', '43', '108', '117', '118', '119', '120', '122', '109',
#        '110', '111', '112', '113', '114', '115', '116', 'PP3_4'],
#       dtype='object')
# Key: 2300
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year', 'PTP5'],
#       dtype='object')

# %%
doc.add_heading('Lists with Activities information', 2)
all_lists_changed = {}
# Update the column names for each dataset and also update the all_lists dictionary
for year, dataset in datasets.items():
    activity_dict = dataset_params[str(year)]['activity_dictionary']
    sync_columns = all_lists[str(year)]['basic_lists']['listSyncColumns']
    datasets[year], column_mapping = update_column_names(dataset, activity_dict, sync_columns)
    all_lists_changed[str(year)] = update_all_lists(all_lists.copy(), str(year), column_mapping)

doc.add_heading('datasets', 2)

for year, dataset in datasets.items():
    print(f"Year: {year}")
    print(dataset.columns)
# Out:
# Year: 2016
# Index(['Course', 'Class', 'Sex', 'freq', '1', '3', '24', '12', '20', '22',
#        ...
#        'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP',
#        'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'],
#       dtype='object', length=105)
# Year: 2017
# Index(['Course', 'Class', 'Sex', 'Commuting', 'freq', '1', '3', '24', '12',
#        '20',
#        ...
#        'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP',
#        'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'],
#       dtype='object', length=107)
# Year: 2018
# Index(['Course', 'Class', 'Sex', 'Commuting', 'freq', '1', '3', '24', '12',
#        '20',
#        ...
#        'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP',
#        'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'],
#       dtype='object', length=107)
# Year: 2019
# Index(['Course', 'Class', 'Sex', 'Commuting', '1', '3', '18', '24', '20', '22',
#        ...
#        'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP',
#        'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'],
#       dtype='object', length=107)
# Year: 2022
# Index(['Course', 'Class', 'Sex', 'Commuting', 'freq', '1', '23', '133', '134',
#        '135',
#        ...
#        'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP',
#        'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'],
#       dtype='object', length=101)
# Year: 2023
# Index(['Course', 'Class', 'Sex', 'Commuting', 'freq', '1', '1_11', '18', '19',
#        '20',
#        ...
#        'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP',
#        'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'],
#       dtype='object', length=115)
# Year: 2024
# Index(['Course', 'Class', 'Sex', 'freq', '1', '2', '15', '18', '19', '20',
#        ...
#        'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP',
#        'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'],
#       dtype='object', length=117)

# %%
# Verify the changes in all_lists
for year in all_lists_changed:
    print(f"Year: {year}")
    print(all_lists_changed[year]['basic_lists']['listAllColumns'])
# Out:
# Year: 2016
# ['Course', 'Class', 'Sex', 'freq', '1', '3', '24', '12', '20', '22', '4', '25', '10', '11', '1_5', '16', '23', '32', '38', '42', '23', '35', '58', '23', '50', '54', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '124', '125', '126', '127', '128', '129', '130', '131', '132', '83', '94', '86', '87', '88', '89', '91', '93', '72', '95', '105', '106', '103', '96', '97', '101', '102', '77', '104', 'SPA1', 'SPA2', 'SPA3', 'Bon', 'BonCoord', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_1', 'PP4_2', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed']
# Year: 2017
# ['Course', 'Class', 'Sex', 'Commuting', 'freq', '1', '3', '24', '12', '20', '22', '4', '25', '10', '11', '16', '23', '32', '38', '42', '23', '35', '58', '23', '50', '54', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '124', '125', '126', '127', '128', '129', '130', '131', '132', '83', '94', '94', '4_2', '86', '87', '88', '89', '91', '93', '72', '72', '95', '104', '106', '96', '97', '101', '102', '77', '103', 'SPA1', 'SPA2', 'SPA3', 'Bon', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_1', 'PP4_2', 'PP4_3', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed']
# Year: 2018
# ['Course', 'Class', 'Sex', 'Commuting', 'freq', '1', '3', '24', '12', '20', '22', '4', '25', '10', '11', '16', '23', '18', '32', '38', '42', '23', '35', '58', '23', '50', '54', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '124', '125', '126', '127', '128', '129', '130', '131', '132', '83', '94', '94', '4_2', '86', '87', '88', '89', '91', '93', '72', '72', '95', '104', '106', '96', '97', '101', '102', '77', '103', 'SPA1', 'SPA2', 'SPA3', 'Bon', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_1', 'PP4_2', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed']
# Year: 2019
# ['Course', 'Class', 'Sex', 'Commuting', '1', '3', '18', '24', '20', '22', '4', '25', '10', '11', '16', '12', '1_8', '32', '38', '42', '23', '35', '58', '23', '50', '54', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '124', '125', '126', '127', '128', '129', '130', '131', '132', '83', '94', '94', '4_2', '86', '87', '88', '89', '91', '93', '72', '72', '95', '104', '106', '96', '97', '101', '102', '77', '103', 'SPA1', 'SPA2', 'SPA3', 'Bon', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_1', 'PP4_2', 'PP4_3', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed']
# Year: 2022
# ['Course', 'Class', 'Sex', 'Commuting', 'freq', '1', '23', '133', '134', '135', '19', '137', '138', '32', '144', '139', '140', '20', '25', '10', '11', '12', '15', '27', '29', '2_11', '35', '45', '46', '69', '70', '71', '72', '73', '49', '30', '75', '66', '63', '64', '50', '31', '33', '36', '37', '34', '38', '44', '42', '43', '108', '117', '118', '142', '119', '120', '122', '109', '110', '111', '112', '113', '114', '115', '116', 'SPA1', 'SPA2', 'SPA3', 'Bon', 'PP1_1', 'PP1_2', 'PP1_3', 'PP1_4', 'PP2_1', 'PP2_2', 'PP2_3', 'PP2_4', 'PP3_1', 'PP3_2', 'PP3_3', 'PP3_4', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed']
# Year: 2023
# ['Course', 'Class', 'Sex', 'Commuting', 'freq', '1', '1_11', '18', '19', '20', '7', '25', '10', '11', '12', '15', '27', '28', '29', '39', '49', '41', '42', '43', '44', '45', '46', '50', '30', '31', '147', '32', '33', '34', '35', '36', '37', '38', '59', '60', '61', '69', '70', '71', '72', '73', '74', '75', '82', '62', '146', '63', '64', '65', '66', '76', '77', '68', '108', '117', '118', '119', '120', '122', '122', '109', '110', '111', '112', '113', '114', '115', '116', 'SPA1', 'SPA2', 'SPA3', 'SPA4', 'Bon', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP3_4', 'PP4_1', 'PP4_2', 'PP4_3', 'PP4_4', 'PP4_5', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed']
# Year: 2024
# ['Course', 'Class', 'Sex', 'freq', '1', '2', '15', '18', '19', '20', '5', '7', '8', '9', '10', '11', '12', '27', '28', '29', '39', '49', '41', '42', '43', '44', '45', '46', '50', '30', '31', '32', '33', '34', '35', '36', '37', '38', '59', '60', '61', '70', '71', '72', '73', '74', '75', '78', '82', '62', '63', '64', '65', '66', '76', '77', '68', '69', '108', '117', '118', '119', '120', '122', '123', '109', '110', '111', '112', '113', '114', '115', '116', 'SPA1', 'SPA2', 'SPA3', 'SPA4', 'Bon', 'PP1_1', 'PP1_2', 'PP1_3', 'PP1_4', 'PP2_1', 'PP2_2', 'PP2_3', 'PP2_4', 'PP3_1', 'PP3_2', 'PP3_3', 'PP3_4', 'PP3_5', 'PP4_1', 'PP4_2', 'PP4_3', 'PP4_4', 'PP4_5', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed']

# %%
doc.add_heading('Combined dataset made in this notebook', 2)

# Ensure the datasets dictionary is properly indexed and columns are unique
for year, df in datasets.items():
    datasets[year] = df.reset_index(drop=True)
    datasets[year] = ensure_unique_columns(datasets[year])

# Combine all the dataframes from the dictionary 'datasets' into a single dataframe
combined_df = combine_datasets(datasets)

# Check the combined dataframe
print("Combined DataFrame shape:", combined_df.shape)
print("Combined DataFrame columns:", combined_df.columns)
# Out:
# Combined DataFrame shape: (7890, 185)
# Combined DataFrame columns: Index(['Course', 'Class', 'Sex', 'freq', '1', '3', '24', '12', '20', '22',
#        ...
#        'SPA4', 'PP4_4', 'PP4_5', '2', '5', '8', '9', '78', '123', 'PP3_5'],
#       dtype='object', length=185)

# %%
doc.add_heading('Verify the loaded datasets', 2)

# Verify the loaded datasets
print("datasets (from data_prepation but with the IDs as column names) keys:", datasets.keys())
print()
print("compose_datasets (from data_preparation notebook) keys:", compose_datasets.keys()) # imported from data_preparation
print()
print("dataset_complete (dataset_no_missing.feather from data_preparation notebook) size = ", len(dataset_complete))
print()
print("-"*50)
print("combined_df dataframe (created in this notebook) size = ", len(combined_df)) # combined in this notebook
print()
print("combined_df dataframe (created in this notebook)  columns: ", combined_df.columns)
print()
print("combined_df dataframe (created in this notebook)  info:")
print(combined_df.info())
print("combined_df dataframe (created in this notebook) statistics:\n", combined_df.describe())
# Out:
# datasets (from data_prepation but with the IDs as column names) keys: dict_keys([2016, 2017, 2018, 2019, 2022, 2023, 2024])
#
# compose_datasets (from data_preparation notebook) keys: dict_keys([242, 6769, 6835, 3453, 5660, 3500, 6711, 1179, 6721, 1055, 3409, 2290, 1121, 6781, 4578, 0, 2230, 5590, 4481, 2300])
#
# dataset_complete (dataset_no_missing.feather from data_preparation notebook) size =  7890
#
# --------------------------------------------------
# combined_df dataframe (created in this notebook) size =  7890
#
# combined_df dataframe (created in this notebook)  columns:  Index(['Course', 'Class', 'Sex', 'freq', '1', '3', '24', '12', '20', '22',
#        ...
#        'SPA4', 'PP4_4', 'PP4_5', '2', '5', '8', '9', '78', '123', 'PP3_5'],
#       dtype='object', length=185)
#
# combined_df dataframe (created in this notebook)  info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7890 entries, 0 to 7889
# Columns: 185 entries, Course to PP3_5
# dtypes: category(1), float64(136), int64(44), object(4)
# memory usage: 11.1+ MB
# None
# combined_df dataframe (created in this notebook) statistics:
#                   1            3           24           12           20  \
# count  7890.000000  4481.000000  4481.000000  7890.000000  7890.000000
# mean      0.901648     0.043071     0.870565     0.927376     0.906971
# std       0.297809     0.236552     0.335719     0.259534     0.304551
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     0.000000     1.000000     1.000000     1.000000
# 50%       1.000000     0.000000     1.000000     1.000000     1.000000
# 75%       1.000000     0.000000     1.000000     1.000000     1.000000
# max       1.000000     3.000000     1.000000     1.000000     2.000000
#
#                 22            4           25           10           11  ...  \
# count  4481.000000  4481.000000  6769.000000  7890.000000  7890.000000  ...
# mean      0.563044     0.028342     0.901315     2.565906     0.914195  ...
# std       1.126432     0.280067     0.298261     0.862908     1.293769  ...
# min       0.000000     0.000000     0.000000     0.000000     0.000000  ...
# 25%       0.000000     0.000000     1.000000     2.000000     0.000000  ...
# 50%       0.000000     0.000000     1.000000     3.000000     0.000000  ...
# 75%       0.000000     0.000000     1.000000     3.000000     2.000000  ...
# max       3.000000     3.000000     1.000000     3.000000     4.000000  ...
#
#               SPA4        PP4_4        PP4_5            2            5  \
# count  2230.000000  2230.000000  2230.000000  1121.000000  1121.000000
# mean      2.121076     0.977578     0.991928     0.850134     0.916146
# std       0.680864     0.465440     0.478265     0.357100     0.277292
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       2.000000     1.000000     1.000000     1.000000     1.000000
# 50%       2.000000     1.000000     1.000000     1.000000     1.000000
# 75%       2.000000     1.000000     1.000000     1.000000     1.000000
# max       7.000000     2.000000     2.000000     1.000000     1.000000
#
#                  8            9           78          123        PP3_5
# count  1121.000000  1121.000000  1121.000000  1121.000000  1121.000000
# mean      0.900981     0.862623     2.446922     0.793042     0.958073
# std       0.298820     0.344399     1.023427     0.405306     0.493737
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       1.000000     1.000000     2.000000     1.000000     1.000000
# 50%       1.000000     1.000000     3.000000     1.000000     1.000000
# 75%       1.000000     1.000000     3.000000     1.000000     1.000000
# max       1.000000     1.000000     3.000000     1.000000     2.000000
#
# [8 rows x 180 columns]

# %%
print("combined_df dataframe (created in this notebook) missing values:")

check_missing_values(combined_df)
# Out:
# combined_df dataframe (created in this notebook) missing values:
# Missing values for Course dataset:
# []
# Missing values for Class dataset:
# []
# Missing values for Sex dataset:
# []
# Missing values for freq dataset:
# [1055]
# Missing values for 1 dataset:
# []
# Missing values for 3 dataset:
# [3409]
# Missing values for 24 dataset:
# [3409]
# Missing values for 12 dataset:
# []
# Missing values for 20 dataset:
# []
# Missing values for 22 dataset:
# [3409]
# Missing values for 4 dataset:
# [3409]
# Missing values for 25 dataset:
# [1121]
# Missing values for 10 dataset:
# []
# Missing values for 11 dataset:
# []
# Missing values for 1_5 dataset:
# [6721]
# Missing values for 16 dataset:
# [3409]
# Missing values for 23 dataset:
# [2230]
# Missing values for 32 dataset:
# []
# Missing values for 38 dataset:
# []
# Missing values for 42 dataset:
# []
# Missing values for 23_1 dataset:
# [3409]
# Missing values for 35 dataset:
# []
# Missing values for 58 dataset:
# [3409]
# Missing values for 23_2 dataset:
# [4464]
# Missing values for 50 dataset:
# []
# Missing values for 54 dataset:
# [3409]
# Missing values for 30 dataset:
# []
# Missing values for 51 dataset:
# [3409]
# Missing values for 31 dataset:
# []
# Missing values for 52 dataset:
# [3409]
# Missing values for 28 dataset:
# [1179]
# Missing values for 53 dataset:
# [3409]
# Missing values for 36 dataset:
# []
# Missing values for 55 dataset:
# [3409]
# Missing values for 56 dataset:
# [3409]
# Missing values for 34 dataset:
# []
# Missing values for 124 dataset:
# [3409]
# Missing values for 125 dataset:
# [3409]
# Missing values for 126 dataset:
# [3409]
# Missing values for 127 dataset:
# [3409]
# Missing values for 128 dataset:
# [3409]
# Missing values for 129 dataset:
# [3409]
# Missing values for 130 dataset:
# [3409]
# Missing values for 131 dataset:
# [3409]
# Missing values for 132 dataset:
# [3409]
# Missing values for 83 dataset:
# [3409]
# Missing values for 94 dataset:
# [3409]
# Missing values for 86 dataset:
# [3409]
# Missing values for 87 dataset:
# [3409]
# Missing values for 88 dataset:
# [3409]
# Missing values for 89 dataset:
# [3409]
# Missing values for 91 dataset:
# [3409]
# Missing values for 93 dataset:
# [3409]
# Missing values for 72 dataset:
# []
# Missing values for 95 dataset:
# [3409]
# Missing values for 105 dataset:
# [6721]
# Missing values for 106 dataset:
# [3409]
# Missing values for 103 dataset:
# [3409]
# Missing values for 96 dataset:
# [3409]
# Missing values for 97 dataset:
# [3409]
# Missing values for 101 dataset:
# [3409]
# Missing values for 102 dataset:
# [3409]
# Missing values for 77 dataset:
# [1179]
# Missing values for 104 dataset:
# [3409]
# Missing values for SPA1 dataset:
# []
# Missing values for SPA2 dataset:
# []
# Missing values for SPA3 dataset:
# []
# Missing values for Bon dataset:
# []
# Missing values for BonCoord dataset:
# [6721]
# Missing values for PP1_1 dataset:
# []
# Missing values for PP1_2 dataset:
# []
# Missing values for PP1_3 dataset:
# []
# Missing values for PP2_1 dataset:
# []
# Missing values for PP2_2 dataset:
# []
# Missing values for PP2_3 dataset:
# []
# Missing values for PP3_1 dataset:
# []
# Missing values for PP3_2 dataset:
# []
# Missing values for PP3_3 dataset:
# []
# Missing values for PP4_1 dataset:
# [1179]
# Missing values for PP4_2 dataset:
# [1179]
# Missing values for PP5_1 dataset:
# [3409]
# Missing values for PP5_2 dataset:
# [3409]
# Missing values for PP5_3 dataset:
# [3409]
# Missing values for PTP1 dataset:
# []
# Missing values for PTP2 dataset:
# []
# Missing values for PTP3 dataset:
# []
# Missing values for PTP4 dataset:
# [1179]
# Missing values for PTP5 dataset:
# [2300]
# Missing values for FinalGradeInteger dataset:
# []
# Missing values for FinalGrade dataset:
# [242]
# Missing values for Total_AP dataset:
# []
# Missing values for Total_PP dataset:
# []
# Missing values for Total_SPA dataset:
# []
# Missing values for Total_Bon dataset:
# []
# Missing values for Week1_AP dataset:
# []
# Missing values for Week2_AP dataset:
# []
# Missing values for Week3_AP dataset:
# []
# Missing values for Week4_AP dataset:
# []
# Missing values for Week5_AP dataset:
# []
# Missing values for Week1_PP dataset:
# []
# Missing values for Week2_PP dataset:
# []
# Missing values for Week3_PP dataset:
# []
# Missing values for Week4_PP dataset:
# []
# Missing values for Week5_PP dataset:
# []
# Missing values for Passed dataset:
# []
# Missing values for Year dataset:
# []
# Missing values for Commuting dataset:
# [2290]
# Missing values for 94_1 dataset:
# [4578]
# Missing values for 4_2 dataset:
# [4578]
# Missing values for 72_1 dataset:
# [4578]
# Missing values for PP4_3 dataset:
# [3453]
# Missing values for 18 dataset:
# [3500]
# Missing values for 1_8 dataset:
# [6835]
# Missing values for 133 dataset:
# [6711]
# Missing values for 134 dataset:
# [6711]
# Missing values for 135 dataset:
# [6711]
# Missing values for 19 dataset:
# [4481]
# Missing values for 137 dataset:
# [6711]
# Missing values for 138 dataset:
# [6711]
# Missing values for 144 dataset:
# [6711]
# Missing values for 139 dataset:
# [6711]
# Missing values for 140 dataset:
# [6711]
# Missing values for 15 dataset:
# [4481]
# Missing values for 27 dataset:
# [4481]
# Missing values for 29 dataset:
# [4481]
# Missing values for 2_11 dataset:
# [6711]
# Missing values for 45 dataset:
# [4481]
# Missing values for 46 dataset:
# [4481]
# Missing values for 69 dataset:
# [4481]
# Missing values for 70 dataset:
# [4481]
# Missing values for 71 dataset:
# [4481]
# Missing values for 73 dataset:
# [4481]
# Missing values for 49 dataset:
# [4481]
# Missing values for 75 dataset:
# [4481]
# Missing values for 66 dataset:
# [4481]
# Missing values for 63 dataset:
# [4481]
# Missing values for 64 dataset:
# [4481]
# Missing values for 33 dataset:
# [4481]
# Missing values for 37 dataset:
# [4481]
# Missing values for 44 dataset:
# [4481]
# Missing values for 43 dataset:
# [4481]
# Missing values for 108 dataset:
# [4481]
# Missing values for 117 dataset:
# [4481]
# Missing values for 118 dataset:
# [4481]
# Missing values for 142 dataset:
# [6711]
# Missing values for 119 dataset:
# [4481]
# Missing values for 120 dataset:
# [4481]
# Missing values for 122 dataset:
# [4481]
# Missing values for 109 dataset:
# [4481]
# Missing values for 110 dataset:
# [4481]
# Missing values for 111 dataset:
# [4481]
# Missing values for 112 dataset:
# [4481]
# Missing values for 113 dataset:
# [4481]
# Missing values for 114 dataset:
# [4481]
# Missing values for 115 dataset:
# [4481]
# Missing values for 116 dataset:
# [4481]
# Missing values for PP1_4 dataset:
# [5590]
# Missing values for PP2_4 dataset:
# [5590]
# Missing values for PP3_4 dataset:
# [4481]
# Missing values for 1_11 dataset:
# [6781]
# Missing values for 7 dataset:
# [5660]
# Missing values for 39 dataset:
# [5660]
# Missing values for 41 dataset:
# [5660]
# Missing values for 147 dataset:
# [6781]
# Missing values for 59 dataset:
# [5660]
# Missing values for 60 dataset:
# [5660]
# Missing values for 61 dataset:
# [5660]
# Missing values for 74 dataset:
# [5660]
# Missing values for 82 dataset:
# [5660]
# Missing values for 62 dataset:
# [5660]
# Missing values for 146 dataset:
# [6781]
# Missing values for 65 dataset:
# [5660]
# Missing values for 76 dataset:
# [5660]
# Missing values for 68 dataset:
# [5660]
# Missing values for 122_1 dataset:
# [6781]
# Missing values for SPA4 dataset:
# [5660]
# Missing values for PP4_4 dataset:
# [5660]
# Missing values for PP4_5 dataset:
# [5660]
# Missing values for 2 dataset:
# [6769]
# Missing values for 5 dataset:
# [6769]
# Missing values for 8 dataset:
# [6769]
# Missing values for 9 dataset:
# [6769]
# Missing values for 78 dataset:
# [6769]
# Missing values for 123 dataset:
# [6769]
# Missing values for PP3_5 dataset:
# [6769]

# %% [markdown]
# # 4. Application of Auxiliary Methods

# %% [markdown]
# ## 4.1. Check Missing Values

# %%
# Check for missing values in the datasets for each CTCT edition
print("datasets (from data_prepation but with the IDs as column names) - Checking missing values: ")
check_missing_values(datasets)
# Out:
# datasets (from data_prepation but with the IDs as column names) - Checking missing values:
# Missing values for 2016 dataset:
# FinalGrade    63
# dtype: int64
# Missing values for 2017 dataset:
# Series([], dtype: int64)
# Missing values for 2018 dataset:
# FinalGrade    29
# dtype: int64
# Missing values for 2019 dataset:
# FinalGrade    42
# dtype: int64
# Missing values for 2022 dataset:
# Series([], dtype: int64)
# Missing values for 2023 dataset:
# FinalGrade    49
# dtype: int64
# Missing values for 2024 dataset:
# FinalGrade    59
# dtype: int64

# %% [markdown]
# ## 4.2. Filter datasets for FinalGrade and FinalGradeInteger Prediction

# %%
# Filter out rows with missing or zero FinalGrade in the datasets
filtered_datasets = filter_missing_and_zero_final_grade(datasets)

for year, dataset in filtered_datasets.items():
    print(f"After filtering, {year} dataset has {len(dataset[dataset['FinalGrade']>0])} positive FinalGrade values.")
# Out:
# After filtering, 2016 dataset has 1106 rows. Before had 1169. Dropped 63 instances/students.
# After filtering, 2017 dataset has 1078 rows. Before had 1152. Dropped 74 instances/students.
# After filtering, 2018 dataset has 1076 rows. Before had 1105. Dropped 29 instances/students.
# After filtering, 2019 dataset has 1013 rows. Before had 1055. Dropped 42 instances/students.
# After filtering, 2022 dataset has 1138 rows. Before had 1179. Dropped 41 instances/students.
# After filtering, 2023 dataset has 1060 rows. Before had 1109. Dropped 49 instances/students.
# After filtering, 2024 dataset has 1062 rows. Before had 1121. Dropped 59 instances/students.
# After filtering, 2016 dataset has 1106 positive FinalGrade values.
# After filtering, 2017 dataset has 1078 positive FinalGrade values.
# After filtering, 2018 dataset has 1076 positive FinalGrade values.
# After filtering, 2019 dataset has 1013 positive FinalGrade values.
# After filtering, 2022 dataset has 1138 positive FinalGrade values.
# After filtering, 2023 dataset has 1060 positive FinalGrade values.
# After filtering, 2024 dataset has 1062 positive FinalGrade values.

# %%
# Filter out missing and zero final grades in dataset_complete
print("Filtering missing and zero final grades in dataset_complete...")
filtered_dataset_complete = dataset_complete.dropna(subset=['FinalGradeInteger'])
filtered_dataset_complete = filtered_dataset_complete[filtered_dataset_complete['FinalGradeInteger'] != 0]

# Filter out missing and zero final grades in dataset_complete
print("Filtering missing and zero final grades in combined_df...")
filtered_combined_df = combined_df.dropna(subset=['FinalGradeInteger'])
filtered_combined_df = filtered_combined_df[filtered_combined_df['FinalGradeInteger'] != 0]
# Out:
# Filtering missing and zero final grades in dataset_complete...
# Filtering missing and zero final grades in combined_df...

# %%
filtered_combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7498 entries, 0 to 7830
# Columns: 185 entries, Course to PP3_5
# dtypes: category(1), float64(136), int64(44), object(4)
# memory usage: 10.6+ MB

# %%
filtered_dataset_complete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7498 entries, 0 to 7830
# Data columns (total 40 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Course             7498 non-null   object
#  1   Class              7498 non-null   object
#  2   Sex                7498 non-null   category
#  3   1                  7498 non-null   int64
#  4   12                 7498 non-null   int64
#  5   20                 7498 non-null   int64
#  6   10                 7498 non-null   int64
#  7   11                 7498 non-null   int64
#  8   32                 7498 non-null   int64
#  9   38                 7498 non-null   int64
#  10  42                 7498 non-null   int64
#  11  35                 7498 non-null   int64
#  12  50                 7498 non-null   int64
#  13  30                 7498 non-null   int64
#  14  31                 7498 non-null   int64
#  15  36                 7498 non-null   int64
#  16  34                 7498 non-null   int64
#  17  72                 7498 non-null   int64
#  18  SPA1               7498 non-null   int64
#  19  SPA2               7498 non-null   int64
#  20  SPA3               7498 non-null   int64
#  21  Bon                7498 non-null   int64
#  22  PP1_1              7498 non-null   int64
#  23  PP1_2              7498 non-null   int64
#  24  PP1_3              7498 non-null   int64
#  25  PP2_1              7498 non-null   int64
#  26  PP2_2              7498 non-null   int64
#  27  PP2_3              7498 non-null   int64
#  28  PP3_1              7498 non-null   int64
#  29  PP3_2              7498 non-null   int64
#  30  PP3_3              7498 non-null   int64
#  31  PTP1               7498 non-null   int64
#  32  PTP2               7498 non-null   int64
#  33  PTP3               7498 non-null   int64
#  34  FinalGradeInteger  7498 non-null   int64
#  35  Total_AP           7498 non-null   float64
#  36  Total_PP           7498 non-null   float64
#  37  Total_SPA          7498 non-null   float64
#  38  Total_Bon          7498 non-null   float64
#  39  Year               7498 non-null   object
# dtypes: category(1), float64(4), int64(32), object(3)
# memory usage: 2.3+ MB

# %% [markdown]
# # 5. Feature Selection

# %%
doc.add_heading('Output of Feature Selection Report', 0)
all_lists = all_lists_changed

# %% [markdown]
# ## 5.1. Exclude Columns from Selection

# %%
doc.add_heading('Exclude Columns', 1)

# %%
exclude_columns = {}
fixed_exclude_columns = ['SS', 'Commuting', 'freq', 'Class', 'Course', 'Sex']
for year in dataset_years:
    exclude_columns[str(year)] = set()
    all_lists_year = all_lists[str(year)]
    exclude_columns[str(year)].update(fixed_exclude_columns)
    exclude_columns[str(year)].update(all_lists_year['basic_lists']['listSPAColumns'])
    exclude_columns[str(year)].update(all_lists_year['basic_lists']['listBonColumns'])
    exclude_columns[str(year)].update(all_lists_year['basic_lists']['listGrades'])
    exclude_columns[str(year)].update(all_lists_year['basic_lists']['listCategorical'])
    exclude_columns[str(year)].update(all_lists_year['basic_lists']['listPPointsColumns'])
    exclude_columns[str(year)].update(all_lists_year['created_columns']['TotalColumns'])
    exclude_columns[str(year)].update(all_lists_year['created_columns']['OtherColumns'])
    exclude_columns[str(year)].update(all_lists_year['created_columns']['WeeklyAP'])
    exclude_columns[str(year)].update(all_lists_year['created_columns']['WeeklyPP'])
    exclude_columns[str(year)].update(all_lists_year['weekly_and_participation_lists']['listWeek3'])
    exclude_columns[str(year)].update(all_lists_year['weekly_and_participation_lists']['listWeek4'])
    exclude_columns[str(year)].update(all_lists_year['weekly_and_participation_lists']['listWeek5'])
    exclude_columns[str(year)].update(all_lists_year['weekly_and_participation_lists']['listPPWeek3'])
    exclude_columns[str(year)].update(all_lists_year['weekly_and_participation_lists']['listPPWeek4'])
    exclude_columns[str(year)].update(all_lists_year['weekly_and_participation_lists']['listPPWeek5'])

print("Exclude columns defined successfully.")
# Out:
# Exclude columns defined successfully.

# %%
exclude_columns_less_restricted = {}
fixed_exclude_columns = ['SS', 'Commuting', 'freq', 'Class', 'Course', 'Sex']
for year in dataset_years:
    exclude_columns_less_restricted [str(year)] = set()
    all_lists_year = all_lists[str(year)]
    exclude_columns_less_restricted[str(year)].update(fixed_exclude_columns)
    exclude_columns_less_restricted[str(year)].update(all_lists_year['basic_lists']['listSPAColumns'])
    exclude_columns_less_restricted[str(year)].update(all_lists_year['basic_lists']['listBonColumns'])
    exclude_columns_less_restricted[str(year)].update(all_lists_year['basic_lists']['listGrades'])
    exclude_columns[str(year)].update(all_lists_year['basic_lists']['listCategorical'])
    exclude_columns_less_restricted[str(year)].update(all_lists_year['basic_lists']['listPPointsColumns'])
    exclude_columns_less_restricted[str(year)].update(all_lists_year['created_columns']['TotalColumns'])
    exclude_columns_less_restricted[str(year)].update(all_lists_year['created_columns']['OtherColumns'])
    exclude_columns_less_restricted[str(year)].update(all_lists_year['created_columns']['WeeklyAP'])
    exclude_columns_less_restricted[str(year)].update(all_lists_year['created_columns']['WeeklyPP'])

print("Exclude columns defined successfully.")
# Out:
# Exclude columns defined successfully.

# %%
exclude_columns_not_restricted = {}
fixed_exclude_columns = ['SS', 'Commuting', 'freq', 'Class', 'Course', 'Sex']
for year in dataset_years:
    exclude_columns_not_restricted [str(year)] = set()
    all_lists_year = all_lists[str(year)]
    exclude_columns_not_restricted [str(year)].update(fixed_exclude_columns)

print("Exclude columns defined successfully.")
# Out:
# Exclude columns defined successfully.

# %%
# List of exclusion types and corresponding exclusion column dictionaries
exclusion_columns_dicts = {
    'more_restricted': exclude_columns,
    'restricted': exclude_columns_less_restricted,
    'less_restricted': exclude_columns_not_restricted
}

# %%
# Aggregate columns to exclude from all specified years
years_to_exclude = ['2016', '2017', '2018', '2019', '2022', '2023', '2024']
aggregated_exclude_columns = {}
aggregated_exclude_columns['more_restricted'] = set()
aggregated_exclude_columns['restricted'] = set()
aggregated_exclude_columns['less_restricted'] = set()

for year in years_to_exclude:
    aggregated_exclude_columns['more_restricted'].update(exclude_columns[year])
    aggregated_exclude_columns['restricted'].update(exclude_columns_less_restricted[year])
    aggregated_exclude_columns['less_restricted'].update(exclude_columns_not_restricted[year])

# Convert the set back to a list
aggregated_exclude_columns['more_restricted'] = list(aggregated_exclude_columns['more_restricted'])
aggregated_exclude_columns['restricted'] = list(aggregated_exclude_columns['restricted'])
aggregated_exclude_columns['less_restricted'] = list(aggregated_exclude_columns['less_restricted'])

# %% [markdown]
# ### 5.1.1. Save combined_df for prediction

# %%
create_and_save_datasets(combined_df, exclude_columns, 'Passed', output_dir)
create_and_save_datasets(filtered_combined_df, exclude_columns, 'FinalGrade', output_dir, filename_suffix="filtered_combined_df")
create_and_save_datasets(combined_df, exclude_columns, 'Total_AP', output_dir)
create_and_save_datasets(combined_df, exclude_columns, 'Total_PP', output_dir)
create_and_save_datasets(combined_df, exclude_columns, 'Total_SPA', output_dir)
# Out:
# Saved selected features to output/combined_df_Passed.feather.
# Saved selected features to output/filtered_combined_df_FinalGrade.feather.
# Saved selected features to output/combined_df_Total_AP.feather.
# Saved selected features to output/combined_df_Total_PP.feather.
# Saved selected features to output/combined_df_Total_SPA.feather.

# %% [markdown]
# ## 5.2. Methods

# %% [markdown]
# ###### select_by_variance

# %%
def select_by_variance(dataset, exclude_columns, variance_threshold=0.0):
    """
    Select columns from a dataset based on variance threshold and print their variance scores.

    Args:
    - dataset (pd.DataFrame): The input dataset containing the data to be filtered.
    - exclude_columns (list): List of columns to be excluded from the variance threshold calculation.
    - variance_threshold (float): The minimum variance threshold for features to be selected. Default is 0.0.

    Returns:
    - selected_columns (pd.Index): A sorted list of columns by variance in descending order.
    """
    # Select numerical columns, drop excluded columns, and fill missing values with 0
    numerical_cols = dataset.select_dtypes(include=[np.number]).drop(columns=exclude_columns, errors='ignore').fillna(0)

    # Initialize the VarianceThreshold with the specified threshold
    sel = VarianceThreshold(threshold=variance_threshold)

    # Apply the variance threshold to the selected numerical columns
    sel.fit(numerical_cols)
    variances = sel.variances_

    # Get the columns that pass the threshold
    selected_columns = numerical_cols.columns[sel.get_support()]

    # Sort the selected columns by their variance in descending order
    sorted_indices = np.argsort(variances[sel.get_support()])[::-1]  # Sort only the selected variances
    sorted_columns = selected_columns[sorted_indices]

    # Print the sorted columns with their variance scores
    variance_table = pd.DataFrame({'Feature': sorted_columns, 'Variance': variances[sel.get_support()][sorted_indices]})
    print("Variance Table")
    print(variance_table)
    print("-" * 50)
    print("")
    # Return only the sorted columns
    return sorted_columns

# %% [markdown]
# ###### feature_selection_analysis  (for original datasets)
# (for use on the dictionary with a dataframe per CTCT edition)

# %%
def feature_selection_analysis(datasets, all_lists, dataset_params, target_column, exclude_columns, methods=['MI', 'RF', 'DT']):
    """
    Perform feature selection analysis using multiple methods.

    Args:
    - datasets (dict): Dictionary of datasets by year.
    - all_lists (dict): Dictionary containing various lists of columns for each dataset year.
    - dataset_params (dict): Dictionary containing dataset parameters.
    - target_column (str): The target column for the analysis.
    - methods (list): List of methods to use for feature selection ('MI', 'RF', 'DT').

    Returns:
    - selected_features (dict): Dictionary of selected features for each year and method.
    """
    def perform_feature_selection_methods(dataset, all_lists, dataset_params, target_column, methods):
        """
        Perform feature selection using specified methods on the given dataset.
        """
        def select_by_mutual_info(features, target, target_is_continuous=False, random_state=2024):
            # Use mutual_info_regression for continuous targets and mutual_info_classif for categorical
            if target_is_continuous:
                mi = mutual_info_regression(features, target, random_state=random_state)
            else:
                mi = mutual_info_classif(features, target, random_state=random_state)
            mi_scores = pd.Series(mi, index=features.columns)
            return mi_scores

        def select_by_random_forest(numerical_cols, target_encoded, is_regression=False, random_state=2024):
            if is_regression:
                rf = RandomForestRegressor(random_state=random_state)
            else:
                rf = RandomForestClassifier(random_state=random_state)
            rf.fit(numerical_cols, target_encoded)
            rf_scores = pd.Series(rf.feature_importances_, index=numerical_cols.columns)
            return rf_scores

        def select_by_decision_tree(numerical_cols, target_encoded, is_regression=False, random_state=2024):
            if is_regression:
                dt = DecisionTreeRegressor(random_state=random_state)
            else:
                dt = DecisionTreeClassifier(random_state=random_state)
            dt.fit(numerical_cols, target_encoded)
            dt_scores = pd.Series(dt.feature_importances_, index=numerical_cols.columns)
            return dt_scores

        selected_features = {}

        # Prepare the data for feature selection
        numerical_cols = dataset.drop(columns=[target_column], errors='ignore').select_dtypes(include=[np.number])

        # Handle missing values
        imputer = SimpleImputer(strategy='constant', fill_value=0)
        numerical_cols = pd.DataFrame(imputer.fit_transform(numerical_cols), columns=numerical_cols.columns)

        # Identify categorical columns
        categorical_cols = [col for col in dataset.columns if col in all_lists.get('basic_lists', {}).get('listCategorical', [])]
        categorical_cols = [col for col in categorical_cols if col not in [target_column]]

        # Ensure proper encoding based on the method used
        encoded_datasets = {}

        if 'MI' in methods:
            # OneHotEncoding for MI
            if categorical_cols:
                enc = OneHotEncoder(sparse_output=False, drop='first')
                encoded_categorical = enc.fit_transform(dataset[categorical_cols].astype(str))
                encoded_categorical_df = pd.DataFrame(encoded_categorical, columns=enc.get_feature_names_out(categorical_cols))
                encoded_datasets['MI'] = numerical_cols.join(encoded_categorical_df)
            else:
                encoded_datasets['MI'] = numerical_cols

        if 'RF' in methods or 'DT' in methods:
            # LabelEncoding for RF and DT
            le = LabelEncoder()
            for col in categorical_cols:
                if col in dataset.columns:
                    dataset[col] = le.fit_transform(dataset[col].astype(str))

            if 'RF' in methods:
                encoded_datasets['RF'] = dataset[numerical_cols.columns.tolist() + categorical_cols]
            if 'DT' in methods:
                encoded_datasets['DT'] = dataset[numerical_cols.columns.tolist() + categorical_cols]

        # Determine if the target is continuous or categorical
        target_is_continuous = pd.api.types.is_numeric_dtype(dataset[target_column])

        # For continuous target (regression), use the target as-is; otherwise, encode it
        target_encoded = dataset[target_column] if target_is_continuous else dataset[target_column]

        for method in methods:
            if method == 'MI' and 'MI' in encoded_datasets:
                mi_scores = select_by_mutual_info(encoded_datasets['MI'], target_encoded, target_is_continuous=target_is_continuous)
                threshold_mi = 0.5 * mi_scores.median()
                important_features_mi = mi_scores[mi_scores > threshold_mi].index.tolist()
                selected_features['MI'] = important_features_mi

            if method == 'RF' and 'RF' in encoded_datasets:
                rf_scores = select_by_random_forest(encoded_datasets['RF'], target_encoded, is_regression=target_is_continuous)
                threshold_rf = 0.5 * rf_scores.median()
                important_features_rf = rf_scores[rf_scores > threshold_rf].index.tolist()
                selected_features['RF'] = important_features_rf

            if method == 'DT' and 'DT' in encoded_datasets:
                dt_scores = select_by_decision_tree(encoded_datasets['DT'], target_encoded, is_regression=target_is_continuous)
                threshold_dt = 0.5 * dt_scores.median()
                important_features_dt = dt_scores[dt_scores > threshold_dt].index.tolist()
                selected_features['DT'] = important_features_dt

        return selected_features

    # Initialize the dictionary to store selected features
    selected_features = {}

    for year, dataset in datasets.items():
        print(f"Feature Selection Analysis for the dataset of year: {year} with target column: {target_column}")

        if target_column not in dataset.columns:
            print(f"Skipping year {year}: Target column not found in dataset.")
            continue

        # Exclude columns and handle categorical variables properly
        columns_to_exclude = list(exclude_columns.get(str(year), []))
        selected_columns = [col for col in dataset.columns if col not in columns_to_exclude + [target_column]]

        if len(selected_columns) == 0:
            print(f"No columns selected for year {year} after applying column exclusion.")
            continue

        # Add the target column back to the selected columns
        selected_columns.append(target_column)

        # Subset the dataset with the selected columns
        dataset_reduced = dataset[selected_columns]

        # Handle missing values
        imputer = SimpleImputer(strategy='constant', fill_value=0)
        dataset_reduced_imputed = pd.DataFrame(imputer.fit_transform(dataset_reduced), columns=dataset_reduced.columns)

        # Process the rest of the function with the reduced and imputed columns
        selected_features[year] = perform_feature_selection_methods(dataset_reduced_imputed, all_lists.get(str(year), {}), dataset_params, target_column, methods)

        print("-" * 50)

    return selected_features

# %% [markdown]
# ###### feature_selection_for_regression

# %%
def feature_selection_for_regression(datasets, target_column, exclude_columns, methods=['FR', 'RF', 'Lasso']):
    """
    Perform feature selection analysis for regression using multiple methods.

    Args:
    - datasets (dict): Dictionary of datasets by year.
    - target_column (str): The target column for regression.
    - exclude_columns (list): List of columns to exclude from feature selection.
    - methods (list): List of methods to use for feature selection ('FR', 'RF', 'Lasso').

    Returns:
    - selected_features (dict): Dictionary of selected features for each year and method.
    """
    selected_features = {}

    for year, dataset in datasets.items():
        print(f"Feature Selection Analysis for the dataset of year: {year} with target column: {target_column}")

        if target_column not in dataset.columns:
            print(f"Skipping year {year}: Target column not found in dataset.")
            continue

        # Exclude columns
        numerical_cols = dataset.drop(columns=exclude_columns + [target_column], errors='ignore').select_dtypes(include=[np.number])
        target = dataset[target_column]

        # Perform feature selection using the specified methods
        selected_features[year] = {}

        if 'FR' in methods:  # Feature selection using F-regression
            #print("Calculating F-regression scores...")
            selector = SelectKBest(score_func=f_regression, k='all')
            selector.fit(numerical_cols, target)
            fr_scores = pd.Series(selector.scores_, index=numerical_cols.columns)
            threshold_fr = 0.5 * fr_scores.median()
            selected_features[year]['FR'] = fr_scores[fr_scores > threshold_fr].index.tolist()
            #print(f"Selected features by F-regression with threshold {threshold_fr}: {selected_features[year]['FR']}")

        if 'RF' in methods:  # Feature selection using Random Forest
            #print("Calculating Random Forest (RF) feature importances...")
            rf = RandomForestRegressor(random_state=2024)
            rf.fit(numerical_cols, target)
            rf_importances = pd.Series(rf.feature_importances_, index=numerical_cols.columns)
            threshold_rf = 0.5 * rf_importances.median()
            selected_features[year]['RF'] = rf_importances[rf_importances > threshold_rf].index.tolist()
            #print(f"Selected features by Random Forest with threshold {threshold_rf}: {selected_features[year]['RF']}")

        if 'Lasso' in methods:  # Feature selection using Lasso regression
            #print("Calculating Lasso coefficients...")
            lasso = Lasso(alpha=0.01, random_state=2024)
            lasso.fit(numerical_cols, target)
            lasso_coefficients = pd.Series(lasso.coef_, index=numerical_cols.columns)
            selected_features[year]['Lasso'] = lasso_coefficients[lasso_coefficients != 0].index.tolist()
            #print(f"Selected features by Lasso: {selected_features[year]['Lasso']}")

        print("-" * 50)

    return selected_features

# %% [markdown]
# ###### feature_selection_analysis_generic (for compose_datasets)

# %%
def feature_selection_analysis_generic(datasets, all_lists, target_column, exclude_columns, methods=['MI', 'RF', 'DT']):
    """
    Perform feature selection analysis using multiple methods.

    Args:
    - datasets (dict): Dictionary of datasets by key.
    - all_lists (dict): Dictionary containing various lists of columns for each dataset key.
    - target_column (str): The target column for the analysis.
    - exclude_columns (dict): Dictionary of columns to exclude for each year.
    - methods (list): List of methods to use for feature selection ('MI', 'RF', 'DT').

    Returns:
    - selected_features (dict): Dictionary of selected features for each key and method.
    """
    def select_by_mutual_info(features, target, target_is_continuous=False, random_state=2024):
        #print("Calculating Mutual Information (MI) scores...")
        if target_is_continuous:
            mi = mutual_info_regression(features, target, random_state=random_state)
        else:
            mi = mutual_info_classif(features, target, random_state=random_state)
        mi_scores = pd.Series(mi, index=features.columns)
        #print("MI scores calculated:", mi_scores.head())
        return mi_scores

    def select_by_random_forest(numerical_cols, target_encoded, random_state=2024):
        #print("Calculating Random Forest (RF) feature importances...")
        rf = RandomForestClassifier(random_state=random_state)
        rf.fit(numerical_cols, target_encoded)
        rf_scores = pd.Series(rf.feature_importances_, index=numerical_cols.columns)
        #print("RF importances calculated:", rf_scores.head())
        return rf_scores

    def select_by_decision_tree(numerical_cols, target_encoded, random_state=2024):
        #print("Calculating Decision Tree (DT) feature importances...")
        dt = DecisionTreeClassifier(random_state=random_state)
        dt.fit(numerical_cols, target_encoded)
        dt_scores = pd.Series(dt.feature_importances_, index=numerical_cols.columns)
        #print("DT importances calculated:", dt_scores.head())
        return dt_scores

    selected_features = {}

    for key, dataset in datasets.items():
        print(f"Feature Selection Analysis for the dataset with key: {key} with target column: {target_column}")

        if target_column not in dataset.columns:
            print(f"Skipping key {key}: Target column not found in dataset.")
            continue

        # Usar todos os anos presentes no dataset
        years = dataset['Year'].unique()

        # Ensure columns are excluded correctly
        columns_to_exclude = set(exclude_columns.get(str(years[0]), [])) | set([target_column])
        numerical_cols = dataset.select_dtypes(include=[np.number]).drop(columns=columns_to_exclude, errors='ignore')

        # Handle missing values
        imputer = SimpleImputer(strategy='constant', fill_value=0)
        numerical_cols = pd.DataFrame(imputer.fit_transform(numerical_cols), columns=numerical_cols.columns)

        selected_features[key] = {}

        for year in years:
            year = str(year)

            # Identify categorical columns for the specific year
            if year in all_lists:
                categorical_cols = [col for col in dataset.columns if col in all_lists[year]['basic_lists']['listCategorical']]
            else:
                print(f"Year {year} not found in all_lists for key {key}. Skipping this year.")
                continue

            categorical_cols = [col for col in categorical_cols if col not in columns_to_exclude]  # Exclude categorical columns that should be excluded

            # Create a copy of the dataset to avoid modifying the original
            dataset_copy = dataset.copy()

            # Apply appropriate encoding for each method
            encoded_datasets = {}

            # OneHotEncoding for MI
            if 'MI' in methods:
                if categorical_cols:
                    #print("Performing OneHotEncoding for MI...")
                    enc = OneHotEncoder(sparse_output=False, drop='first')
                    encoded_categorical = enc.fit_transform(dataset[categorical_cols].astype(str))
                    encoded_categorical_df = pd.DataFrame(encoded_categorical, columns=enc.get_feature_names_out(categorical_cols))
                    encoded_datasets['MI'] = numerical_cols.join(encoded_categorical_df)
                    #print(f"Encoded MI dataset: {encoded_datasets['MI'].shape}")
                else:
                    encoded_datasets['MI'] = numerical_cols  # If no categorical columns, MI can use numerical data directly

            # LabelEncoding for RF and DT
            if 'RF' in methods or 'DT' in methods:
                #print("Performing LabelEncoding for RF and DT...")
                le = LabelEncoder()
                for col in categorical_cols:
                    if col in dataset_copy.columns:
                        dataset_copy[col] = le.fit_transform(dataset_copy[col].astype(str))

                if 'RF' in methods:
                    encoded_datasets['RF'] = dataset_copy[numerical_cols.columns.tolist() + categorical_cols]
                    #print(f"Encoded RF dataset: {encoded_datasets['RF'].shape}")

                if 'DT' in methods:
                    encoded_datasets['DT'] = dataset_copy[numerical_cols.columns.tolist() + categorical_cols]
                    #print(f"Encoded DT dataset: {encoded_datasets['DT'].shape}")

            # Handle target column discretization or encoding
            if pd.api.types.is_numeric_dtype(dataset[target_column]):
                target_encoded = dataset[target_column]
            else:
                target_encoded = dataset[target_column]

            for method in methods:
                if method == 'MI' and 'MI' in encoded_datasets:
                    mi_scores = select_by_mutual_info(encoded_datasets['MI'], target_encoded)
                    threshold_mi = 0.5 * mi_scores.median()
                    important_features_mi = mi_scores[mi_scores > threshold_mi].index.tolist()
                    selected_features[key][f'MI_{year}'] = important_features_mi
                    #print(f"Selected features by MI with threshold {threshold_mi}: {important_features_mi}")

                if method == 'RF' and 'RF' in encoded_datasets:
                    rf_scores = select_by_random_forest(encoded_datasets['RF'], target_encoded)
                    threshold_rf = 0.5 * rf_scores.median()
                    important_features_rf = rf_scores[rf_scores > threshold_rf].index.tolist()
                    selected_features[key][f'RF_{year}'] = important_features_rf
                    #print(f"Selected features by RF with threshold {threshold_rf}: {important_features_rf}")

                if method == 'DT' and 'DT' in encoded_datasets:
                    dt_scores = select_by_decision_tree(encoded_datasets['DT'], target_encoded)
                    threshold_dt = 0.5 * dt_scores.median()
                    important_features_dt = dt_scores[dt_scores > threshold_dt].index.tolist()
                    selected_features[key][f'DT_{year}'] = important_features_dt
                    #print(f"Selected features by DT with threshold {threshold_dt}: {important_features_dt}")

        print("-" * 50)

    return selected_features

# %% [markdown]
# ###### extract_common_features
# ###### extract_common_features_continuous

# %%
def extract_common_features(selected_features):
    common_features = {'MI': [], 'RF': [], 'DT': []}
    methods = common_features.keys()

    for method in methods:
        # Get the list of features for each year for the current method
        features_per_year = [set(features[method]) for year, features in selected_features.items() if method in features]

        # Find the intersection of all feature sets
        if features_per_year:
            common_features[method] = list(set.intersection(*features_per_year))

    return common_features

def extract_common_features_continuous(selected_features_cont):
    common_features = {'FR': [], 'RF': [], 'Lasso': []}
    methods = common_features.keys()

    for method in methods:
        # Get the list of features for each year for the current method
        features_per_year = [set(features[method]) for year, features in selected_features_cont.items() if method in features]

        # Find the intersection of all feature sets
        if features_per_year:
            common_features[method] = list(set.intersection(*features_per_year))

    return common_features

# %%
def extract_common_features_per_compose_dataset(selected_features, compose_datasets):
    common_features_per_dataset = {}

    for dataset_key, compose_df in compose_datasets.items():
        # Extract the years available in the current compose dataset
        dataset_years = compose_df['Year'].unique()
        common_features = {'MI': [], 'RF': [], 'DT': []}

        for method in common_features.keys():
            # Collect features for the available years and the current method
            features_per_year = []
            for year in dataset_years:
                key = f"{method}_{year}"
                if key in selected_features.get(dataset_key, {}):
                    features_per_year.append(set(selected_features[dataset_key][key]))

            # Find the intersection of all feature sets for the current method
            if features_per_year:
                common_features[method] = list(set.intersection(*features_per_year))
                if not common_features[method]:  # Check if the intersection is empty
                    print(f"No common features found for {dataset_key} (method {method})")

        common_features_per_dataset[dataset_key] = common_features

    return common_features_per_dataset

def extract_common_features_continuous_per_compose_dataset(selected_features_cont, compose_datasets):
    common_features_per_dataset = {}

    for dataset_key, compose_df in compose_datasets.items():
        # Extract the years available in the current compose dataset
        dataset_years = compose_df['Year'].unique()
        common_features = {'FR': [], 'RF': [], 'Lasso': []}

        for method in common_features.keys():
            # Collect features for the available years and the current method
            features_per_year = []
            for year in dataset_years:
                key = f"{method}_{year}"
                if key in selected_features_cont.get(dataset_key, {}):
                    features_per_year.append(set(selected_features_cont[dataset_key][key]))

            # Find the intersection of all feature sets for the current method
            if features_per_year:
                common_features[method] = list(set.intersection(*features_per_year))
                if not common_features[method]:  # Check if the intersection is empty
                    print(f"No common features found for {dataset_key} (method {method})")

        common_features_per_dataset[dataset_key] = common_features

    return common_features_per_dataset

# %% [markdown]
# ## 5.3. Application of Methods for Selection

# %%
doc.add_heading('Variance Threshold 0.05', 1)

# %%
# Applying the modified function in the loop
high_variance_features = {}
variance_threshold = 0.05

for year, dataset in datasets.items():
    print(f"Applying variance filter for dataset of year: {year}")

    # Call the select_by_variance method and get only the selected columns
    high_variance_features[str(year)] = select_by_variance(
        dataset,
        exclude_columns_less_restricted[str(year)],
        variance_threshold
    )

    print(f"Columns retained from {year} dataset based on variance threshold = {variance_threshold}:")
    print(high_variance_features[str(year)].tolist())

    missing_week1 = set(all_lists[str(year)]['weekly_and_participation_lists']['listWeek1']) - set(high_variance_features[str(year)])
    missing_week2 = set(all_lists[str(year)]['weekly_and_participation_lists']['listWeek2']) - set(high_variance_features[str(year)])
    print("-" * 50)
    print()
    print("----------------------------------------------------------------------")

print("-" * 50)
print()
print("----------------------------------------------------------------------")
print("Converted:")
converted_features = {}
for year in high_variance_features:
    converted_features[year] = convert_feature_ids_to_activity_names(high_variance_features[year], dataset_params)
    print(f"Converted features for year {year}: {converted_features[year]}")
# Out:
# Applying variance filter for dataset of year: 2016
# Variance Table
#    Feature  Variance
# 0       91  2.477985
# 1      129  2.251002
# 2      128  2.247608
# 3       30  2.100181
# 4      130  2.000701
# 5      127  1.871316
# 6      103  1.760783
# 7      102  1.604145
# 8       77  1.483133
# 9       88  1.437878
# 10      58  1.436170
# 11     101  1.429324
# 12      93  1.399207
# 13      97  1.397496
# 14    23_1  1.365687
# 15      11  1.257817
# 16      96  1.196216
# 17      72  1.082637
# 18      89  1.043503
# 19      87  1.041490
# 20    23_2  1.013609
# 21      86  1.010377
# 22      22  0.971728
# 23      31  0.923272
# 24      32  0.891707
# 25     125  0.874281
# 26      10  0.856720
# 27      34  0.826952
# 28      35  0.784875
# 29      38  0.573078
# 30      16  0.520366
# 31     106  0.303547
# 32     132  0.244888
# 33      54  0.234488
# 34     104  0.178995
# 35     131  0.176698
# 36      83  0.172945
# 37     105  0.166648
# 38      50  0.156476
# 39      53  0.145166
# 40      95  0.141816
# 41      94  0.130860
# 42      24  0.129082
# 43      20  0.121684
# 44      28  0.113751
# 45     124  0.102804
# 46      51  0.100828
# 47      23  0.095495
# 48       1  0.094147
# 49      52  0.094147
# 50       4  0.092927
# 51      12  0.092114
# 52      42  0.091434
# 53       3  0.088707
# 54     126  0.088009
# 55      25  0.081753
# 56      55  0.081753
# 57      56  0.081753
# 58      36  0.081050
# --------------------------------------------------
#
# Columns retained from 2016 dataset based on variance threshold = 0.05:
# ['91', '129', '128', '30', '130', '127', '103', '102', '77', '88', '58', '101', '93', '97', '23_1', '11', '96', '72', '89', '87', '23_2', '86', '22', '31', '32', '125', '10', '34', '35', '38', '16', '106', '132', '54', '104', '131', '83', '105', '50', '53', '95', '94', '24', '20', '28', '124', '51', '23', '1', '52', '4', '12', '42', '3', '126', '25', '55', '56', '36']
# --------------------------------------------------
#
# ----------------------------------------------------------------------
# Applying variance filter for dataset of year: 2017
# Variance Table
#    Feature  Variance
# 0       30  2.552924
# 1      128  2.347629
# 2      129  2.211461
# 3      127  2.146484
# 4       91  2.110457
# 5      103  2.092291
# 6      130  2.043438
# 7      102  1.577534
# 8       77  1.500407
# 9       93  1.477186
# 10      58  1.473714
# 11    23_1  1.443515
# 12     101  1.442681
# 13      88  1.442382
# 14      11  1.412886
# 15    72_1  1.411476
# 16      97  1.401849
# 17      72  1.378279
# 18      89  1.318377
# 19      22  1.307677
# 20      34  1.069830
# 21    23_2  1.048375
# 22      96  1.021192
# 23      31  1.011664
# 24      32  0.959960
# 25      86  0.958001
# 26     4_2  0.955710
# 27      87  0.946994
# 28     125  0.917853
# 29      35  0.861642
# 30      10  0.824417
# 31      38  0.610453
# 32      16  0.487121
# 33     106  0.323398
# 34      54  0.292281
# 35     132  0.239291
# 36     104  0.223368
# 37    94_1  0.218024
# 38     131  0.176649
# 39      50  0.172840
# 40      83  0.158746
# 41      94  0.151256
# 42      24  0.134211
# 43      95  0.129437
# 44      53  0.128228
# 45     126  0.117711
# 46      23  0.116445
# 47      52  0.113895
# 48      51  0.110025
# 49      20  0.108723
# 50     124  0.106759
# 51      42  0.101454
# 52      28  0.100113
# 53      55  0.099440
# 54      36  0.099440
# 55      56  0.098765
# 56      25  0.091939
# 57      12  0.089166
# 58       1  0.079270
# 59       4  0.077353
# --------------------------------------------------
#
# Columns retained from 2017 dataset based on variance threshold = 0.05:
# ['30', '128', '129', '127', '91', '103', '130', '102', '77', '93', '58', '23_1', '101', '88', '11', '72_1', '97', '72', '89', '22', '34', '23_2', '96', '31', '32', '86', '4_2', '87', '125', '35', '10', '38', '16', '106', '54', '132', '104', '94_1', '131', '50', '83', '94', '24', '95', '53', '126', '23', '52', '51', '20', '124', '42', '28', '55', '36', '56', '25', '12', '1', '4']
# --------------------------------------------------
#
# ----------------------------------------------------------------------
# Applying variance filter for dataset of year: 2018
# Variance Table
#    Feature  Variance
# 0       91  2.139140
# 1      129  2.009053
# 2      130  1.768904
# 3      102  1.575509
# 4      128  1.536992
# 5       77  1.493742
# 6       88  1.443181
# 7       58  1.429949
# 8       93  1.425741
# 9      101  1.408838
# 10    72_1  1.406561
# 11      97  1.400572
# 12    23_1  1.347658
# 13      30  1.330431
# 14      22  1.318052
# 15      11  1.258950
# 16     103  1.212555
# 17     127  1.168792
# 18    23_2  1.075760
# 19      72  0.967400
# 20      96  0.955337
# 21     4_2  0.949175
# 22      86  0.932204
# 23      87  0.908332
# 24      89  0.850682
# 25      32  0.655395
# 26      34  0.637107
# 27      31  0.627845
# 28      35  0.625294
# 29      10  0.495063
# 30      38  0.490891
# 31      16  0.447072
# 32      54  0.278949
# 33     132  0.262973
# 34     104  0.213365
# 35     106  0.163368
# 36    94_1  0.157815
# 37      83  0.152803
# 38      94  0.139312
# 39     131  0.117978
# 40      95  0.109290
# 41      50  0.105875
# 42     126  0.096095
# 43      20  0.088185
# 44      18  0.085993
# 45      24  0.085260
# 46      53  0.084524
# 47      23  0.075571
# 48      25  0.073296
# 49      28  0.070239
# 50      42  0.069471
# 51       4  0.063742
# 52     124  0.059335
# 53      52  0.058544
# 54      36  0.056161
# 55      55  0.056161
# 56      56  0.056161
# 57      51  0.054564
# 58       3  0.052960
# --------------------------------------------------
#
# Columns retained from 2018 dataset based on variance threshold = 0.05:
# ['91', '129', '130', '102', '128', '77', '88', '58', '93', '101', '72_1', '97', '23_1', '30', '22', '11', '103', '127', '23_2', '72', '96', '4_2', '86', '87', '89', '32', '34', '31', '35', '10', '38', '16', '54', '132', '104', '106', '94_1', '83', '94', '131', '95', '50', '126', '20', '18', '24', '53', '23', '25', '28', '42', '4', '124', '52', '36', '55', '56', '51', '3']
# --------------------------------------------------
#
# ----------------------------------------------------------------------
# Applying variance filter for dataset of year: 2019
# Variance Table
#    Feature  Variance
# 0      127  2.270731
# 1      129  2.241220
# 2       91  1.942691
# 3       30  1.914961
# 4      128  1.846433
# 5      130  1.630355
# 6      102  1.592881
# 7       77  1.543541
# 8       22  1.461858
# 9       93  1.432748
# 10      58  1.388774
# 11      97  1.382215
# 12      23  1.379595
# 13      88  1.368661
# 14    72_1  1.367809
# 15      72  1.339224
# 16     101  1.332292
# 17     103  1.315518
# 18      11  1.282805
# 19      89  1.073333
# 20      96  0.994177
# 21    23_1  0.955436
# 22      35  0.900869
# 23     4_2  0.888422
# 24      86  0.875542
# 25      87  0.865384
# 26      32  0.809096
# 27      31  0.797928
# 28      34  0.763625
# 29      38  0.633112
# 30      10  0.577863
# 31      16  0.471952
# 32     132  0.260138
# 33      54  0.255568
# 34     106  0.244855
# 35     104  0.227429
# 36    94_1  0.157711
# 37      94  0.153635
# 38      83  0.144606
# 39     131  0.136453
# 40      50  0.123318
# 41      95  0.123318
# 42     126  0.103721
# 43      52  0.099338
# 44     1_8  0.097123
# 45      18  0.096381
# 46      24  0.096381
# 47      25  0.095637
# 48     125  0.088099
# 49      42  0.086569
# 50      20  0.083490
# 51     124  0.081939
# 52      51  0.080381
# 53       4  0.078812
# 54      53  0.073281
# 55      28  0.070883
# 56      36  0.070079
# 57      56  0.069274
# 58      55  0.068467
# 59       1  0.057815
# --------------------------------------------------
#
# Columns retained from 2019 dataset based on variance threshold = 0.05:
# ['127', '129', '91', '30', '128', '130', '102', '77', '22', '93', '58', '97', '23', '88', '72_1', '72', '101', '103', '11', '89', '96', '23_1', '35', '4_2', '86', '87', '32', '31', '34', '38', '10', '16', '132', '54', '106', '104', '94_1', '94', '83', '131', '50', '95', '126', '52', '1_8', '18', '24', '25', '125', '42', '20', '124', '51', '4', '53', '28', '36', '56', '55', '1']
# --------------------------------------------------
#
# ----------------------------------------------------------------------
# Applying variance filter for dataset of year: 2022
# Variance Table
#    Feature  Variance
# 0      117  2.352126
# 1      119  2.347377
# 2      116  2.182651
# 3      134  2.099784
# 4      114  2.070312
# 5       73  2.039508
# 6       15  2.035612
# 7      138  2.026875
# 8       43  1.982969
# 9       11  1.977339
# 10     120  1.822135
# 11      75  0.988495
# 12      30  0.978469
# 13     118  0.967885
# 14      32  0.965205
# 15      64  0.962399
# 16     108  0.951796
# 17     111  0.932890
# 18      34  0.883502
# 19     110  0.870993
# 20      71  0.864736
# 21      31  0.850867
# 22     109  0.824855
# 23      10  0.797296
# 24     112  0.796263
# 25      35  0.789233
# 26      38  0.727137
# 27    2_11  0.186756
# 28     142  0.138039
# 29     122  0.133452
# 30      33  0.132872
# 31      27  0.128773
# 32      49  0.122795
# 33     115  0.118525
# 34      70  0.105935
# 35      45  0.103348
# 36      29  0.098765
# 37     140  0.097443
# 38     139  0.094112
# 39     144  0.092097
# 40      37  0.091422
# 41      25  0.091422
# 42      69  0.091422
# 43      63  0.090746
# 44     133  0.088026
# 45      36  0.088026
# 46      23  0.088026
# 47      50  0.088026
# 48      42  0.087343
# 49      66  0.087343
# 50      20  0.085284
# 51       1  0.083904
# 52      44  0.082518
# 53     113  0.079730
# 54      19  0.077624
# 55      46  0.077624
# 56     137  0.076919
# 57     135  0.076212
# 58      12  0.068346
# 59      72  0.068346
# --------------------------------------------------
#
# Columns retained from 2022 dataset based on variance threshold = 0.05:
# ['117', '119', '116', '134', '114', '73', '15', '138', '43', '11', '120', '75', '30', '118', '32', '64', '108', '111', '34', '110', '71', '31', '109', '10', '112', '35', '38', '2_11', '142', '122', '33', '27', '49', '115', '70', '45', '29', '140', '139', '144', '37', '25', '69', '63', '133', '36', '23', '50', '42', '66', '20', '1', '44', '113', '19', '46', '137', '135', '12', '72']
# --------------------------------------------------
#
# ----------------------------------------------------------------------
# Applying variance filter for dataset of year: 2023
# Variance Table
#    Feature  Variance
# 0       76  5.060639
# 1       77  4.989444
# 2      119  2.924073
# 3      114  2.207277
# 4      116  2.068935
# ..     ...       ...
# 62     115  0.075323
# 63      72  0.074568
# 64      61  0.073812
# 65      63  0.069241
# 66      28  0.063834
#
# [67 rows x 2 columns]
# --------------------------------------------------
#
# Columns retained from 2023 dataset based on variance threshold = 0.05:
# ['76', '77', '119', '114', '116', '117', '15', '11', '122', '43', '146', '65', '41', '113', '73', '64', '111', '30', '112', '118', '32', '110', '10', '75', '46', '35', '108', '71', '34', '62', '31', '38', '122_1', '74', '59', '49', '1', '39', '147', '82', '120', '25', '33', '7', '60', '109', '66', '29', '50', '19', '1_11', '20', '18', '37', '12', '42', '68', '36', '70', '69', '44', '45', '115', '72', '61', '63', '28']
# --------------------------------------------------
#
# ----------------------------------------------------------------------
# Applying variance filter for dataset of year: 2024
# Variance Table
#    Feature  Variance
# 0       76  5.027396
# 1       77  4.837388
# 2      117  3.106913
# 3      116  2.991774
# 4      119  2.802597
# ..     ...       ...
# 63      45  0.072339
# 64      42  0.070076
# 65      65  0.063200
# 66      28  0.056196
# 67      12  0.052249
#
# [68 rows x 2 columns]
# --------------------------------------------------
#
# Columns retained from 2024 dataset based on variance threshold = 0.05:
# ['76', '77', '117', '116', '119', '114', '120', '15', '11', '111', '110', '112', '108', '78', '64', '75', '30', '32', '73', '62', '43', '46', '71', '118', '31', '10', '113', '35', '34', '38', '74', '123', '82', '122', '59', '1', '2', '49', '60', '115', '9', '33', '109', '50', '19', '66', '61', '63', '41', '44', '8', '29', '72', '68', '20', '70', '18', '37', '39', '5', '69', '7', '36', '45', '42', '65', '28', '12']
# --------------------------------------------------
#
# ----------------------------------------------------------------------
# --------------------------------------------------
#
# ----------------------------------------------------------------------
# Converted:
# Converted features for year 2016: ['Evaluation of synthesis groups A vs A', 'Individual Test: VB Function', 'School Planning', 'SMART goals', 'Moodle test Excel', 'List of Insured Persons', 'Group evaluation of the presentation given by Spokespersons', 'Presentation of Oral Communication', 'Communication using audiovisual media - Posters', 'Structure of a report (Spokesperson)', 'Leadership Paradigms (Spokesperson)', 'Newscast Presentation', 'Student Behavior: Ethics (Spokesperson)', 'Manuscript Summary / Oral Communication', '23_1', 'Presentation on the analyzed CVs', 'Portuguese Manuscript Summary', 'Ethical dilemmas', 'Search at B-on complementary Famelab', 'Structure of a report', '23_2', 'Summary correction', 'Assessment of the week gathering', "Maria's dashboard", 'Submission of CV on Moodle', 'Homework: clothes/colours', 'Analysis of 3 CVs of candidates', 'Wolis', '4x100m freestyle', 'Parking', 'Interview with volunteers (2 students)', 'Global evaluation of the discipline (oral)', 'Week b review', 'Assessment of the week Gathering', 'Assessment of the week (5th week)', 'Evaluation of the week', 'Researches Privacy on social media', 'Global evaluation of the discipline (written)', 'Assessment of the week', 'Email and Social Media Management', 'Draw figures = What is the message? (66)', 'Moodle Questionnaire', 'Submission of CV on Moodle 2', 'Assessment of the week', 'Procrastination vs. Perfectionism on Moodle', 'Excel Exercises 1 to 5', 'SMART goals (evaluate other group)', 'Bloco Livre', 'Submission of CV on Moodle', 'Introduction to Google Calendar', 'Online interview', 'Psychotechnical test (Moodle)', 'Leading is ...', 'Expectations regarding CTCT', 'Programming f(x, y)', 'Submission of short CV & Cover Letter', 'Forced landing (group) - column 3', 'Forced landing (group) - columns 5, 2 and 4', 'Forced landing - individual']
# Converted features for year 2017: ['SMART goals', 'School Planning', 'Individual Test: VB Function', 'List of Insured Persons', 'Evaluation of synthesis groups A vs A', 'Group evaluation of the presentation given by Spokespersons', 'Moodle test Excel', 'Presentation of Oral Communication', 'Communication using audiovisual media - Posters', 'Student Behavior: Ethics (Spokesperson)', 'Leadership Paradigms (Spokesperson)', '23_1', 'Newscast Presentation', 'Structure of a report (Spokesperson)', 'Presentation on the analyzed CVs', '72_1', 'Manuscript Summary / Oral Communication', 'Ethical dilemmas', 'Search at B-on complementary Famelab', 'Assessment of the week gathering', 'Wolis', '23_2', 'Portuguese Manuscript Summary', "Maria's dashboard", 'Submission of CV on Moodle', 'Summary correction', '4_2', 'Structure of a report', 'Homework: clothes/colours', '4x100m freestyle', 'Analysis of 3 CVs of candidates', 'Parking', 'Interview with volunteers (2 students)', 'Global evaluation of the discipline (oral)', 'Assessment of the week Gathering', 'Week b review', 'Assessment of the week (5th week)', '94_1', 'Evaluation of the week', 'Assessment of the week', 'Researches Privacy on social media', 'Moodle Questionnaire', 'Submission of CV on Moodle 2', 'Draw figures = What is the message? (66)', 'Email and Social Media Management', 'Programming f(x, y)', 'Bloco Livre', 'Introduction to Google Calendar', 'SMART goals (evaluate other group)', 'Assessment of the week', 'Excel Exercises 1 to 5', 'Leading is ...', 'Procrastination vs. Perfectionism on Moodle', 'Forced landing (group) - column 3', 'Forced landing - individual', 'Forced landing (group) - columns 5, 2 and 4', 'Submission of short CV & Cover Letter', 'Psychotechnical test (Moodle)', 'Submission of CV on Moodle', 'Online interview']
# Converted features for year 2018: ['Evaluation of synthesis groups A vs A', 'Individual Test: VB Function', 'Moodle test Excel', 'Presentation of Oral Communication', 'School Planning', 'Communication using audiovisual media - Posters', 'Structure of a report (Spokesperson)', 'Leadership Paradigms (Spokesperson)', 'Student Behavior: Ethics (Spokesperson)', 'Newscast Presentation', '72_1', 'Manuscript Summary / Oral Communication', '23_1', 'SMART goals', 'Assessment of the week gathering', 'Presentation on the analyzed CVs', 'Group evaluation of the presentation given by Spokespersons', 'List of Insured Persons', '23_2', 'Ethical dilemmas', 'Portuguese Manuscript Summary', '4_2', 'Summary correction', 'Structure of a report', 'Search at B-on complementary Famelab', 'Submission of CV on Moodle', 'Wolis', "Maria's dashboard", '4x100m freestyle', 'Analysis of 3 CVs of candidates', 'Parking', 'Interview with volunteers (2 students)', 'Assessment of the week Gathering', 'Week b review', 'Assessment of the week (5th week)', 'Global evaluation of the discipline (oral)', '94_1', 'Researches Privacy on social media', 'Moodle Questionnaire', 'Evaluation of the week', 'Draw figures = What is the message? (66)', 'Assessment of the week', 'Programming f(x, y)', 'Assessment of the week', 'Quizz: Is it worth going on Erasmus/Erasmus+?', 'Submission of CV on Moodle 2', 'Email and Social Media Management', 'Bloco Livre', 'Submission of short CV & Cover Letter', 'Procrastination vs. Perfectionism on Moodle', 'Leading is ...', 'Online interview', 'Excel Exercises 1 to 5', 'Introduction to Google Calendar', 'Forced landing - individual', 'Forced landing (group) - column 3', 'Forced landing (group) - columns 5, 2 and 4', 'SMART goals (evaluate other group)', 'Expectations regarding CTCT']
# Converted features for year 2019: ['List of Insured Persons', 'Individual Test: VB Function', 'Evaluation of synthesis groups A vs A', 'SMART goals', 'School Planning', 'Moodle test Excel', 'Presentation of Oral Communication', 'Communication using audiovisual media - Posters', 'Assessment of the week gathering', 'Student Behavior: Ethics (Spokesperson)', 'Leadership Paradigms (Spokesperson)', 'Manuscript Summary / Oral Communication', 'Bloco Livre', 'Structure of a report (Spokesperson)', '72_1', 'Ethical dilemmas', 'Newscast Presentation', 'Group evaluation of the presentation given by Spokespersons', 'Presentation on the analyzed CVs', 'Search at B-on complementary Famelab', 'Portuguese Manuscript Summary', '23_1', '4x100m freestyle', '4_2', 'Summary correction', 'Structure of a report', 'Submission of CV on Moodle', "Maria's dashboard", 'Wolis', 'Parking', 'Analysis of 3 CVs of candidates', 'Interview with volunteers (2 students)', 'Week b review', 'Assessment of the week Gathering', 'Global evaluation of the discipline (oral)', 'Assessment of the week (5th week)', '94_1', 'Moodle Questionnaire', 'Researches Privacy on social media', 'Evaluation of the week', 'Assessment of the week', 'Draw figures = What is the message? (66)', 'Programming f(x, y)', 'Introduction to Google Calendar', '1_8', 'Quizz: Is it worth going on Erasmus/Erasmus+?', 'Submission of CV on Moodle 2', 'Submission of short CV & Cover Letter', 'Homework: clothes/colours', 'Leading is ...', 'Assessment of the week', 'Excel Exercises 1 to 5', 'SMART goals (evaluate other group)', 'Online interview', 'Email and Social Media Management', 'Procrastination vs. Perfectionism on Moodle', 'Forced landing - individual', 'Forced landing (group) - columns 5, 2 and 4', 'Forced landing (group) - column 3', 'Submission of CV on Moodle']
# Converted features for year 2022: ['ID_117_Not_Found', 'ID_119_Not_Found', 'ID_116_Not_Found', 'ID_134_Not_Found', 'ID_114_Not_Found', 'ID_73_Not_Found', 'ID_15_Not_Found', 'ID_138_Not_Found', 'ID_43_Not_Found', 'Presentation on the analyzed CVs', 'ID_120_Not_Found', 'ID_75_Not_Found', 'SMART goals', 'ID_118_Not_Found', 'Submission of CV on Moodle', 'ID_64_Not_Found', 'ID_108_Not_Found', 'ID_111_Not_Found', 'Wolis', 'ID_110_Not_Found', 'ID_71_Not_Found', "Maria's dashboard", 'ID_109_Not_Found', 'Analysis of 3 CVs of candidates', 'ID_112_Not_Found', '4x100m freestyle', 'Parking', '2_11', 'ID_142_Not_Found', 'ID_122_Not_Found', 'ID_33_
Found', 'ID_46_Not_Found', 'ID_71_Not_Found', 'ID_118_Not_Found', "Maria's dashboard", 'Analysis of 3 CVs of candidates', 'ID_113_Not_Found', '4x100m freestyle', 'Wolis', 'Parking', 'ID_74_Not_Found', 'ID_123_Not_Found', 'ID_82_Not_Found', 'ID_122_Not_Found', 'ID_59_Not_Found', 'Submission of CV on Moodle', 'ID_2_Not_Found', 'ID_49_Not_Found', 'ID_60_Not_Found', 'ID_115_Not_Found', 'ID_9_Not_Found', 'ID_33_Not_Found', 'ID_109_Not_Found', 'Assessment of the week', 'ID_19_Not_Found', 'ID_66_Not_Found', 'ID_61_Not_Found', 'ID_63_Not_Found', 'ID_41_Not_Found', 'ID_44_Not_Found', 'ID_8_Not_Found', 'ID_29_Not_Found', 'Ethical dilemmas', 'ID_68_Not_Found', 'Assessment of the week', 'ID_70_Not_Found', 'Quizz: Is it worth going on Erasmus/Erasmus+?', 'ID_37_Not_Found', 'ID_39_Not_Found', 'ID_5_Not_Found', 'ID_69_Not_Found', 'ID_7_Not_Found', 'Forced landing - individual', 'ID_45_Not_Found', 'Leading is ...', 'ID_65_Not_Found', 'Procrastination vs. Perfectionism on Moodle', 'Psychotechnical test (Moodle)']

# %%
get_activity_name_by_id(117, dataset_params, 2022)
# Out:
# 'Purchase of computer equipment (Solver)'

# %%
get_activity_name_by_id(76, dataset_params, 2023)
# Out:
# 'Communication using audiovisual media - Slides'

# %% [markdown]
# ### 5.3.1. For predicting if a student pass or fail
# Feature selection on datasets dictionary of dataframes, one per each year (preprocessed original dataframes).

# %%
doc.add_heading('Predicting Passed', 2)

# %%
exclusion_type = 'more_restricted'
exclude_columns = exclusion_columns_dicts[exclusion_type]
target_column = 'Passed'

selected_features_predict_passed_more_restricted = feature_selection_analysis(datasets, all_lists, dataset_params, target_column, exclude_columns, methods=['MI', 'RF', 'DT'])
#save_selected_features_to_feather(selected_features_predict_passed_more_restricted, datasets, target_column, output_dir, "predict_passed", exclusion_type)
# Out:
# Feature Selection Analysis for the dataset of year: 2016 with target column: Passed
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2017 with target column: Passed
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2018 with target column: Passed
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2019 with target column: Passed
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2022 with target column: Passed
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2023 with target column: Passed
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2024 with target column: Passed
# --------------------------------------------------

# %%
doc.add_heading('More restricted Results', 3)

# %%
print("Selected Features:")
print(selected_features_predict_passed_more_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names(selected_features_predict_passed_more_restricted, dataset_params)
print(converted_features)
# Out:
# Selected Features:
# {2016: {'MI': ['1', '3', '24', '12', '20', '25', '10', '23', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34'], 'RF': ['24', '12', '20', '22', '25', '10', '11', '23', '32', '38', '42', '23_1', '35', '50', '30', '51', '31', '28', '53', '36', '55', '56', '34'], 'DT': ['12', '20', '25', '10', '11', '23', '32', '42', '23_1', '23_2', '50', '30', '51', '31', '53', '34']}, 2017: {'MI': ['1', '24', '12', '20', '25', '10', '23', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '94_1'], 'RF': ['1', '12', '20', '25', '10', '23', '32', '38', '42', '35', '58', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '94_1'], 'DT': ['1', '20', '10', '11', '38', '23_1', '35', '58', '23_2', '50', '30', '31', '52', '28', '56', '94_1']}, 2018: {'MI': ['1', '24', '12', '20', '25', '10', '11', '23', '18', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '55', '56', '34', '94_1'], 'RF': ['1', '24', '12', '25', '10', '18', '32', '38', '42', '23_1', '35', '58', '50', '30', '51', '31', '53', '36', '55', '56', '34', '94_1'], 'DT': ['1', '24', '25', '23_1', '35', '58', '52', '34', '94_1']}, 2019: {'MI': ['1', '18', '24', '20', '25', '10', '12', '1_8', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '94_1', '72_1'], 'RF': ['1', '20', '25', '10', '12', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '55', '56', '34', '94_1'], 'DT': ['1', '20', '10', '12', '38', '35', '50', '51', '28', '55']}, 2022: {'MI': ['1', '23', '133', '135', '19', '137', '32', '144', '139', '140', '20', '25', '10', '12', '27', '29', '35', '45', '46', '69', '70', '71', '72', '49', '30', '75', '66', '63', '64', '50', '
'4_2', '86', '87', '89', '91', '72', '95', '104', '96', '77', '103', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_2', 'PP5_1', 'PP5_3', 'PTP1', 'PTP2', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_PP', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP'], 'RF': ['FinalGradeInteger', 'FinalGrade', 'Week5_AP'], 'DT': ['FinalGrade']}, 2019: {'MI': ['1', '24', '20', '25', '10', '12', '1_8', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '124', '125', '126', '127', '128', '129', '130', '131', '83', '94', '94_1', '4_2', '86', '87', '89', '91', '93', '72', '95', '96', '103', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_1', 'PP4_2', 'PP4_3', 'PP5_1', 'PP5_2', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_PP', 'Total_SPA', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP'], 'RF': ['SPA3', 'FinalGradeInteger', 'FinalGrade', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week3_PP'], 'DT': ['FinalGrade']}, 2022: {'MI': ['1', '23', '133', '135', '19', '137', '32', '144', '139', '140', '20', '25', '10', '12', '27', '29', '35', '45', '46', '69', '70', '71', '72', '49', '30', '75', '66', '63', '64', '50', '31', '33', '36', '37', '34', '38', '44', '42', '108', '117', '118', '142', '119', '120', '122', '109', '110', '111', '112', '113', '114', '115', '116', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP1_4', 'PP2_1', 'PP2_2', 'PP2_3', 'PP2_4', 'PP3_1', 'PP3_2', 'PP3_3', 'PP3_4', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_PP', 'Total_SPA', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP'], 'RF': ['FinalGradeInteger', 'FinalGrade', 'Week3_AP'], 'DT': ['FinalGradeInteger']}, 2023: {'MI': ['1_11', '18', '19', '20', '7', '25', '10', '12', '28', '29', '39', '49', '41', '42', '43', '44', '45', '46', '50', '30', '31', '147', '32', '33', '34', '35', '36', '37', '38', '59', '60', '61', '69', '70', '71', '72', '73', '74', '75', '82', '62', '146', '63', '64', '65' ...
# Converted:
# {2016: {'MI': ['Submission of CV on Moodle', 'Submission of CV on Moodle 2', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Submission of short CV & Cover Letter', 'Analysis of 3 CVs of candidates', 'Bloco Livre', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'SMART goals', 'SMART goals (evaluate other group)', "Maria's dashboard", 'Introduction to Google Calendar', 'Procrastination vs. Perfectionism on Moodle', 'Email and Social Media Management', 'Forced landing - individual', 'Forced landing (group) - column 3', 'Forced landing (group) - columns 5, 2 and 4', 'Wolis', 'Excel Exercises 1 to 5', 'Homework: clothes/colours', 'Programming f(x, y)', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Evaluation of the week', 'Researches Privacy on social media', 'Moodle Questionnaire', 'Summary correction', 'Structure of a report', 'Search at B-on complementary Famelab', 'Evaluation of synthesis groups A vs A', 'Ethical dilemmas', 'Draw figures = What is the message? (66)', 'Global evaluation of the discipline (written)', 'Group evaluation of the presentation given by Spokespersons', 'Portuguese Manuscript Summary', 'Assessment of the week (5th week)', 'SPA1', 'SPA2', 'SPA3', 'BonCoord', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_1', 'PP4_2', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_PP', 'Total_SPA', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP'], 'RF': ['FinalGradeInteger', 'FinalGrade'], 'DT': ['FinalGrade']}, 2017: {'MI': ['Submission of CV on Moodle', 'Submission of CV on Moodle 2', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Submission of short CV & Cover Letter', 'Analysis of 3 CVs of candidates', 'Bloco Livre', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', 'SMART goals (evaluate other group)', "Maria's dashboard", 'Introduction to Google Calendar', 'Procrastination vs. Perfectionism on Moodle', 'Email and Social Media Management', 'Forced landing - individual', 'Forced landing (group) - column 3', 'Forced landing (group) - columns 5, 2 and 4', 'Wolis', 'Excel Exercises 1 to 5', 'Homework: clothes/colours', 'Programming f(x, y)', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Evaluation of the week', 'Researches Privacy on social media', 'Assessment of the Week', '94_1', '4_2', 'Summary correction', 'Structure of a report', 'Evaluation of synthesis groups A vs A', 'Ethical dilemmas', 'Draw figures = What is the message? (66)', 'Assessment of the week (5th week)', 'Portuguese Manuscript Summary', 'Group evaluation of the presentation given by Spokespersons', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_1', 'PP4_2', 'PP4_3', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_PP', 'Total_SPA', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP'], 'RF': ['Submission of CV on Moodle', 'FinalGradeInteger', 'FinalGrade', 'Week1_AP'], 'DT': ['FinalGradeInteger', 'Week1_AP']}, 2018: {'MI': ['Submission of CV on Moodle', 'Submission of CV on Moodle 2', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Assessment of the week gathering', 'Online interview', 'Submission of short CV & Cover Letter', 'Analysis of 3 CVs of candidates', 'Bloco Livre', 'Quizz: Is it worth going on Erasmus/Erasmus+?', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Leadership Paradigms (Spokesperson)', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Introduction to Google Calendar', 'Proc ...

# %%
print(extract_common_features(selected_features_predict_passed_less_restricted))
# Out:
# {'MI': ['Week1_AP', 'SPA2', '35', 'Total_PP', 'SPA3', 'Week3_PP', 'FinalGrade', '42', '72', 'Week1_PP', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', 'Week3_AP', '31', 'Week2_PP', 'PP2_3', 'Week2_AP', '10', 'PTP1', 'SPA1', '20', '32', '38', 'PP1_3', '34', 'PP2_2', '12', '30'], 'RF': ['FinalGradeInteger', 'FinalGrade'], 'DT': []}

# %% [markdown]
# ### 5.3.2. For predicting *FinalGrade* from students that passed
# Feature selection on datasets dictionary of dataframes, one per each year (preprocessed original dataframes).

# %%
doc.add_heading('Predicting FinalGrade from students that passed', 2)

# %%
print("More Restricted Results")
print("----------------------------------------------------------------------")
selected_features_finalgrade_more_restricted = feature_selection_for_regression(
    filtered_datasets, # using only students that passed CTCT
    target_column='FinalGrade',
    exclude_columns=aggregated_exclude_columns['more_restricted'],
    methods=['FR', 'RF', 'Lasso']
)

print("Restricted Results")
print("----------------------------------------------------------------------")
selected_features_finalgrade_restricted = feature_selection_for_regression(
    filtered_datasets, # using only students that passed CTCT
    target_column='FinalGrade',
    exclude_columns=aggregated_exclude_columns['restricted'],
    methods=['FR', 'RF', 'Lasso']
)

print("Less Restricted Results")
print("----------------------------------------------------------------------")
selected_features_finalgrade_less_restricted = feature_selection_for_regression(
    filtered_datasets, # using only students that passed CTCT
    target_column='FinalGrade',
    exclude_columns=aggregated_exclude_columns['less_restricted'],
    methods=['FR', 'RF', 'Lasso']
)
# Out:
# More Restricted Results
# ----------------------------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2016 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2017 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2018 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2019 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2022 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2023 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2024 with target column: FinalGrade
# --------------------------------------------------
# Restricted Results
# ----------------------------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2016 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2017 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2018 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2019 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2022 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2023 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2024 with target column: FinalGrade
# --------------------------------------------------
# Less Restricted Results
# ----------------------------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2016 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2017 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2018 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2019 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2022 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2023 with target column: FinalGrade
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2024 with target column: FinalGrade
# --------------------------------------------------

# %%
print("Selected features for predicting FinalGrade:")
print("------------------ More restricted set")
print(selected_features_finalgrade_more_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names(selected_features_finalgrade_more_restricted, dataset_params)
print(converted_features)
print("------------------ Restricted set")
print(selected_features_finalgrade_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names(selected_features_finalgrade_restricted, dataset_params)
print(converted_features)
print("------------------ Less restricted set")
print(selected_features_finalgrade_less_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names(selected_features_finalgrade_less_restricted, dataset_params)
print(converted_features)
# Out:
# Selected features for predicting FinalGrade:
# ------------------ More restricted set
# {2016: {'FR': ['1', '24', '12', '20', '25', '10', '23', '32', '38', '42', '35', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34'], 'RF': ['1', '24', '12', '20', '22', '25', '10', '11', '16', '23', '32', '38', '23_1', '35', '58', '23_2', '50', '30', '31', '52', '28', '53', '34'], 'Lasso': ['1', '3', '24', '22', '4', '25', '10', '11', '16', '23', '32', '38', '42', '23_1', '35', '58', '23_2', '50', '54', '30', '31', '52', '28', '53', '36', '56', '34']}, 2017: {'FR': ['1', '24', '12', '20', '25', '23', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '94_1'], 'RF': ['24', '12', '20', '22', '25', '10', '11', '23', '32', '38', '23_1', '35', '58', '23_2', '50', '30', '31', '52', '36', '55', '56', '34', '94_1', '72_1'], 'Lasso': ['24', '12', '20', '22', '25', '10', '11', '16', '23', '32', '38', '23_1', '35', '58', '23_2', '50', '54', '30', '31', '52', '53', '36', '55', '34', '94_1', '72_1']}, 2018: {'FR': ['1', '24', '12', '20', '10', '23', '18', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '94_1'], 'RF': ['24', '22', '25', '10', '11', '16', '23', '18', '32', '38', '23_1', '35', '58', '23_2', '50', '30', '31', '52', '28', '34', '94_1', '72_1'], 'Lasso': ['1', '3', '24', '20', '22', '25', '10', '11', '16', '23', '18', '32', '38', '42', '23_1', '58', '23_2', '50', '54', '30', '31', '52', '28', '53', '34', '94_1', '72_1']}, 2019: {'FR': ['1', '18', '24', '20', '25', '1_8', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '94_1'], 'RF': ['1', '18', '24', '22', '25', '10', '11', '1_8', '32', '38', '42', '23', '35', '58', '23_1', '50', '30', '31', '52', '34', '94_1', '72_1'], 'Lasso': ['1', '18', '24', '22', '4', '25', '10', '11', '16', '1_8', '32', '38', '42', '23', '35', '58', '23_1', '50', '54', '30', '31', '52', '28', '53', '34', '94_1', '72_1']}, 2022: {'FR': ['23', '133', '135', '19', '137', '32', '144', '139', '140', '20', '25', '10', '12', '27', '29', '35', '45', '46', '49', '30', '50', '31', '33', '36', '37', '34', '38', '44', '42'], 'RF': ['1', '23', '134', '135', '19', '137', '138', '32', '144', '139', '140', '20', '25', '10', '11', '12', '15', '27', '29', '2_11', '35', '45', '46', '49', '30', '50', '31', '33', '36', '37', '34', '38', '44', '42', '43'], 'Lasso': ['1', '23', '133', '134', '135', '19', '138', '32', '144', '139', '140', '25', '10', '11', '12', '15', '27', '29', '35', '45', '46', '49', '30', '50', '31', '33', '37', '34', '38', '44', '42', '43']}, 2023: {'FR': ['1', '7', '25', '12', '29', '49', '41', '42', '43', '44', '45', '46', '50', '30', '31',
['Submission of CV on Moodle', 'Submission of CV on Moodle 2', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Submission of short CV & Cover Letter', 'Bloco Livre', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'Assessment of the week', 'SMART goals', 'SMART goals (evaluate other group)', "Maria's dashboard", 'Introduction to Google Calendar', 'Procrastination vs. Perfectionism on Moodle', 'Email and Social Media Management', 'Forced landing - individ ...

# %%
print(extract_common_features_continuous(selected_features_finalgrade_more_restricted))
print(extract_common_features_continuous(selected_features_finalgrade_restricted))
print(extract_common_features_continuous(selected_features_finalgrade_less_restricted))
# Out:
# {'FR': ['34', '31', '42', '35', '30', '32', '36'], 'RF': ['38', '34', '31', '11', '35', '10', '30', '50', '32'], 'Lasso': ['38', '34', '31', '10', '11', '30', '50', '32']}
# {'FR': ['31', '34', '42', '72', '35', '30', '32', '36'], 'RF': ['38', '31', '34', '10', '35', '30', '50', '32'], 'Lasso': ['38', '31', '34', '32', '11', '35', '10', '50', '30']}
# {'FR': ['Week1_AP', 'SPA2', 'Total_PP', 'SPA3', 'Week3_PP', '72', 'PP3_1', 'PP2_1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', 'Week3_AP', '31', 'Week2_PP', 'Week2_AP', 'SPA1', '32', 'Total_SPA', '34', 'PP2_2', '30'], 'RF': ['PTP2', 'Bon', 'SPA2', 'Week1_AP', '11', '35', 'Total_PP', 'SPA3', 'Week3_PP', 'Week1_PP', 'PP3_1', 'PP1_2', 'Total_AP', 'FinalGradeInteger', 'Week3_AP', '31', 'Week2_PP', 'Week2_AP', '10', 'SPA1', '32', '38', 'PTP3', 'Total_SPA', '34', '30'], 'Lasso': ['FinalGradeInteger', 'Week3_AP', 'Week1_AP', 'Week2_AP', 'Total_PP']}

# %% [markdown]
# ### 5.3.3. For predicting *Total_AP*
# Feature selection on datasets dictionary of dataframes, one per each year (preprocessed original dataframes).

# %%
print("More Restricted Results")
print("----------------------------------------------------------------------")

# For Total_AP
target_column = 'Total_AP'
selected_features_total_ap_regression_more_restricted = feature_selection_for_regression(
    datasets,
    target_column=target_column,
    exclude_columns=aggregated_exclude_columns['more_restricted'],
    methods=['FR', 'RF', 'Lasso']
)

# For Total_PP
target_column = 'Total_PP'
selected_features_total_pp_regression_more_restricted = feature_selection_for_regression(
    datasets,
    target_column=target_column,
    exclude_columns=aggregated_exclude_columns['more_restricted'],
    methods=['FR', 'RF', 'Lasso']
)

# For Total_SPA
target_column = 'Total_SPA'
selected_features_total_spa_regression_more_restricted = feature_selection_for_regression(
    datasets,
    target_column=target_column,
    exclude_columns=aggregated_exclude_columns['more_restricted'],
    methods=['FR', 'RF', 'Lasso']
)
# Out:
# More Restricted Results
# ----------------------------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2016 with target column: Total_AP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2017 with target column: Total_AP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2018 with target column: Total_AP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2019 with target column: Total_AP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2022 with target column: Total_AP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2023 with target column: Total_AP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2024 with target column: Total_AP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2016 with target column: Total_PP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2017 with target column: Total_PP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2018 with target column: Total_PP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2019 with target column: Total_PP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2022 with target column: Total_PP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2023 with target column: Total_PP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2024 with target column: Total_PP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2016 with target column: Total_SPA
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2017 with target column: Total_SPA
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2018 with target column: Total_SPA
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2019 with target column: Total_SPA
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2022 with target column: Total_SPA
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2023 with target column: Total_SPA
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2024 with target column: Total_SPA
# --------------------------------------------------

# %%
# Combine features across all years for each method
combined_features_total_ap_regression_more_restricted = combine_selected_features(selected_features_total_ap_regression_more_restricted)
combined_features_total_pp_regression_more_restricted = combine_selected_features(selected_features_total_pp_regression_more_restricted)
combined_features_total_spa_regression_more_restricted = combine_selected_features(selected_features_total_spa_regression_more_restricted)

# %%
print("Selected features for predicting Total_AP:")
print(selected_features_total_ap_regression_more_restricted)
print("Combined features for predicting Total_AP:")
print(combined_features_total_ap_regression_more_restricted)
# Out:
# Selected features for predicting Total_AP:
# {2016: {'FR': ['1', '24', '12', '20', '25', '10', '23', '32', '38', '42', '35', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34'], 'RF': ['1', '24', '12', '20', '22', '25', '10', '11', '16', '23', '32', '38', '42', '23_1', '35', '58', '23_2', '50', '30', '31', '52', '28', '53', '36', '55', '34'], 'Lasso': ['1', '3', '24', '12', '20', '22', '4', '25', '10', '11', '16', '23', '32', '38', '42', '23_1', '35', '58', '23_2', '50', '54', '30', '51', '31', '52', '28', '53', '36', '34']}, 2017: {'FR': ['1', '24', '12', '20', '25', '10', '23', '32', '38', '42', '35', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34'], 'RF': ['12', '20', '25', '10', '11', '23', '32', '38', '42', '23_1', '35', '58', '23_2', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '94_1', '72_1'], 'Lasso': ['1', '3', '24', '12', '20', '22', '4', '25', '10', '11', '16', '23', '32', '38', '42', '23_1', '35', '58', '23_2', '50',
'70', '71', '72', '49', '30', '75', '66', '63', '64', '50', '31', '37', '34', '38', '42', '108', '117', '118', '142', '119', '120', '109', '110', '111', '112', '113', '114', '115', '116'], 'DT': ['1', '133', '137', '138', '32', '10', ...
# Converted:
# {2016: {'MI': ['Submission of CV on Moodle', 'Submission of CV on Moodle 2', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Submission of short CV & Cover Letter', 'Analysis of 3 CVs of candidates', 'Bloco Livre', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', 'SMART goals (evaluate other group)', "Maria's dashboard", 'Introduction to Google Calendar', 'Procrastination vs. Perfectionism on Moodle', 'Email and Social Media Management', 'Forced landing - individual', 'Forced landing (group) - column 3', 'Forced landing (group) - columns 5, 2 and 4', 'Wolis', 'Excel Exercises 1 to 5', 'Homework: clothes/colours', 'Programming f(x, y)', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Evaluation of the week', 'Researches Privacy on social media', 'Moodle Questionnaire', 'Summary correction', 'Structure of a report', 'Search at B-on complementary Famelab', 'Evaluation of synthesis groups A vs A', 'Ethical dilemmas', 'Draw figures = What is the message? (66)', 'Global evaluation of the discipline (written)', 'Group evaluation of the presentation given by Spokespersons', 'Portuguese Manuscript Summary', 'Assessment of the week (5th week)'], 'RF': ['Submission of CV on Moodle 2', 'Assessment of the week', 'Submission of short CV & Cover Letter', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '23_1', '4x100m freestyle', 'Leadership Paradigms (Spokesperson)', '23_2', 'Assessment of the week', 'SMART goals', 'SMART goals (evaluate other group)', "Maria's dashboard", 'Introduction to Google Calendar', 'Procrastination vs. Perfectionism on Moodle', 'Email and Social Media Management', 'Forced landing (group) - column 3', 'Wolis', 'Excel Exercises 1 to 5', 'Homework: clothes/colours', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Evaluation of the week', 'Researches Privacy on social media', 'Moodle Questionnaire', 'Summary correction', 'Structure of a report', 'Search at B-on complementary Famelab', 'Evaluation of synthesis groups A vs A', 'Ethical dilemmas', 'Draw figures = What is the message? (66)', 'Global evaluation of the discipline (written)', 'Group evaluation of the presentation given by Spokespersons', 'Portuguese Manuscript Summary', 'Manuscript Summary / Oral Communication', 'Newscast Presentation', 'Presentation of Oral Communication', 'Communication using audiovisual media - Posters', 'Assessment of the week (5th week)'], 'DT': ['Psychotechnical test (Moodle)', 'Submission of short CV & Cover Letter', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Interview with volunteers (2 students)', 'Parking', '23_1', '4x100m freestyle', 'Leadership Paradigms (Spokesperson)', '23_2', 'SMART goals', 'SMART goals (evaluate other group)', "Maria's dashboard", 'Introduction to Google Calendar', 'Forced landing (group) - column 3', 'Wolis', 'Excel Exercises 1 to 5', 'Homework: clothes/colours', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Evaluation of the week', 'Researches Privacy on social media', 'Moodle Questionnaire', 'Summary correction', 'Structure of a report', 'Structure of a report (Spokesperson)', 'Search at B-on complementary Famelab', 'Evaluation of synthesis groups A vs A', 'Student Behavior: Ethics (Spokesperson)', 'Ethical dilemmas', 'Global evaluation of the discipline (written)', 'Global evaluation of the discipline (oral)', 'Group evaluation of the presentation given by Spokespersons', 'Portuguese Manuscript Summary', 'Manuscript Summary / Oral Communication', 'Newscast Presentation', 'Presentation of Oral Communication', 'Communication using audiovisual media - Posters', 'Assessment of the week (5th week)']}, 2017: {'MI': ['Submission of CV on Moodle', 'Submission of CV on M ...

# %%
print(extract_common_features(selected_features_total_ap_restricted))
# Out:
# {'MI': ['38', '31', '34', '42', '72', '35', '10', '30', '50', '20', '12', '32', '1', '36'], 'RF': ['38', '31', '34', '35', '30', '32'], 'DT': ['30', '10', '38']}

# %%
exclusion_type = 'less_restricted'
exclude_columns = exclusion_columns_dicts[exclusion_type]
target_column = 'Total_AP'

selected_features_total_ap_less_restricted = feature_selection_analysis(datasets, all_lists, dataset_params, target_column, exclude_columns, methods=['MI', 'RF', 'DT'])
#save_selected_features_to_feather(selected_features_total_ap_less_restricted, datasets, target_column, output_dir, "predict_total_ap", exclusion_type)
# Out:
# Feature Selection Analysis for the dataset of year: 2016 with target column: Total_AP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2017 with target column: Total_AP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2018 with target column: Total_AP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2019 with target column: Total_AP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2022 with target column: Total_AP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2023 with target column: Total_AP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2024 with target column: Total_AP
# --------------------------------------------------

# %%
doc.add_heading('Less restricted Results', 3)

# %%
print("Selected Features:")
print(selected_features_total_ap_less_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names(selected_features_total_ap_less_restricted, dataset_params)
print(converted_features)
# Out:
# Selected Features:
# {2016: {'MI': ['1', '24', '12', '20', '25', '10', '23', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '124', '125', '126', '127', '128', '129', '130', '131', '83', '94', '86', '87', '89', '91', '72', '95', '105', '103', '96', '104', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_1', 'PP4_2', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_PP', 'Total_SPA', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'], 'RF': ['12', '20', '22', '10', '11', '23', '32', '38', '23_1', '35', '58', '54', '30', '31', '34', '125', '127', '128', '129', '130', '131', '83', '86', '87', '88', '89', '91', '93', '72', '95', '103', '96', '97', '101', '102', '77', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP2_1', 'PP2_3', 'PP3_2', 'PP4_1', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP1', 'PTP3', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_PP', 'Total_SPA', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'], 'DT': ['12', '20', '22', '11', '32', '38', '23_1', '35', '58', '23_2', '30', '31', '124', '125', '126', '127', '128', '129', '130', '83', '86', '87', '88', '89', '91', '93', '72', '105', '103', '96', '97', '101', '102', '77', '104', 'SPA1', 'SPA2', 'SPA3', 'PP1_2', 'PP2_1', 'PP2_2', 'PP3_2', 'PP3_3', 'PP4_1', 'PP5_1', 'PP5_2', 'PTP2', 'PTP3', 'PTP4', 'FinalGradeInteger', 'FinalGrade', 'Total_PP', 'Total_SPA', 'Total_Bon', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP']}, 2017: {'MI': ['1', '24', '12', '20', '25', '10', '23', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '124', '125', '126', '127', '128', '129', '130', '131', '83', '94', '94_1', '4_2', '86', '87', '89', '91', '72', '95', '104', '96', '103', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_1', 'PP4_2', 'PP4_3', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_PP', 'Total_SPA', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'], 'RF': ['1', '24', '12', '20', '22', '11', '32', '38', '23_1', '35', '58', '23_2', '30', '51', '31', '52', '28', '125', '126', '127', '128', '129', '130', '131', '132', '83', '94_1', '4_2', '86', '87', '88', '89', '91', '93', '72_1', '104', '96', '97', '101', '102', '77', '103', 'SPA1', 'SPA2', 'SPA3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_3', 'PP4_1', 'PP4_2', 'PP4_3', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP2', 'PTP3', 'FinalGradeInteger', 'FinalGrade', 'Total_PP', 'Total_SPA', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'], 'DT': ['22', '10', '11', '16', '23', '32', '38', '42', '35', '58', '23_2', '54', '30', '51', '31', '52', '34', '125', '126', '127', '128', '129', '130', '131', '94_1', '89', '91', '72', '72_1', '96', '97', '101', '102', '77', '103', 'SPA1', 'SPA3', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP4_2', 'PP4_3', 'PP5_1', 'PP5_3', 'PTP1', 'PTP3', 'PTP5', 'FinalGrade', 'Total_PP', 'Total_SPA', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP']}, 2018: {'MI': ['1', '12', '4', '25', '23', '18', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '124', '125', '126', '127', '128', '129', '130', '131', '83', '94', '94_1', '4_2', '86', '87', '89', '91', '72', '95', '96', '97', '103', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_1', 'PP4_2', 'PP5_1', 'PP5_2', 'PTP1', 'PTP2', ' ...
# Converted:
# {2016: {'MI': ['Submission of CV on Moodle', 'Submission of CV on Moodle 2', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Submission of short CV & Cover Letter', 'Analysis of 3 CVs of candidates', 'Bloco Livre', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', 'SMART goals (evaluate other group)', "Maria's dashboard", 'Introduction to Google Calendar', 'Procrastination vs. Perfectionism on Moodle', 'Email and Social Media Management', 'Forced landing - individual', 'Forced landing (group) - column 3', 'Forced landing (group) - columns 5, 2 and 4', 'Wolis', 'Excel Exercises 1 to 5', 'Homework: clothes/colours', 'Programming f(x, y)', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Evaluation of the week', 'Researches Privacy on social media', 'Moodle Questionnaire', 'Summary correction', 'Structure of a report', 'Search at B-on complementary Famelab', 'Evaluation of synthesis groups A vs A', 'Ethical dilemmas', 'Draw figures = What is the message? (66)', 'Global evaluation of the discipline (written)', 'Group evaluation of the presentation given by Spokespersons', 'Portuguese Manuscript Summary', 'Assessment of the week (5th week)', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_1', 'PP4_2', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_PP', 'Total_SPA', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'], 'RF': ['Psychotechnical test (Moodle)', 'Assessment of the week', 'Assessment of the week gathering', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Bloco Livre', 'Submission of CV on Moodle', 'Parking', '23_1', '4x100m freestyle', 'Leadership Paradigms (Spokesperson)', 'Assessment of the week Gathering', 'SMART goals', "Maria's dashboard", 'Wolis', 'Homework: clothes/colours', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Evaluation of the week', 'Researches Privacy on social media', 'Summary correction', 'Structure of a report', 'Structure of a report (Spokesperson)', 'Search at B-on complementary Famelab', 'Evaluation of synthesis groups A vs A', 'Student Behavior: Ethics (Spokesperson)', 'Ethical dilemmas', 'Draw figures = What is the message? (66)', 'Group evaluation of the presentation given by Spokespersons', 'Portuguese Manuscript Summary', 'Manuscript Summary / Oral Communication', 'Newscast Presentation', 'Presentation of Oral Communication', 'Communication using audiovisual media - Posters', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP2_1', 'PP2_3', 'PP3_2', 'PP4_1', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP1', 'PTP3', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_PP', 'Total_SPA', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'], 'DT': ['Psychotechnical test (Moodle)', 'Assessment of the week', 'Assessment of the week gathering', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '23_1', '4x100m freestyle', 'Leadership Paradigms (Spokesperson)', '23_2', 'SMART goals', "Maria's dashboard", 'Excel Exercises 1 to 5', 'Homework: clothes/colours', 'Programming f(x, y)', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Researches Privacy on social media', 'Summary correction', 'Structure of a report', 'Structure of a report (Spokesperson)', 'Search at B-on complementary Famelab', 'Evaluation of synthesis groups A vs A', 'Student Behavior: Ethics (Spokesperson)', 'Ethical dilemmas', 'Global evaluation of the discipline (written)', 'Group evaluation of the presentation given by Spokespersons', 'Portuguese Manuscript Summary', 'Manuscript Summary / Ora ...

# %%
print(extract_common_features(selected_features_total_ap_less_restricted))
# Out:
# {'MI': ['Week1_AP', 'SPA2', '35', 'Total_PP', 'SPA3', 'FinalGrade', 'Week3_PP', '42', '72', 'Week1_PP', 'PP3_1', '50', 'PP3_2', 'PP2_1', 'Passed', 'PP3_3', '1', '36', 'FinalGradeInteger', 'Week3_AP', '31', 'Week2_PP', 'Week2_AP', 'SPA1', '32', '38', 'Total_SPA', '34', 'PP2_2', '12', '30'], 'RF': ['FinalGradeInteger', '38', 'Week3_AP', 'Total_SPA', 'FinalGrade', 'Week3_PP', 'Week1_AP', 'SPA2', 'PP2_3', 'Week2_PP', 'Week2_AP', '35', '30', 'Total_PP', 'SPA3', '32'], 'DT': ['38', 'PTP3', 'Week3_AP', 'Total_SPA', 'FinalGrade', 'Week3_PP', 'Week1_AP', '31', 'Week2_AP', '11', 'Week1_PP', '30', 'Total_PP', 'SPA1', '32']}

# %% [markdown]
# ### 5.3.4. For predicting *Total_PP*
# Feature selection on datasets dictionary of dataframes, one per each year (preprocessed original dataframes).

# %%
doc.add_heading('Predicting Total_PP', 2)

# %%
exclusion_type = 'more_restricted'
exclude_columns = exclusion_columns_dicts[exclusion_type]
target_column = 'Total_PP'

selected_features_total_pp_more_restricted = feature_selection_analysis(datasets, all_lists, dataset_params, target_column, exclude_columns, methods=['MI', 'RF', 'DT'])
#save_selected_features_to_feather(selected_features_total_pp_more_restricted, datasets, target_column, output_dir, "predict_total_pp", exclusion_type)
# Out:
# Feature Selection Analysis for the dataset of year: 2016 with target column: Total_PP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2017 with target column: Total_PP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2018 with target column: Total_PP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2019 with target column: Total_PP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2022 with target column: Total_PP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2023 with target column: Total_PP
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2024 with target column: Total_PP
# --------------------------------------------------

# %%
doc.add_heading('More restricted Results', 3)

# %%
print("Selected Features:")
print(selected_features_total_pp_more_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names(selected_features_total_pp_more_restricted, dataset_params)
print(converted_features)
# Out:
# Selected Features:
# {2016: {'MI': ['1', '24', '12', '20', '25', '10', '23', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34'], 'RF': ['1', '3', '24', '20', '22', '25', '10', '11', '16', '32', '38', '42', '23_1', '35', '58', '23_2', '50', '30', '51', '31', '28', '53', '36', '55', '56', '34'], 'DT': ['1', '3', '24', '12', '20', '22', '10', '11', '16', '32', '38', '23_1', '35', '58', '23_2', '50', '30', '31', '28', '53', '34']}, 2017: {'MI': ['1', '24', '12', '20', '25', '10', '23', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '94_1'], 'RF': ['24', '12', '20', '22', '25', '10', '11', '23', '32', '38', '42', '23_1', '35', '58', '23_2', '50', '30', '31', '52', '28', '53', '36', '55', '56', '34', '94_1', '72_1'], 'DT': ['24', '12', '22', '25', '10', '11', '16', '23', '32', '38', '23_1', '35', '58', '23_2', '50', '54', '30', '31', '52', '36', '55', '34', '94_1', '72_1']}, 2018: {'MI': ['1', '24', '12', '20', '25', '10', '11', '23', '18', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '94_1'], 'RF': ['1', '24', '12', '20', '22', '25', '10', '11', '23', '32', '38', '23_1', '35', '58', '23_2', '50', '30', '31', '52', '28', '53', '55', '34', '94_1', '72_1'], 'DT': ['1', '12', '22', '25', '10', '11', '16', '23', '18', '32', '38', '23_1', '35', '58', '23_2', '50', '54', '30', '31', '52', '28', '34', '94_1', '72_1']}, 2019: {'MI': ['1', '3', '18', '20', '10', '12', '1_8', '32', '38', '42', '35', '50', '54', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '94_1'], 'RF': ['1', '3', '18', '24', '20', '22', '10', '11', '16', '12', '1_8', '32', '38', '42', '23', '35', '58', '23_1', '50', '30', '31', '52', '28', '53', '55', '34', '94_1', '72_1'], 'DT': ['3', '20', '22', '10', '11', '16', '12', '1_8', '32', '38', '23', '35', '58', '23_1', '50', '30', '31', '52', '34', '94_1', '72_1']}, 2022: {'MI': ['1', '23', '133', '135', '19', '137', '32', '144', '139', '140', '20', '25', '10', '12', '27', '29', '35', '45', '46', '69', '70', '71', '72', '49', '30', '75', '66', '63', '64', '50', '
'53', '36', '55', '56', '34', '124', '125', '126', '127', '128', '130', '131', '83', '94', '94_1', '4_2', '86', '89', '91', '72', '95', '104', '96', '103', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'P ...
# Converted:
# {2016: {'MI': ['Submission of CV on Moodle', 'Submission of CV on Moodle 2', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Submission of short CV & Cover Letter', 'Analysis of 3 CVs of candidates', 'Bloco Livre', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', 'SMART goals (evaluate other group)', "Maria's dashboard", 'Introduction to Google Calendar', 'Procrastination vs. Perfectionism on Moodle', 'Forced landing - individual', 'Forced landing (group) - column 3', 'Forced landing (group) - columns 5, 2 and 4', 'Wolis', 'Excel Exercises 1 to 5', 'Homework: clothes/colours', 'Programming f(x, y)', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Evaluation of the week', 'Researches Privacy on social media', 'Moodle Questionnaire', 'Summary correction', 'Structure of a report', 'Search at B-on complementary Famelab', 'Evaluation of synthesis groups A vs A', 'Ethical dilemmas', 'Draw figures = What is the message? (66)', 'Global evaluation of the discipline (written)', 'Group evaluation of the presentation given by Spokespersons', 'Portuguese Manuscript Summary', 'Assessment of the week (5th week)', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_1', 'PP4_2', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_SPA', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'], 'RF': ['Assessment of the week gathering', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '23_1', '4x100m freestyle', 'Leadership Paradigms (Spokesperson)', '23_2', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Procrastination vs. Perfectionism on Moodle', 'Email and Social Media Management', 'Wolis', 'Homework: clothes/colours', 'Programming f(x, y)', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Evaluation of the week', 'Researches Privacy on social media', 'Summary correction', 'Structure of a report', 'Structure of a report (Spokesperson)', 'Search at B-on complementary Famelab', 'Evaluation of synthesis groups A vs A', 'Student Behavior: Ethics (Spokesperson)', 'Ethical dilemmas', 'Draw figures = What is the message? (66)', 'Global evaluation of the discipline (oral)', 'Group evaluation of the presentation given by Spokespersons', 'Portuguese Manuscript Summary', 'Manuscript Summary / Oral Communication', 'Newscast Presentation', 'Presentation of Oral Communication', 'Communication using audiovisual media - Posters', 'Assessment of the week (5th week)', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PP4_1', 'PP4_2', 'PP5_1', 'PP5_2', 'PP5_3', 'PTP1', 'PTP2', 'PTP3', 'PTP4', 'PTP5', 'FinalGradeInteger', 'FinalGrade', 'Total_AP', 'Total_SPA', 'Week1_AP', 'Week2_AP', 'Week3_AP', 'Week4_AP', 'Week5_AP', 'Week1_PP', 'Week2_PP', 'Week3_PP', 'Week4_PP', 'Week5_PP', 'Passed'], 'DT': ['Submission of CV on Moodle', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', '23_1', '4x100m freestyle', 'Leadership Paradigms (Spokesperson)', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Procrastination vs. Perfectionism on Moodle', 'Email and Social Media Management', 'Wolis', 'Homework: clothes/colours', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Evaluation of the week', 'Week b review', 'Researches Privacy on social media', 'Summary correction', 'Structure of a report', 'Structure of a report (Spokesperson)', 'Ethical dilemmas', 'Global evaluation of the discipline (oral)', 'Group evaluation of the pre ...

# %%
print(extract_common_features(selected_features_total_pp_less_restricted))
# Out:
# {'MI': ['PTP2', 'Week1_AP', 'SPA2', '35', 'SPA3', 'PP1_1', 'Week3_PP', 'FinalGrade', '42', '72', 'Week1_PP', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'Passed', 'PP2_1', '1', '36', 'PP3_3', 'Total_AP', 'FinalGradeInteger', 'Week3_AP', '31', 'Week2_PP', 'PP2_3', 'Week2_AP', '10', 'PTP1', 'SPA1', '20', '32', '38', 'PTP3', 'PP1_3', 'Total_SPA', 'PP2_2', '12', '30'], 'RF': ['PTP2', 'Week1_AP', 'SPA2', '11', '35', 'SPA3', 'PP1_1', 'FinalGrade', 'Week3_PP', 'Week1_PP', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', 'Week3_AP', '31', 'PP2_3', 'Week2_PP', 'Week2_AP', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', 'PP2_2', '30'], 'DT': ['PTP2', 'Total_AP', 'PTP3', 'Week3_AP', 'PP1_3', 'Week3_PP', 'FinalGrade', 'Week1_AP', 'Week2_PP', 'Total_SPA', 'Week2_AP', 'Week1_PP', 'SPA3', 'PP1_2', '30']}

# %% [markdown]
# ### 5.3.5. For predicting *Total_SPA*
# Feature selection on datasets dictionary of dataframes, one per each year (preprocessed original dataframes).

# %%
doc.add_heading('Predicting Total_SPA', 2)

# %%
exclusion_type = 'more_restricted'
exclude_columns = exclusion_columns_dicts[exclusion_type]
target_column = 'Total_SPA'

selected_features_total_spa_more_restricted = feature_selection_analysis(datasets, all_lists, dataset_params, target_column, exclude_columns, methods=['MI', 'RF', 'DT'])
#save_selected_features_to_feather(selected_features_total_spa_more_restricted, datasets, target_column, output_dir, "predict_total_spa", exclusion_type)
# Out:
# Feature Selection Analysis for the dataset of year: 2016 with target column: Total_SPA
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2017 with target column: Total_SPA
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2018 with target column: Total_SPA
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2019 with target column: Total_SPA
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2022 with target column: Total_SPA
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2023 with target column: Total_SPA
# --------------------------------------------------
# Feature Selection Analysis for the dataset of year: 2024 with target column: Total_SPA
# --------------------------------------------------

# %%
doc.add_heading('More restricted Results', 3)

# %%
print("Selected Features:")
print(selected_features_total_spa_more_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names(selected_features_total_spa_more_restricted, dataset_params)
print(converted_features)
# Out:
# Selected Features:
# {2016: {'MI': ['1', '24', '12', '20', '25', '10', '23', '32', '38', '42', '35', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34'], 'RF': ['1', '24', '12', '20', '22', '25', '10', '11', '32', '38', '23_1', '35', '58', '23_2', '50', '30', '51', '31', '28', '53', '36', '55', '56', '34'], 'DT': ['1', '24', '12', '22', '25', '10', '11', '23', '32', '38', '23_1', '35', '58', '23_2', '50', '30', '51', '31', '52', '28', '53', '56']}, 2017: {'MI': ['1', '24', '12', '20', '25', '10', '23', '32', '38', '42', '35', '50', '30', '51', '31', '52', '28', '53', '36', '55', '56', '34', '94_1'], 'RF': ['12', '20', '22', '25', '10', '11', '32', '38', '42', '23_1', '35', '58', '23_2', '50', '30', '31', '52', '53', '55', '56', '34', '94_1', '72_1'], 'DT': ['24', '12', '22', '25', '10', '11', '16', '23', '32', '38', '23_1', '35', '58', '23_2', '50', '54', '30', '31', '28', '53', '56', '34', '94_1', '72_1']}, 2018: {'MI': ['1', '24', '12', '22', '10', '11', '23', '18', '32', '38', '42', '23_1', '35', '58', '50', '54', '30', '51', '31', '52', '28', '53', '36', '55', '56', '
', '97', '101', '102', '77', '103'], 'DT': ['1', '18', '24', '22', '10', '11', '32', '38', '23', '35', '50', '31', '53', '36', '126', '127', '129', '130', '131', '94', '4_2', '86', '87', '88', '89', '91', '93', '72', '95', '104', '96', '101', '102', '77', '103']}, 2022: {'MI': ['1', '23', '133', '135', '19', '137', '32', '144', '139', '140', '20', '25', '12', '27', '29', '35', '45', '46', '69', '70', '71', '72', '49', '30', '75', '66', '63', '64', '50', '31', '36', '37', '34', '38', '44', '42', '108', '117', '118', '142', '119', '120', '122', '109', '110', '111', '112', '113', '114', '115', '116'], 'RF': ['1', '23', '133', '134', '135', '19', '138', '32', '144', '140', '25', '10', '11', '15', '27', '29', '2_11', '35', '45', '71', '72', '73', '49', '30', '75', '63', '64', '31', '33', '36', '34', '38', '44', '43', '108', '117', '118', '142', '119', '120', '122', '109', '110', '111', '112', '113', '114', '115', '116'], 'DT' ...
# Converted:
# {2016: {'MI': ['Submission of CV on Moodle', 'Submission of CV on Moodle 2', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Submission of short CV & Cover Letter', 'Analysis of 3 CVs of candidates', 'Bloco Livre', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', 'SMART goals (evaluate other group)', "Maria's dashboard", 'Introduction to Google Calendar', 'Procrastination vs. Perfectionism on Moodle', 'Email and Social Media Management', 'Forced landing - individual', 'Forced landing (group) - column 3', 'Forced landing (group) - columns 5, 2 and 4', 'Wolis', 'Excel Exercises 1 to 5', 'Homework: clothes/colours', 'Programming f(x, y)', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Researches Privacy on social media', 'Moodle Questionnaire', 'Summary correction', 'Structure of a report', 'Search at B-on complementary Famelab', 'Evaluation of synthesis groups A vs A', 'Ethical dilemmas', 'Draw figures = What is the message? (66)', 'Global evaluation of the discipline (written)', 'Group evaluation of the presentation given by Spokespersons', 'Portuguese Manuscript Summary', 'Manuscript Summary / Oral Communication', 'Presentation of Oral Communication', 'Communication using audiovisual media - Posters', 'Assessment of the week (5th week)'], 'RF': ['Submission of CV on Moodle', 'Submission of CV on Moodle 2', 'Assessment of the week gathering', 'Submission of short CV & Cover Letter', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '23_1', '4x100m freestyle', 'Assessment of the week', 'SMART goals', 'SMART goals (evaluate other group)', "Maria's dashboard", 'Procrastination vs. Perfectionism on Moodle', 'Wolis', 'Excel Exercises 1 to 5', 'Homework: clothes/colours', 'Programming f(x, y)', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Evaluation of the week', 'Researches Privacy on social media', 'Moodle Questionnaire', 'Summary correction', 'Structure of a report', 'Structure of a report (Spokesperson)', 'Search at B-on complementary Famelab', 'Evaluation of synthesis groups A vs A', 'Student Behavior: Ethics (Spokesperson)', 'Ethical dilemmas', 'Group evaluation of the presentation given by Spokespersons', 'Portuguese Manuscript Summary', 'Manuscript Summary / Oral Communication', 'Newscast Presentation', 'Presentation of Oral Communication', 'Communication using audiovisual media - Posters', 'Assessment of the week (5th week)'], 'DT': ['Submission of CV on Moodle', 'Submission of CV on Moodle 2', 'Psychotechnical test (Moodle)', 'Assessment of the week gathering', 'Submission of short CV & Cover Letter', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Interview with volunteers (2 students)', 'Submission of CV on Moodle', 'Parking', '23_1', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Procrastination vs. Perfectionism on Moodle', 'Forced landing (group) - column 3', 'Wolis', 'Excel Exercises 1 to 5', 'Homework: clothes/colours', 'Programming f(x, y)', 'List of Insured Persons', 'School Planning', 'Individual Test: VB Function', 'Moodle test Excel', 'Moodle Questionnaire', 'Summary correction', 'Structure of a report', 'Structure of a report (Spokesperson)', 'Search at B-on complementary Famelab', 'Evaluation of synthesis groups A vs A', 'Student Behavior: Ethics (Spokesperson)', 'Ethical dilemmas', 'Global evaluation of the discipline (written)', 'Global evaluation of the discipline (oral)', 'Group evaluation of the presentation given by Spokespersons', 'Portuguese Manuscript Summary', 'Manuscript Summary / Oral Communication', 'Newscast Presentation', 'Presentation of Oral Communication', 'Communication using audiovisual media - Posters']}, 2017: {'MI': ['Submission of CV on Moodle', 'Submission of CV on Moodle 2', 'Psychotechnical test (Moodl ...

# %%
print(extract_common_features(selected_features_total_spa_less_restricted))
# Out:
# {'MI': ['38', '31', '34', '42', '72', '35', '30', '50', '12', '32'], 'RF': ['38', '31', '34', '10', '11', '35', '30', '32'], 'DT': ['10', '11', '31']}

# %% [markdown]
# ### 5.3.6 Using compose_datasets
# Feature selection on datasets with multiple years generated in data_preparation.ipynb file.

# %%
doc.add_heading('Using compose_datasets', 1)

# %%
for key, value in compose_datasets.items():
    print(f"Key: {key}, Dataset Size: {len(value)}")
    print(f"Years in this dataset: {value['Year'].unique()}")
# Out:
# Key: 242, Dataset Size: 7648
# Years in this dataset: ['2016' '2017' '2018' '2019' '2022' '2023' '2024']
# Key: 6769, Dataset Size: 1121
# Years in this dataset: ['2024']
# Key: 6835, Dataset Size: 1055
# Years in this dataset: ['2019']
# Key: 3453, Dataset Size: 4437
# Years in this dataset: ['2017' '2019' '2023' '2024']
# Key: 5660, Dataset Size: 2230
# Years in this dataset: ['2023' '2024']
# Key: 3500, Dataset Size: 4390
# Years in this dataset: ['2018' '2019' '2023' '2024']
# Key: 6711, Dataset Size: 1179
# Years in this dataset: ['2022']
# Key: 1179, Dataset Size: 6711
# Years in this dataset: ['2016' '2017' '2018' '2019' '2023' '2024']
# Key: 6721, Dataset Size: 1169
# Years in this dataset: ['2016']
# Key: 1055, Dataset Size: 6835
# Years in this dataset: ['2016' '2017' '2018' '2022' '2023' '2024']
# Key: 3409, Dataset Size: 4481
# Years in this dataset: ['2016' '2017' '2018' '2019']
# Key: 2290, Dataset Size: 5600
# Years in this dataset: ['2017' '2018' '2019' '2022' '2023']
# Key: 1121, Dataset Size: 6769
# Years in this dataset: ['2016' '2017' '2018' '2019' '2022' '2023']
# Key: 6781, Dataset Size: 1109
# Years in this dataset: ['2023']
# Key: 4578, Dataset Size: 3312
# Years in this dataset: ['2017' '2018' '2019']
# Key: 0, Dataset Size: 7890
# Years in this dataset: ['2016' '2017' '2018' '2019' '2022' '2023' '2024']
# Key: 2230, Dataset Size: 5660
# Years in this dataset: ['2016' '2017' '2018' '2019' '2022']
# Key: 5590, Dataset Size: 2300
# Years in this dataset: ['2022' '2024']
# Key: 4481, Dataset Size: 3409
# Years in this dataset: ['2022' '2023' '2024']
# Key: 2300, Dataset Size: 5590
# Years in this dataset: ['2016' '2017' '2018' '2019' '2023']

# %% [markdown]
# #### For predicting Sex column

# %%
doc.add_heading('For predicting Sex', 2)

# %%
exclusion_type = 'more_restricted'
exclude_columns = exclusion_columns_dicts[exclusion_type]
target_column = 'Sex'

selected_features_sex_more_restricted = feature_selection_analysis_generic(compose_datasets, all_lists_id, target_column, exclude_columns, methods=['MI', 'RF', 'DT'])
#save_selected_features_to_feather(selected_features_sex_more_restricted, compose_datasets, target_column, output_dir, "predict_sex", exclusion_type)
# Out:
# Feature Selection Analysis for the dataset with key: 242 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6769 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6835 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3453 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5660 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3500 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6711 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1179 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6721 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1055 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3409 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2290 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1121 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6781 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4578 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 0 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2230 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5590 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4481 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2300 with target column: Sex
# --------------------------------------------------

# %%
doc.add_heading('More restricted Results', 3)

# %%
print("Selected Features:")
print(selected_features_sex_more_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names_complete(selected_features_sex_more_restricted, dataset_params)
print(converted_features)
# Out:
# Selected Features:
# {242: {'MI_2016': ['1', '12', '11', '32', '38', '42', '35', '50', '31', '36', '34'], 'RF_2016': ['10', '11', '32', '38', '35', '30', '31', '34'], 'DT_2016': ['10', '11', '32', '38', '35', '50', '30', '31', '34'], 'MI_2017': ['1', '12', '11', '32', '38', '42', '35', '50', '31', '36', '34'], 'RF_2017': ['10', '11', '32', '38', '35', '30', '31', '34'], 'DT_2017': ['10', '11', '32', '38', '35', '50', '30', '31', '34'], 'MI_2018': ['1', '12', '11', '32', '38', '42', '35', '50', '31', '36', '34'], 'RF_2018': ['10', '11', '32', '38', '35', '30', '31', '34'], 'DT_2018': ['10', '11', '32', '38', '35', '50', '30', '31', '34'], 'MI_2019': ['1', '12', '11', '32', '38', '42', '35', '50', '31', '36', '34'], 'RF_2019': ['10', '11', '32', '38', '35', '30', '31', '34'], 'DT_2019': ['10', '11', '32', '38', '35', '50', '30', '31', '34'], 'MI_2022': ['1', '12', '11', '32', '38', '42', '35', '50', '31', '36', '34'], 'RF_2022': ['10', '11', '32', '38', '35', '30', '31', '34'], 'DT_2022': ['10', '11', '32', '38', '35', '50', '30', '31', '34'], 'MI_2023': ['1', '12', '11', '32', '38', '42', '35', '50', '31', '36', '34'], 'RF_2023': ['10', '11', '32', '38', '35', '30', '31', '34'], 'DT_2023': ['10', '11', '32', '38', '35', '50', '30', '31', '34'], 'MI_2024': ['1', '12', '11', '32', '38', '42', '35', '50', '31', '36', '34'], 'RF_2024': ['10', '11', '32', '38', '35', '30', '31', '34'], 'DT_
], 'RF': ['38', '34', '31', '32', '11', '35', '10', '72', '50', '30'], 'DT': ['38', '34', '31', '32', '11', '10', '35', '72', '20', '50', '30']}, 6781: {'MI': ['38', '31', '32', '1', '146', '10'], 'RF': ['38', '31', '34', '11', '10', '35', '30', '147', '32', '1', '146'], 'DT': ['38', '31', '34', '11', '10', '35', '30', '72', '20', '32', '146']}, 4578: {'MI': ['38', '10', '11', '35', '4_2', '20', '12', '32', '1'], 'RF': ['38', '34', '31', '32', '11', '35', '10', '72', '4_2', '50', '30'], 'DT': ['38', '34', '31', '32', '10', '35', '72', '4_2', '20', '50', '30']}, 0: {'MI': ['38', '42', '11', '35', '50', '30', ...

# %%
exclusion_type = 'less_restricted'
exclude_columns = exclusion_columns_dicts[exclusion_type]
target_column = 'Sex'

selected_features_sex_less_restricted = feature_selection_analysis_generic(compose_datasets, all_lists_id, target_column, exclude_columns, methods=['MI', 'RF', 'DT'])
#save_selected_features_to_feather(selected_features_sex_less_restricted, compose_datasets, target_column, output_dir, "predict_sex", exclusion_type)
# Out:
# Feature Selection Analysis for the dataset with key: 242 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6769 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6835 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3453 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5660 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3500 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6711 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1179 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6721 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1055 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3409 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2290 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1121 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6781 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4578 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 0 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2230 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5590 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4481 with target column: Sex
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2300 with target column: Sex
# --------------------------------------------------

# %%
doc.add_heading('Less restricted Results', 3)

# %%
print("Selected Features:")
print(selected_features_sex_less_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names_complete(selected_features_sex_less_restricted, dataset_params)
print(converted_features)
# Out:
# Selected Features:
# {242: {'MI_2016': ['1', '20', '42', '35', '30', '31', '36', 'SPA2', 'SPA3', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP2', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'RF_2016': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'DT_2016': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'MI_2017': ['1', '20', '42', '35', '30', '31', '36', 'SPA2', 'SPA3', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP2', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'RF_2017': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'DT_2017': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'MI_2018': ['1', '20', '42', '35', '30', '31', '36', 'SPA2', 'SPA3', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP2', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'RF_2018': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'DT_2018': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'MI_2019': ['1', '20', '42', '35', '30', '31', '36', 'SPA2', 'SPA3', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP2', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'RF_2019': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'DT_2019': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'MI_2022': ['1', '20', '42', '35', '30', '31', '36', 'SPA2', 'SPA3', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP2', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'RF_2022': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'DT_2022': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'MI_2023': ['1', '20', '42', '35', '30', '31', '36', 'SPA2', 'SPA3', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP2', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'To ...
# Converted:
# {242: {'MI_2016': ['Submission of CV on Moodle', 'Assessment of the week', 'Leading is ...', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP2)', 'Unknown (ID: FinalGradeInteger)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: FinalGrade)'], 'RF_2016': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_1)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_2)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: FinalGradeInteger)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: FinalGrade)'], 'DT_2016': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_1)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_2)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: FinalGradeInteger)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: FinalGrade)'], 'MI_2017': ['Submission of CV on Moodle', 'Assessment of the week', 'Leading is ...', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP2)', 'Unknown (ID: FinalGradeInteger)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: FinalGrade)'], 'RF_2017': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_1)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_2)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: FinalGradeInteger)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: FinalGrade)'], 'DT_2017': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_1)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_2)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: FinalGradeInteger)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: FinalGrade)'], 'MI_2018': ['Submission of CV on Moodle ...

# %%
common_features_per_dataset = extract_common_features_per_compose_dataset(selected_features_sex_less_restricted, compose_datasets)
print(common_features_per_dataset)
# Out:
# {242: {'MI': ['PTP2', 'SPA2', '35', 'Total_PP', 'SPA3', 'FinalGrade', '42', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '20', 'PP1_3', 'Total_SPA', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 6769: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '123', 'PTP1', 'PP3_5', '38', '2', 'Total_SPA', 'Total_Bon', '72', '8', 'PP2_2', '50', 'PP3_2', 'PP2_1', '1', '30', 'PP3_3', '36'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '78', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', '123', 'PTP1', 'SPA1', '9', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP2_2', '30'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP3_3', 'PP2_2', '78', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', '1']}, 6835: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', 'PTP1', 'Total_PP', 'SPA3', '20', 'PP1_1', 'Total_SPA', '34', '50', 'PP3_2', 'PP2_1', 'PP3_3'], 'RF': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3', '36']}, 3453: {'MI': ['PTP2', '35', 'PP4_3', 'SPA3', 'PP1_1', '50', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PTP1', 'SPA1', 'PTP3', 'Total_SPA', 'PP2_2', '12'], 'RF': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 5660: {'MI': ['41', 'Bon', 'SPA2', '68', '35', 'SPA3', '61', '60', '42', 'PP3_2', 'PP2_1', '1', 'Total_AP', 'PP2_3', '82', 'PP4_4', '65', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'Total_Bon', '39', 'PP2_2', '74', 'PP4_5', '12'], 'RF': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', '82', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59'], 'DT': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59']}, 3500: {'MI': ['Total_PP', 'SPA3', '42', '72', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '36', 'FinalGradeInteger', 'PP2_3', 'PTP1', '20', '32', '18', '38', 'PTP3', 'Total_SPA', 'PP2_2', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', ...

# %% [markdown]
# #### For predicting FinalGradeInteger column

# %%
print("Number of Students had negative to CTCT discipline:")
for key, value in compose_datasets.items():
    print(f"Key: {key}, Categories of 'Year' column:\n{value['Year'].value_counts()}")
    print(f"Negatives: {len(value[value['FinalGradeInteger']==0])}")
    print("-" * 50  )
# Out:
# Number of Students had negative to CTCT discipline:
# Key: 242, Categories of 'Year' column:
# Year
# 2022    1179
# 2017    1152
# 2016    1106
# 2018    1076
# 2024    1062
# 2023    1060
# 2019    1013
# Name: count, dtype: int64
# Negatives: 150
# --------------------------------------------------
# Key: 6769, Categories of 'Year' column:
# Year
# 2024    1121
# Name: count, dtype: int64
# Negatives: 59
# --------------------------------------------------
# Key: 6835, Categories of 'Year' column:
# Year
# 2019    1055
# Name: count, dtype: int64
# Negatives: 42
# --------------------------------------------------
# Key: 3453, Categories of 'Year' column:
# Year
# 2017    1152
# 2024    1121
# 2023    1109
# 2019    1055
# Name: count, dtype: int64
# Negatives: 232
# --------------------------------------------------
# Key: 5660, Categories of 'Year' column:
# Year
# 2024    1121
# 2023    1109
# Name: count, dtype: int64
# Negatives: 108
# --------------------------------------------------
# Key: 3500, Categories of 'Year' column:
# Year
# 2024    1121
# 2023    1109
# 2018    1105
# 2019    1055
# Name: count, dtype: int64
# Negatives: 179
# --------------------------------------------------
# Key: 6711, Categories of 'Year' column:
# Year
# 2022    1179
# Name: count, dtype: int64
# Negatives: 68
# --------------------------------------------------
# Key: 1179, Categories of 'Year' column:
# Year
# 2016    1169
# 2017    1152
# 2024    1121
# 2023    1109
# 2018    1105
# 2019    1055
# Name: count, dtype: int64
# Negatives: 324
# --------------------------------------------------
# Key: 6721, Categories of 'Year' column:
# Year
# 2016    1169
# Name: count, dtype: int64
# Negatives: 63
# --------------------------------------------------
# Key: 1055, Categories of 'Year' column:
# Year
# 2022    1179
# 2016    1169
# 2017    1152
# 2024    1121
# 2023    1109
# 2018    1105
# Name: count, dtype: int64
# Negatives: 350
# --------------------------------------------------
# Key: 3409, Categories of 'Year' column:
# Year
# 2016    1169
# 2017    1152
# 2018    1105
# 2019    1055
# Name: count, dtype: int64
# Negatives: 216
# --------------------------------------------------
# Key: 2290, Categories of 'Year' column:
# Year
# 2022    1179
# 2017    1152
# 2023    1109
# 2018    1105
# 2019    1055
# Name: count, dtype: int64
# Negatives: 270
# --------------------------------------------------
# Key: 1121, Categories of 'Year' column:
# Year
# 2022    1179
# 2016    1169
# 2017    1152
# 2023    1109
# 2018    1105
# 2019    1055
# Name: count, dtype: int64
# Negatives: 333
# --------------------------------------------------
# Key: 6781, Categories of 'Year' column:
# Year
# 2023    1109
# Name: count, dtype: int64
# Negatives: 49
# --------------------------------------------------
# Key: 4578, Categories of 'Year' column:
# Year
# 2017    1152
# 2018    1105
# 2019    1055
# Name: count, dtype: int64
# Negatives: 153
# --------------------------------------------------
# Key: 0, Categories of 'Year' column:
# Year
# 2022    1179
# 2016    1169
# 2017    1152
# 2024    1121
# 2023    1109
# 2018    1105
# 2019    1055
# Name: count, dtype: int64
# Negatives: 392
# --------------------------------------------------
# Key: 2230, Categories of 'Year' column:
# Year
# 2022    1179
# 2016    1169
# 2017    1152
# 2018    1105
# 2019    1055
# Name: count, dtype: int64
# Negatives: 284
# --------------------------------------------------
# Key: 5590, Categories of 'Year' column:
# Year
# 2022    1179
# 2024    1121
# Name: count, dtype: int64
# Negatives: 127
# --------------------------------------------------
# Key: 4481, Categories of 'Year' column:
# Year
# 2022    1179
# 2024    1121
# 2023    1109
# Name: count, dtype: int64
# Negatives: 176
# --------------------------------------------------
# Key: 2300, Categories of 'Year' column:
# Year
# 2016    1169
# 2017    1152
# 2023    1109
# 2018    1105
# 2019    1055
# Name: count, dtype: int64
# Negatives: 265
# --------------------------------------------------

# %%
doc.add_heading('For predicting FinalGradeInteger', 2)

# %%
exclusion_type = 'more_restricted'
exclude_columns = exclusion_columns_dicts[exclusion_type]
target_column = 'FinalGradeInteger'

selected_features_finalgradeinteger_more_restricted = feature_selection_analysis_generic(compose_datasets, all_lists_id, target_column, exclude_columns, methods=['MI', 'RF', 'DT'])
#save_selected_features_to_feather(selected_features_finalgradeinteger_more_restricted, compose_datasets, target_column, output_dir, "predict_finalgradeinteger", exclusion_type)
# Out:
# Feature Selection Analysis for the dataset with key: 242 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6769 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6835 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3453 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5660 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3500 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6711 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1179 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6721 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1055 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3409 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2290 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1121 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6781 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4578 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 0 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2230 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5590 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4481 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2300 with target column: FinalGradeInteger
# --------------------------------------------------

# %%
doc.add_heading('More restricted Results', 3)

# %%
print("Selected Features:")
print(selected_features_finalgradeinteger_more_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names_complete(selected_features_finalgradeinteger_more_restricted, dataset_params)
print(converted_features)
# Out:
# Selected Features:
# {242: {'MI_2016': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34'], 'RF_2016': ['20', '10', '11', '32', '38', '35', '30', '31', '34'], 'DT_2016': ['10', '11', '32', '38', '35', '30', '31', '34'], 'MI_2017': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34'], 'RF_2017': ['20', '10', '11', '32', '38', '35', '30', '31', '34'], 'DT_2017': ['10', '11', '32', '38', '35', '30', '31', '34'], 'MI_2018': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34'], 'RF_2018': ['20', '10', '11', '32', '38', '35', '30', '31', '34'], 'DT_2018': ['10', '11', '32', '38', '35', '30', '31', '34'], 'MI_2019': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34'], 'RF_2019': ['20', '10', '11', '32', '38', '35', '30', '31', '34'], 'DT_2019': ['10', '11', '32', '38', '35', '30', '31', '34'], 'MI_2022': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34'], 'RF_2022': ['20', '10', '11', '32', '38', '35', '30', '31', '34'], 'DT_2022': ['10', '11', '32', '38', '35', '30', '31', '34'], 'MI_2023': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34'], 'RF_2023': ['20', '10', '11', '32', '38', '35', '30', '31', '34'], 'DT_2023': ['10', '11', '32', '38', '35', '30', '31', '34'], 'MI_2024': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34'], 'RF_2024': ['20', '10', '11', '32', '38', '35', '30', '31', '34'], 'DT_2024': ['10', '11', '32', '38', '35', '30', '31', '34']}, 6769: {'MI_2024': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '2', '5', '8', '9'], 'RF_2024': ['1', '12', '20', '10', '11', '32', '38', '42', '35', '50', '30', '31', '36', '34', '2', '5', '8', '9'], 'DT_2024': ['1', '12', '20', '10', '11', '32', '38', '35', '50', '30', '31', '36', '34', '9']}, 6835: {'MI_2019': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '1_8'], 'RF_2019': ['10', '11', '32', '38', '35', '50', '30', '31', '34'], 'DT_2019': ['12', '10', '11', '32', '38', '35', '50', '30', '31', '34']}, 3453: {'MI_2017': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34'], 'RF_2017': ['20', '10', '11', '32', '38', '35', '50', '30', '31', '34'], 'DT_2017': ['12', '10', '11', '32', '38', '42', '35', '50', '30', '31', '34'], 'MI_2019': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34'], 'RF_2019': ['20', '10', '11', '32', '38', '35', '50', '30', '31', '34'], 'DT_2019': ['12', '10', '11', '32', '38', '42', '35', '50', '30', '31', '34'], 'MI_2023': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34'], 'RF_2023': ['20', '10', '11', '32', '38', '35', '50', '30', '31', '34'], 'DT_2023': ['12', '10', '11', '32', '38', '42', '35', '50', '30', '31', '34'], 'MI_2024': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34'], 'RF_2024': ['20', '10', '11', '32', '38', '35', '50', '30', '31', '34'], 'DT_2024': ['12', '10', '11', '32', '38', '42', '35', '50', '30', '31', '34']}, 5660: {'MI_2023': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '7', '39', '41'], 'RF_2023': ['1', '20', '10', '11', '32', '38', '35', '30', '31', '34', '41'], 'DT_2023': ['1', '20', '10', '11', '32', '38', '42', '35', '30', '31', '34', '7', '41'], 'MI_2024': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '7', '39', '41'], 'RF_2024': ['1', '20', '10', '11', '32', '38', '35', '30', '31', '34', '41'], 'DT_2024': ['1', '20', '10', '11', '32', '38', '42', '35', '30', '31', '34', '7', '41']}, 3500: {'MI_2018': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '18'], 'RF_2018': ['1', '10', '11', '32', '38', '35', '50', '30', '31', '34'], 'DT_2018': ['12', '10', '11', '32', '38', '42', '35', '30', '31', '34', '18'], 'MI_2019': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '18'], 'RF_2019': ...
# Converted:
# {242: {'MI_2016': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis'], 'RF_2016': ['Assessment of the week', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'DT_2016': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'MI_2017': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis'], 'RF_2017': ['Assessment of the week', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'DT_2017': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'MI_2018': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis'], 'RF_2018': ['Assessment of the week', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'DT_2018': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'MI_2019': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis'], 'RF_2019': ['Assessment of the week', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'DT_2019': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'MI_2022': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Project execution', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis'], 'RF_2022': ['Assessment of the week', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Project execution', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'DT_2022': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Project execution', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'MI_2023': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Project execution', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis'], 'RF_2023': ['Assessment of the week', 'Analysis of 3 CVs of candidates', 'Presentation on t ...

# %%
common_features_per_dataset = extract_common_features_per_compose_dataset(selected_features_sex_less_restricted, compose_datasets)
print(common_features_per_dataset)
# Out:
# {242: {'MI': ['PTP2', 'SPA2', '35', 'Total_PP', 'SPA3', 'FinalGrade', '42', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '20', 'PP1_3', 'Total_SPA', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 6769: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '123', 'PTP1', 'PP3_5', '38', '2', 'Total_SPA', 'Total_Bon', '72', '8', 'PP2_2', '50', 'PP3_2', 'PP2_1', '1', '30', 'PP3_3', '36'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '78', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', '123', 'PTP1', 'SPA1', '9', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP2_2', '30'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP3_3', 'PP2_2', '78', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', '1']}, 6835: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', 'PTP1', 'Total_PP', 'SPA3', '20', 'PP1_1', 'Total_SPA', '34', '50', 'PP3_2', 'PP2_1', 'PP3_3'], 'RF': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3', '36']}, 3453: {'MI': ['PTP2', '35', 'PP4_3', 'SPA3', 'PP1_1', '50', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PTP1', 'SPA1', 'PTP3', 'Total_SPA', 'PP2_2', '12'], 'RF': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 5660: {'MI': ['41', 'Bon', 'SPA2', '68', '35', 'SPA3', '61', '60', '42', 'PP3_2', 'PP2_1', '1', 'Total_AP', 'PP2_3', '82', 'PP4_4', '65', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'Total_Bon', '39', 'PP2_2', '74', 'PP4_5', '12'], 'RF': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', '82', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59'], 'DT': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59']}, 3500: {'MI': ['Total_PP', 'SPA3', '42', '72', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '36', 'FinalGradeInteger', 'PP2_3', 'PTP1', '20', '32', '18', '38', 'PTP3', 'Total_SPA', 'PP2_2', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', ...

# %%
exclusion_type = 'restricted'
exclude_columns = exclusion_columns_dicts[exclusion_type]
target_column = 'FinalGradeInteger'

selected_features_finalgradeinteger_restricted = feature_selection_analysis_generic(compose_datasets, all_lists_id, target_column, exclude_columns, methods=['MI', 'RF', 'DT'])
#save_selected_features_to_feather(selected_features_finalgradeinteger_restricted, compose_datasets, target_column, output_dir, "predict_finalgradeinteger", exclusion_type)
# Out:
# Feature Selection Analysis for the dataset with key: 242 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6769 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6835 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3453 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5660 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3500 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6711 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1179 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6721 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1055 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3409 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2290 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1121 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6781 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4578 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 0 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2230 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5590 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4481 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2300 with target column: FinalGradeInteger
# --------------------------------------------------

# %%
doc.add_heading('Restricted Results', 3)

# %%
print("Selected Features:")
print(selected_features_finalgradeinteger_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names_complete(selected_features_finalgradeinteger_restricted, dataset_params)
print(converted_features)
# Out:
# Selected Features:
# {242: {'MI_2016': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72'], 'RF_2016': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_2016': ['20', '10', '11', '32', '38', '35', '30', '31', '34', '72'], 'MI_2017': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72'], 'RF_2017': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_2017': ['20', '10', '11', '32', '38', '35', '30', '31', '34', '72'], 'MI_2018': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72'], 'RF_2018': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_2018': ['20', '10', '11', '32', '38', '35', '30', '31', '34', '72'], 'MI_2019': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72'], 'RF_2019': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_2019': ['20', '10', '11', '32', '38', '35', '30', '31', '34', '72'], 'MI_2022': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72'], 'RF_2022': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_2022': ['20', '10', '11', '32', '38', '35', '30', '31', '34', '72'], 'MI_2023': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72'], 'RF_2023': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_2023': ['20', '10', '11', '32', '38', '35', '30', '31', '34', '72'], 'MI_2024': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72'], 'RF_2024': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_2024': ['20', '10', '11', '32', '38', '35', '30', '31', '34', '72']}, 6769: {'MI_2024': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72', '2', '5', '8', '9', '78', '123'], 'RF_2024': ['1', '20', '10', '11', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72', '2', '5', '8', '9', '78', '123'], 'DT_2024': ['1', '12', '20', '10', '11', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72', '2', '5', '9', '78', '123']}, 6835: {'MI_2019': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72', '1_8'], 'RF_2019': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72'], 'DT_2019': ['12', '10', '11', '32', '38', '35', '50', '30', '31', '34', '72']}, 3453: {'MI_2017': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72'], 'RF_2017': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72'], 'DT_2017': ['12', '10', '11', '32', '38', '42', '35', '50', '30', '31', '34', '72'], 'MI_2019': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72'], 'RF_2019': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72'], 'DT_2019': ['12', '10', '11', '32', '38', '42', '35', '50', '30', '31', '34', '72'], 'MI_2023': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72'], 'RF_2023': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72'], 'DT_2023': ['12', '10', '11', '32', '38', '42', '35', '50', '30', '31', '34', '72'], 'MI_2024': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72'], 'RF_2024': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72'], 'DT_2024': ['12', '10', '11', '32', '38', '42', '35', '50', '30', '31', '34', '72']}, 5660: {'MI_2023': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72', '7', '39', '41', '59', '60', '61', '82', '62', '65', '68'], 'RF_2023': ['1', '20', '10', '11', '32', '38', '35', '50', '30', '31', '34', '72', '7', '41', '59', '60', '61', '74', '82', '62', '65', '76', '68'], 'DT_2023': ['1', '10', '11', '32', '38', '35', '30', '31', '34', '41', '60', '74', '82', '62', '65', '76', '68'], 'MI_2024': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72', '7', '39', '41', '59', '60', '61', '82', '62', '65', '68'], 'RF_2024': ['1', '20', '10', '11', '32', '38', '35', '50', '30', '31', '34',  ...
# Converted:
# {242: {'MI_2016': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis', 'Ethical dilemmas'], 'RF_2016': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas'], 'DT_2016': ['Assessment of the week', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas'], 'MI_2017': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis', 'Ethical dilemmas'], 'RF_2017': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas'], 'DT_2017': ['Assessment of the week', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas'], 'MI_2018': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis', 'Ethical dilemmas'], 'RF_2018': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas'], 'DT_2018': ['Assessment of the week', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas'], 'MI_2019': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis', 'Ethical dilemmas'], 'RF_2019': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas'], 'DT_2019': ['Assessment of the week', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas'], 'MI_2022': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Project execution', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis', 'Ethical dilemmas'], 'RF_2022': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Project execution', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas'], 'DT_2022': ['Assessment of the week', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Project execution', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas'], 'MI_2023': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', ...

# %%
common_features_per_dataset = extract_common_features_per_compose_dataset(selected_features_sex_less_restricted, compose_datasets)
print(common_features_per_dataset)
# Out:
# {242: {'MI': ['PTP2', 'SPA2', '35', 'Total_PP', 'SPA3', 'FinalGrade', '42', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '20', 'PP1_3', 'Total_SPA', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 6769: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '123', 'PTP1', 'PP3_5', '38', '2', 'Total_SPA', 'Total_Bon', '72', '8', 'PP2_2', '50', 'PP3_2', 'PP2_1', '1', '30', 'PP3_3', '36'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '78', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', '123', 'PTP1', 'SPA1', '9', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP2_2', '30'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP3_3', 'PP2_2', '78', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', '1']}, 6835: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', 'PTP1', 'Total_PP', 'SPA3', '20', 'PP1_1', 'Total_SPA', '34', '50', 'PP3_2', 'PP2_1', 'PP3_3'], 'RF': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3', '36']}, 3453: {'MI': ['PTP2', '35', 'PP4_3', 'SPA3', 'PP1_1', '50', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PTP1', 'SPA1', 'PTP3', 'Total_SPA', 'PP2_2', '12'], 'RF': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 5660: {'MI': ['41', 'Bon', 'SPA2', '68', '35', 'SPA3', '61', '60', '42', 'PP3_2', 'PP2_1', '1', 'Total_AP', 'PP2_3', '82', 'PP4_4', '65', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'Total_Bon', '39', 'PP2_2', '74', 'PP4_5', '12'], 'RF': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', '82', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59'], 'DT': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59']}, 3500: {'MI': ['Total_PP', 'SPA3', '42', '72', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '36', 'FinalGradeInteger', 'PP2_3', 'PTP1', '20', '32', '18', '38', 'PTP3', 'Total_SPA', 'PP2_2', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', ...

# %%
exclusion_type = 'less_restricted'
exclude_columns = exclusion_columns_dicts[exclusion_type]
target_column = 'FinalGradeInteger'

selected_features_finalgradeinteger_less_restricted = feature_selection_analysis_generic(compose_datasets, all_lists_id, target_column, exclude_columns, methods=['MI', 'RF', 'DT'])
#save_selected_features_to_feather(selected_features_finalgradeinteger_less_restricted, compose_datasets, target_column, output_dir, "predict_finalgradeinteger", exclusion_type)
# Out:
# Feature Selection Analysis for the dataset with key: 242 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6769 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6835 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3453 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5660 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3500 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6711 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1179 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6721 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1055 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3409 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2290 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1121 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6781 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4578 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 0 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2230 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5590 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4481 with target column: FinalGradeInteger
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2300 with target column: FinalGradeInteger
# --------------------------------------------------

# %%
doc.add_heading('Less restricted Results', 3)

# %%
print("Selected Features:")
print(selected_features_finalgradeinteger_less_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names_complete(selected_features_finalgradeinteger_less_restricted, dataset_params)
print(converted_features)
# Out:
# Selected Features:
# {242: {'MI_2016': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'RF_2016': ['1', '10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'DT_2016': ['38', '50', '36', '34', 'Bon', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'MI_2017': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'RF_2017': ['1', '10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'DT_2017': ['38', '50', '36', '34', 'Bon', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'MI_2018': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'RF_2018': ['1', '10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'DT_2018': ['38', '50', '36', '34', 'Bon', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'MI_2019': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'RF_2019': ['1', '10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'DT_2019': ['38', '50', '36', '34', 'Bon', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'MI_2022': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'RF_2022': ['1', '10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'DT_2022': ['38', '50', '36', '34', 'Bon', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'MI_2023': ['1', '12', '20', '10', '32', '38', '42', '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'RF_2023': ['1', '10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'DT_2023': ['38', '50', '36', '34', 'Bon', 'PTP2' ...
# Converted:
# {242: {'MI_2016': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis', 'Ethical dilemmas', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_1)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_2)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: FinalGrade)'], 'RF_2016': ['Submission of CV on Moodle', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: Bon)', 'Unknown (ID: PP1_1)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_2)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: Total_Bon)', 'Unknown (ID: FinalGrade)'], 'DT_2016': ['Parking', 'Assessment of the week', 'Forced landing - individual', 'Wolis', 'Unknown (ID: Bon)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: Total_Bon)', 'Unknown (ID: FinalGrade)'], 'MI_2017': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis', 'Ethical dilemmas', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_1)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_2)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: FinalGrade)'], 'RF_2017': ['Submission of CV on Moodle', 'Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: Bon)', 'Unknown (ID: PP1_1)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_2)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: Total_Bon)', 'Unknown (ID: FinalGrade)'], 'DT_2017': ['Parking', 'Assessment of the week', 'Forced landing - individual', 'Wolis', 'Unknown (ID: Bon)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: Total_Bon)', 'Unknown (ID: FinalGrade)'], 'MI_2018': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Analysis of 3 CVs of candidates', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Forced landing - individual', 'Wolis', 'Ethical d ...

# %%
common_features_per_dataset = extract_common_features_per_compose_dataset(selected_features_sex_less_restricted, compose_datasets)
print(common_features_per_dataset)
# Out:
# {242: {'MI': ['PTP2', 'SPA2', '35', 'Total_PP', 'SPA3', 'FinalGrade', '42', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '20', 'PP1_3', 'Total_SPA', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 6769: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '123', 'PTP1', 'PP3_5', '38', '2', 'Total_SPA', 'Total_Bon', '72', '8', 'PP2_2', '50', 'PP3_2', 'PP2_1', '1', '30', 'PP3_3', '36'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '78', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', '123', 'PTP1', 'SPA1', '9', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP2_2', '30'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP3_3', 'PP2_2', '78', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', '1']}, 6835: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', 'PTP1', 'Total_PP', 'SPA3', '20', 'PP1_1', 'Total_SPA', '34', '50', 'PP3_2', 'PP2_1', 'PP3_3'], 'RF': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3', '36']}, 3453: {'MI': ['PTP2', '35', 'PP4_3', 'SPA3', 'PP1_1', '50', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PTP1', 'SPA1', 'PTP3', 'Total_SPA', 'PP2_2', '12'], 'RF': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 5660: {'MI': ['41', 'Bon', 'SPA2', '68', '35', 'SPA3', '61', '60', '42', 'PP3_2', 'PP2_1', '1', 'Total_AP', 'PP2_3', '82', 'PP4_4', '65', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'Total_Bon', '39', 'PP2_2', '74', 'PP4_5', '12'], 'RF': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', '82', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59'], 'DT': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59']}, 3500: {'MI': ['Total_PP', 'SPA3', '42', '72', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3',
'10', '11', '32', '38', '42', '35', '50', '30', '31', '34', '72', '133', '134', '135', '138', '144', '140', '2_11']}, 1179: {'MI_2016': ['12', '20', '32', '38', '42', '35' ...
# Converted:
# {242: {'MI_2016': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Presentation on the analyzed CVs', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'RF_2016': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'DT_2016': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'MI_2017': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Presentation on the analyzed CVs', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'RF_2017': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'DT_2017': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'MI_2018': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Presentation on the analyzed CVs', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'RF_2018': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'DT_2018': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'MI_2019': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Presentation on the analyzed CVs', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'RF_2019': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'DT_2019': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'MI_2022': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Presentation on the analyzed CVs', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'RF_2022': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Project execution', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'DT_2022': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Project execution', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'MI_2023': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Presentation on the analyzed CVs', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'RF_2023': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Project execution', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'DT_2023': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Project execution', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'MI_2024': ['Submission of CV on Moodle', 'Psychotechnical test (Moodle)', 'Assessment of the week', 'Presentation on the analyzed CVs', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'RF_2024': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Project execution', 'Parking', '4x100m freestyle', 'SMART goals', "Maria's dashboard", 'Wolis'], 'DT_2024': ['Analysis of 3 CVs of candidates', 'Presentation on the an ...

# %%
common_features_per_dataset = extract_common_features_per_compose_dataset(selected_features_sex_less_restricted, compose_datasets)
print(common_features_per_dataset)
# Out:
# {242: {'MI': ['PTP2', 'SPA2', '35', 'Total_PP', 'SPA3', 'FinalGrade', '42', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '20', 'PP1_3', 'Total_SPA', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 6769: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '123', 'PTP1', 'PP3_5', '38', '2', 'Total_SPA', 'Total_Bon', '72', '8', 'PP2_2', '50', 'PP3_2', 'PP2_1', '1', '30', 'PP3_3', '36'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '78', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', '123', 'PTP1', 'SPA1', '9', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP2_2', '30'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP3_3', 'PP2_2', '78', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', '1']}, 6835: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', 'PTP1', 'Total_PP', 'SPA3', '20', 'PP1_1', 'Total_SPA', '34', '50', 'PP3_2', 'PP2_1', 'PP3_3'], 'RF': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3', '36']}, 3453: {'MI': ['PTP2', '35', 'PP4_3', 'SPA3', 'PP1_1', '50', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PTP1', 'SPA1', 'PTP3', 'Total_SPA', 'PP2_2', '12'], 'RF': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 5660: {'MI': ['41', 'Bon', 'SPA2', '68', '35', 'SPA3', '61', '60', '42', 'PP3_2', 'PP2_1', '1', 'Total_AP', 'PP2_3', '82', 'PP4_4', '65', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'Total_Bon', '39', 'PP2_2', '74', 'PP4_5', '12'], 'RF': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', '82', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59'], 'DT': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59']}, 3500: {'MI': ['Total_PP', 'SPA3', '42', '72', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '36', 'FinalGradeInteger', 'PP2_3', 'PTP1', '20', '32', '18', '38', 'PTP3', 'Total_SPA', 'PP2_2', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', ...

# %%
exclusion_type = 'restricted'
exclude_columns = exclusion_columns_dicts[exclusion_type]
target_column = 'Course'

selected_features_course_restricted = feature_selection_analysis_generic(compose_datasets, all_lists_id, target_column, exclude_columns, methods=['MI', 'RF', 'DT'])
#save_selected_features_to_feather(selected_features_course_restricted, compose_datasets, target_column, output_dir, "predict_course", exclusion_type)
# Out:
# Feature Selection Analysis for the dataset with key: 242 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6769 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6835 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3453 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5660 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3500 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6711 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1179 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6721 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1055 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3409 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2290 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1121 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6781 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4578 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 0 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2230 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5590 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4481 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2300 with target column: Course
# --------------------------------------------------

# %%
doc.add_heading('Restricted Results', 3)

# %%
print("Selected Features:")
print(selected_features_course_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names_complete(selected_features_course_restricted, dataset_params)
print(converted_features)
# Out:
# Selected Features:
# {242: {'MI_2016': ['1', '20', '11', '32', '38', '35', '30', '36', '72'], 'RF_2016': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_2016': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'MI_2017': ['1', '20', '11', '32', '38', '35', '30', '36', '72'], 'RF_2017': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_2017': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'MI_2018': ['1', '20', '11', '32', '38', '35', '30', '36', '72'], 'RF_2018': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_2018': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'MI_2019': ['1', '20', '11', '32', '38', '35', '30', '36', '72'], 'RF_2019': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_2019': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'MI_2022': ['1', '20', '11', '32', '38', '35', '30', '36', '72'], 'RF_2022': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_2022': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'MI_2023': ['1', '20', '11', '32', '38', '35', '30', '36', '72'], 'RF_2023': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_2023': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'MI_2024': ['1', '20', '11', '32', '38', '35', '30', '36', '72'], 'RF_2024': ['10', '11', '32', '38', '35', '30', '31', '34', '72'], 'DT_
['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3', '36']}, 3453: {'MI': ['PTP2', '35', 'PP4_3', 'SPA3', 'PP1_1', '50', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PTP1', 'SPA1', 'PTP3', 'Total_SPA', 'PP2_2', '12'], 'RF': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 5660: {'MI': ['41', 'Bon', 'SPA2', '68', '35', 'SPA3', '61', '60', '42', 'PP3_2', 'PP2_1', '1', 'Total_AP', 'PP2_3', '82', 'PP4_4', '65', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'Total_Bon', '39', 'PP2_2', '74', 'PP4_5', '12'], 'RF': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', '82', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59'], 'DT': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59']}, 3500: {'MI': ['Total_PP', 'SPA3', '42', '72', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '36', 'FinalGradeInteger', 'PP2_3', 'PTP1', '20', '32', '18', '38', 'PTP3', 'Total_SPA', 'PP2_2', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', ...

# %%
exclusion_type = 'less_restricted'
exclude_columns = exclusion_columns_dicts[exclusion_type]
target_column = 'Course'

selected_features_course_less_restricted = feature_selection_analysis_generic(compose_datasets, all_lists_id, target_column, exclude_columns, methods=['MI', 'RF', 'DT'])
#save_selected_features_to_feather(selected_features_course_less_restricted, compose_datasets, target_column, output_dir, "predict_course", exclusion_type)
# Out:
# Feature Selection Analysis for the dataset with key: 242 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6769 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6835 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3453 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5660 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3500 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6711 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1179 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6721 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1055 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 3409 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2290 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 1121 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 6781 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4578 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 0 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2230 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 5590 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 4481 with target column: Course
# --------------------------------------------------
# Feature Selection Analysis for the dataset with key: 2300 with target column: Course
# --------------------------------------------------

# %%
doc.add_heading('Less restricted Results', 3)

# %%
print("Selected Features:")
print(selected_features_course_less_restricted)
print("Converted:")
converted_features = convert_feature_ids_to_activity_names_complete(selected_features_course_less_restricted, dataset_params)
print(converted_features)
# Out:
# Selected Features:
# {242: {'MI_2016': ['1', '20', '32', '38', '42', 'SPA1', 'SPA2', 'SPA3', 'PP1_2', 'PP1_3', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'RF_2016': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'DT_2016': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'MI_2017': ['1', '20', '32', '38', '42', 'SPA1', 'SPA2', 'SPA3', 'PP1_2', 'PP1_3', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'RF_2017': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'DT_2017': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'MI_2018': ['1', '20', '32', '38', '42', 'SPA1', 'SPA2', 'SPA3', 'PP1_2', 'PP1_3', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'RF_2018': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'DT_2018': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'MI_2019': ['1', '20', '32', '38', '42', 'SPA1', 'SPA2', 'SPA3', 'PP1_2', 'PP1_3', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'RF_2019': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'DT_2019': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'MI_2022': ['1', '20', '32', '38', '42', 'SPA1', 'SPA2', 'SPA3', 'PP1_2', 'PP1_3', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'Total_Bon', 'FinalGrade'], 'RF_2022': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'DT_2022': ['10', '11', '32', '38', '35', '50', '30', '31', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP', 'Total_PP', 'Total_SPA', 'FinalGrade'], 'MI_2023': ['1', '20', '32', '38', '42', 'SPA1', 'SPA2', 'SPA3', 'PP1_2', 'PP1_3', 'PP2_3', 'PP3_1', 'PP3_2', 'PP3_3', 'PTP1', 'PTP2', 'FinalGradeIn ...
# Converted:
# {242: {'MI_2016': ['Submission of CV on Moodle', 'Assessment of the week', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: FinalGradeInteger)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: Total_Bon)', 'Unknown (ID: FinalGrade)'], 'RF_2016': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_1)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_2)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: FinalGradeInteger)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: FinalGrade)'], 'DT_2016': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_1)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_2)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: FinalGradeInteger)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: FinalGrade)'], 'MI_2017': ['Submission of CV on Moodle', 'Assessment of the week', 'Submission of CV on Moodle', 'Parking', 'Leading is ...', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: FinalGradeInteger)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: Total_Bon)', 'Unknown (ID: FinalGrade)'], 'RF_2017': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_1)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_2)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: FinalGradeInteger)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: FinalGrade)'], 'DT_2017': ['Analysis of 3 CVs of candidates', 'Presentation on the analyzed CVs', 'Submission of CV on Moodle', 'Parking', '4x100m freestyle', 'Assessment of the week', 'SMART goals', "Maria's dashboard", 'Wolis', 'Ethical dilemmas', 'Unknown (ID: SPA1)', 'Unknown (ID: SPA2)', 'Unknown (ID: SPA3)', 'Unknown (ID: PP1_1)', 'Unknown (ID: PP1_2)', 'Unknown (ID: PP1_3)', 'Unknown (ID: PP2_1)', 'Unknown (ID: PP2_2)', 'Unknown (ID: PP2_3)', 'Unknown (ID: PP3_1)', 'Unknown (ID: PP3_2)', 'Unknown (ID: PP3_3)', 'Unknown (ID: PTP1)', 'Unknown (ID: PTP2)', 'Unknown (ID: PTP3)', 'Unknown (ID: FinalGradeInteger)', 'Unknown (ID: Total_AP)', 'Unknown (ID: Total_PP)', 'Unknown (ID: Total_SPA)', 'Unknown (ID: FinalGrade)'], 'MI_2018': ['Submission of CV on Mo ...

# %%
common_features_per_dataset = extract_common_features_per_compose_dataset(selected_features_sex_less_restricted, compose_datasets)
print(common_features_per_dataset)
# Out:
# {242: {'MI': ['PTP2', 'SPA2', '35', 'Total_PP', 'SPA3', 'FinalGrade', '42', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '20', 'PP1_3', 'Total_SPA', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 6769: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '123', 'PTP1', 'PP3_5', '38', '2', 'Total_SPA', 'Total_Bon', '72', '8', 'PP2_2', '50', 'PP3_2', 'PP2_1', '1', '30', 'PP3_3', '36'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '78', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', '123', 'PTP1', 'SPA1', '9', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP2_2', '30'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP3_3', 'PP2_2', '78', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', '1']}, 6835: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', 'PTP1', 'Total_PP', 'SPA3', '20', 'PP1_1', 'Total_SPA', '34', '50', 'PP3_2', 'PP2_1', 'PP3_3'], 'RF': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3', '36']}, 3453: {'MI': ['PTP2', '35', 'PP4_3', 'SPA3', 'PP1_1', '50', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PTP1', 'SPA1', 'PTP3', 'Total_SPA', 'PP2_2', '12'], 'RF': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 5660: {'MI': ['41', 'Bon', 'SPA2', '68', '35', 'SPA3', '61', '60', '42', 'PP3_2', 'PP2_1', '1', 'Total_AP', 'PP2_3', '82', 'PP4_4', '65', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'Total_Bon', '39', 'PP2_2', '74', 'PP4_5', '12'], 'RF': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', '82', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59'], 'DT': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59']}, 3500: {'MI': ['Total_PP', 'SPA3', '42', '72', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '36', 'FinalGradeInteger', 'PP2_3', 'PTP1', '20', '32', '18', '38', 'PTP3', 'Total_SPA', 'PP2_2', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', ...

# %%
print(common_features_per_dataset)
# Out:
# {242: {'MI': ['PTP2', 'SPA2', '35', 'Total_PP', 'SPA3', 'FinalGrade', '42', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '20', 'PP1_3', 'Total_SPA', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', 'FinalGrade', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 6769: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '123', 'PTP1', 'PP3_5', '38', '2', 'Total_SPA', 'Total_Bon', '72', '8', 'PP2_2', '50', 'PP3_2', 'PP2_1', '1', '30', 'PP3_3', '36'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '78', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', '1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', '123', 'PTP1', 'SPA1', '9', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP2_2', '30'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', '32', 'PP3_5', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '2', 'PP3_3', 'PP2_2', '78', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', '1']}, 6835: {'MI': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', 'PTP1', 'Total_PP', 'SPA3', '20', 'PP1_1', 'Total_SPA', '34', '50', 'PP3_2', 'PP2_1', 'PP3_3'], 'RF': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3'], 'DT': ['PTP2', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', 'SPA2', '11', '35', '10', 'PTP1', 'Total_PP', 'SPA1', 'SPA3', 'PP2_1', 'PP1_1', '32', '38', 'PTP3', 'Total_SPA', '34', '72', 'PP2_2', 'PP3_1', '50', 'PP3_2', 'PP1_2', '30', 'PP3_3', '36']}, 3453: {'MI': ['PTP2', '35', 'PP4_3', 'SPA3', 'PP1_1', '50', 'PP1_2', 'PP2_1', '1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', '31', 'PTP1', 'SPA1', 'PTP3', 'Total_SPA', 'PP2_2', '12'], 'RF': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', '72', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30'], 'DT': ['PTP2', 'SPA2', '11', '35', 'PP4_3', 'Total_PP', 'SPA3', 'PP1_1', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '31', 'PP2_3', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '30']}, 5660: {'MI': ['41', 'Bon', 'SPA2', '68', '35', 'SPA3', '61', '60', '42', 'PP3_2', 'PP2_1', '1', 'Total_AP', 'PP2_3', '82', 'PP4_4', '65', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'Total_Bon', '39', 'PP2_2', '74', 'PP4_5', '12'], 'RF': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', '82', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59'], 'DT': ['PTP2', '41', 'SPA2', '11', '35', 'Total_PP', 'SPA3', 'PP1_1', '60', 'PP3_1', 'PP3_2', 'PP1_2', 'PP3_3', '1', 'Total_AP', 'FinalGradeInteger', '76', '31', 'PP2_3', '10', 'PTP1', '62', 'SPA1', '32', 'PP4_4', '65', 'SPA4', '38', 'PP1_3', 'PTP3', 'Total_SPA', '34', 'PP2_2', '74', 'PP4_5', '30', '59']}, 3500: {'MI': ['Total_PP', 'SPA3', '42', '72', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '36', 'FinalGradeInteger', 'PP2_3', 'PTP1', '20', '32', '18', '38', 'PTP3', 'Total_SPA', 'PP2_2', '30'], 'RF': ['PTP2', 'SPA2', '11', '35', 'Total_PP', 'SPA3', ...

# %% [markdown]
# ## 5.4. Save Outputs from Feature Selection

# %%
doc.add_heading('Feature Selection Outputs', 2)

# %%
# Combine features across all years for each method
combined_features_finalgrade_more_restricted = combine_selected_features(selected_features_finalgrade_more_restricted)
combined_features_finalgrade_restricted = combine_selected_features(selected_features_finalgrade_restricted)
combined_features_finalgrade_less_restricted = combine_selected_features(selected_features_finalgrade_less_restricted)

combined_features_passed_more_restricted = combine_selected_features(selected_features_predict_passed_more_restricted)
combined_features_passed_restricted = combine_selected_features(selected_features_predict_passed_restricted)
combined_features_passed_less_restricted = combine_selected_features(selected_features_predict_passed_less_restricted)

combined_features_total_ap_more_restricted = combine_selected_features(selected_features_total_ap_more_restricted)
combined_features_total_ap_restricted = combine_selected_features(selected_features_total_ap_restricted)
combined_features_total_ap_less_restricted = combine_selected_features(selected_features_total_ap_less_restricted)

combined_features_total_pp_more_restricted = combine_selected_features(selected_features_total_pp_more_restricted)
combined_features_total_pp_restricted = combine_selected_features(selected_features_total_pp_restricted)
combined_features_total_pp_less_restricted = combine_selected_features(selected_features_total_pp_less_restricted)

combined_features_total_spa_more_restricted = combine_selected_features(selected_features_total_spa_more_restricted)
combined_features_total_spa_restricted = combine_selected_features(selected_features_total_spa_restricted)
combined_features_total_spa_less_restricted = combine_selected_features(selected_features_total_spa_less_restricted)

# Save the combined features
output_dir = 'output/feather_files'  # Replace with your actual output directory

# Save for FinalGrade
filename_suffix = 'predict_finalgrade'
save_combined_features_to_feather(combined_features_finalgrade_more_restricted, combined_df, 'FinalGrade', output_dir, filename_suffix, 'more_restricted')
save_combined_features_to_feather(combined_features_finalgrade_restricted, combined_df, 'FinalGrade', output_dir, filename_suffix, 'restricted')
save_combined_features_to_feather(combined_features_finalgrade_less_restricted, combined_df, 'FinalGrade', output_dir, filename_suffix, 'less_restricted')

# Save for Passed
filename_suffix = 'predict_passed'
save_combined_features_to_feather(combined_features_passed_more_restricted, combined_df, 'Passed', output_dir, filename_suffix, 'more_restricted')
save_combined_features_to_feather(combined_features_passed_restricted, combined_df, 'Passed', output_dir, filename_suffix, 'restricted')
save_combined_features_to_feather(combined_features_passed_less_restricted, combined_df, 'Passed', output_dir, filename_suffix, 'less_restricted')

# Save for Total_AP
filename_suffix = 'predict_total_ap'
save_combined_features_to_feather(combined_features_total_ap_more_restricted, combined_df, 'Total_AP', output_dir, filename_suffix, 'more_restricted')
save_combined_features_to_feather(combined_features_total_ap_regression_more_restricted, combined_df, 'Total_AP', output_dir, filename_suffix, 'more_restricted_regression')
save_combined_features_to_feather(combined_features_total_ap_restricted, combined_df, 'Total_AP', output_dir, filename_suffix, 'restricted')
save_combined_features_to_feather(combined_features_total_ap_less_restricted, combined_df, 'Total_AP', output_dir, filename_suffix, 'less_restricted')

# Save for Total_PP
filename_suffix = 'predict_total_pp'
save_combined_features_to_feather(combined_features_total_pp_more_restricted, combined_df, 'Total_PP', output_dir, filename_suffix, 'more_restricted')
save_combined_features_to_feather(combined_features_total_pp_regression_more_restricted, combined_df, 'Total_PP', output_dir, filename_suffix, 'more_restricted_regression')
save_combined_features_to_feather(combined_features_total_pp_restricted, combined_df, 'Total_PP', output_dir, filename_suffix, 'restricted')
save_combined_features_to_feather(combined_features_total_pp_less_restricted, combined_df, 'Total_PP', output_dir, filename_suffix, 'less_restricted')

# Save for Total_SPA
filename_suffix = 'predict_total_spa'
save_combined_features_to_feather(combined_features_total_spa_more_restricted, combined_df, 'Total_SPA', output_dir, filename_suffix, 'more_restricted')
save_combined_features_to_feather(combined_features_total_spa_regression_more_restricted, combined_df, 'Total_SPA', output_dir, filename_suffix, 'more_restricted_regression')
save_combined_features_to_feather(combined_features_total_spa_restricted, combined_df, 'Total_SPA', output_dir, filename_suffix, 'restricted')
save_combined_features_to_feather(combined_features_total_spa_less_restricted, combined_df, 'Total_SPA', output_dir, filename_suffix, 'less_restricted')
# Out:
# Saving DataFrame for method 'FR' with exclusion type 'more_restricted':
# - Number of features: 49
# - Shape of DataFrame: (7890, 50)
# - First few columns: ['23', '37', '133', '41', '35']...
# Success: Saved output/feather_files/predict_finalgrade_FR_more_restricted.feather with FinalGrade as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'more_restricted':
# - Number of features: 57
# - Shape of DataFrame: (7890, 58)
# - First few columns: ['23', '37', '2_11', '41', '11']...
# Success: Saved output/feather_files/predict_finalgrade_RF_more_restricted.feather with FinalGrade as the last column.
# Saving DataFrame for method 'Lasso' with exclusion type 'more_restricted':
# - Number of features: 61
# - Shape of DataFrame: (7890, 62)
# - First few columns: ['23', '37', '133', '41', '11']...
# Success: Saved output/feather_files/predict_finalgrade_Lasso_more_restricted.feather with FinalGrade as the last column.
# Saving DataFrame for method 'FR' with exclusion type 'restricted':
# - Number of features: 104
# - Shape of DataFrame: (7890, 105)
# - First few columns: ['23', '114', '133', '70', '41']...
# Success: Saved output/feather_files/predict_finalgrade_FR_restricted.feather with FinalGrade as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'restricted':
# - Number of features: 112
# - Shape of DataFrame: (7890, 113)
# - First few columns: ['23', '114', '41', '104', '116']...
# Success: Saved output/feather_files/predict_finalgrade_RF_restricted.feather with FinalGrade as the last column.
# Saving DataFrame for method 'Lasso' with exclusion type 'restricted':
# - Number of features: 126
# - Shape of DataFrame: (7890, 127)
# - First few columns: ['23', '114', '133', '70', '41']...
# Success: Saved output/feather_files/predict_finalgrade_Lasso_restricted.feather with FinalGrade as the last column.
# Saving DataFrame for method 'FR' with exclusion type 'less_restricted':
# - Number of features: 150
# - Shape of DataFrame: (7890, 151)
# - First few columns: ['23', '114', '133', 'PP2_4', '70']...
# Success: Saved output/feather_files/predict_finalgrade_FR_less_restricted.feather with FinalGrade as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'less_restricted':
# - Number of features: 151
# - Shape of DataFrame: (7890, 152)
# - First few columns: ['23', '114', '133', 'PP2_4', '70']...
# Success: Saved output/feather_files/predict_finalgrade_RF_less_restricted.feather with FinalGrade as the last column.
# Saving DataFrame for method 'Lasso' with exclusion type 'less_restricted':
# - Number of features: 89
# - Shape of DataFrame: (7890, 90)
# - First few columns: ['23', '114', '41', 'Week1_AP', 'SPA2']...
# Success: Saved output/feather_files/predict_finalgrade_Lasso_less_restricted.feather with FinalGrade as the last column.
# Saving DataFrame for method 'MI' with exclusion type 'more_restricted':
# - Number of features: 60
# - Shape of DataFrame: (7890, 61)
# - First few columns: ['23', '37', '133', '70', '41']...
# Success: Saved output/feather_files/predict_passed_MI_more_restricted.feather with Passed as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'more_restricted':
# - Number of features: 57
# - Shape of DataFrame: (7890, 58)
# - First few columns: ['23', '37', '2_11', '133', '70']...
# Success: Saved output/feather_files/predict_passed_RF_more_restricted.feather with Passed as the last column.
# Saving DataFrame for method 'DT' with exclusion type 'more_restricted':
# - Number of features: 42
# - Shape of DataFrame: (7890, 43)
# - First few columns: ['23', '37', '41', '11', '35']...
# Success: Saved output/feather_files/predict_passed_DT_more_restricted.feather with Passed as the last column.
# Saving DataFrame for method 'MI' with exclusion type 'restricted':
# - Number of features: 113
# - Shape of DataFrame: (7890, 114)
# - First few columns: ['23', '114', '133', '70', '41']...
# Success: Saved output/feather_files/predict_passed_MI_restricted.feather with Passed as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'restricted':
# - Number of features: 108
# - Shape of DataFrame: (7890, 109)
# - First few columns: ['23', '114', '133', '70', '41']...
# Success: Saved output/feather_files/predict_passed_RF_restricted.feather with Passed as the last column.
# Saving DataFrame for method 'DT' with exclusion type 'restricted':
# - Number of features: 36
# - Shape of DataFrame: (7890, 37)
# - First few columns: ['41', '12', '69', '129', '130']...
# Success: Saved output/feather_files/predict_passed_DT_restricted.feather with Passed as the last column.
# Saving DataFrame for method 'MI' with exclusion type 'less_restricted':
# - Number of features: 155
# - Shape of DataFrame: (7890, 156)
# - First few columns: ['23', '114', '133', 'PP2_4', '70']...
# Success: Saved output/feather_files/predict_passed_MI_less_restricted.feather with Passed as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'less_restricted':
# - Number of features: 12
# - Shape of DataFrame: (7890, 13)
# - First few columns: ['SPA4', 'FinalGradeInteger', 'Week3_AP', 'FinalGrade', 'Week3_PP']...
# Success: Saved output/feather_files/predict_passed_RF_less_restricted.feather with Passed as the last column.
# Saving DataFrame for method 'DT' with exclusion type 'less_restricted':
# - Number of features: 3
# - Shape of DataFrame: (7890, 4)
# - First few columns: ['Week1_AP', 'FinalGradeInteger', 'FinalGrade', 'Passed']...
# Success: Saved output/feather_files/predict_passed_DT_less_restricted.feather with Passed as the last column.
# Saving DataFrame for method 'MI' with exclusion type 'more_restricted':
# - Number of features: 61
# - Shape of DataFrame: (7890, 62)
# - First few columns: ['23', '37', '2_11', '133', '70']...
# Success: Saved output/feather_files/predict_total_ap_MI_more_restricted.feather with Total_AP as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'more_restricted':
# - Number of features: 62
# - Shape of DataFrame: (7890, 63)
# - First few columns: ['23', '37', '2_11', '41', '75']...
# Success: Saved output/feather_files/predict_total_ap_RF_more_restricted.feather with Total_AP as the last column.
# Saving DataFrame for method 'DT' with exclusion type 'more_restricted':
# - Number of features: 54
# - Shape of DataFrame: (7890, 55)
# - First few columns: ['23', '37', '41', '75', '11']...
# Success: Saved output/feather_files/predict_total_ap_DT_more_restricted.feather with Total_AP as the last column.
# Saving DataFrame for method 'FR' with exclusion type 'more_restricted_regression':
# - Number of features: 50
# - Shape of DataFrame: (7890, 51)
# - First few columns: ['23', '37', '133', '41', '35']...
# Success: Saved output/feather_files/predict_total_ap_FR_more_restricted_regression.feather with Total_AP as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'more_restricted_regression':
# - Number of features: 56
# - Shape of DataFrame: (7890, 57)
# - First few columns: ['23', '37', '2_11', '41', '11']...
# Success: Saved output/feather_files/predict_total_ap_RF_more_restricted_regression.feather with Total_AP as the last column.
# Saving DataFrame for method 'Lasso' with exclusion type 'more_restricted_regression':
# - Number of features: 62
# - Shape of DataFrame: (7890, 63)
# - First few columns: ['23', '37', '2_11', '41', '11']...
# Success: Saved output/feather_files/predict_total_ap_Lasso_more_restricted_regression.feather with Total_AP as the last column.
# Saving DataFrame for method 'MI' with exclusion type 'restricted':
# - Number of features: 107
# - Shape of DataFrame: (7890, 108)
# - First few columns: ['23', '114', '133', '70', '41']...
# Success: Saved output/feather_files/predict_total_ap_MI_restricted.feather with Total_AP as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'restricted':
# - Number of features: 109
# - Shape of DataFrame: (7890, 110)
# - First few columns: ['23', '114', '70', '41', '104']...
# Success: Saved output/feather_files/predict_total_ap_RF_restricted.feather with Total_AP as the last column.
# Saving DataFrame for method 'DT' with exclusion type 'restricted':
# - Number of features: 109
# - Shape of DataFrame: (7890, 110)
# - First few columns: ['23', '114', '133', '70', '41']...
# Success: Saved output/feather_files/predict_total_ap_DT_restricted.feather with Total_AP as the last column.
# Saving DataFrame for method 'MI' with exclusion type 'less_restricted':
# - Number of features: 154
# - Shape of DataFrame: (7890, 155)
# - First few columns: ['23', '114', '133', 'PP2_4', '70']...
# Success: Saved output/feather_files/predict_total_ap_MI_less_restricted.feather with Total_AP as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'less_restricted':
# - Number of features: 145
# - Shape of DataFrame: (7890, 146)
# - First few columns: ['23', '114', 'PP2_4', '70', 'Week1_AP']...
# Success: Saved output/feather_files/predict_total_ap_RF_less_restricted.feather with Total_AP as the last column.
# Saving DataFrame for method 'DT' with exclusion type 'less_restricted':
# - Number of features: 146
# - Shape of DataFrame: (7890, 147)
# - First few columns: ['23', '114', 'PP2_4', '70', 'Week1_AP']...
# Success: Saved output/feather_files/predict_total_ap_DT_less_restricted.feather with Total_AP as the last column.
# Saving DataFrame for method 'MI' with exclusion type 'more_restricted':
# - Number of features: 61
# - Shape of DataFrame: (7890, 62)
# - First few columns: ['23', '37', '133', '70', '41']...
# Success: Saved output/feather_files/predict_total_pp_MI_more_restricted.feather with Total_PP as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'more_restricted':
# - Number of features: 63
# - Shape of DataFrame: (7890, 64)
# - First few columns: ['23', '37', '2_11', '133', '41']...
# Success: Saved output/feather_files/predict_total_pp_RF_more_restricted.feather with Total_PP as the last column.
# Saving DataFrame for method 'DT' with exclusion type 'more_restricted':
# - Number of features: 59
# - Shape of DataFrame: (7890, 60)
# - First few columns: ['23', '37', '2_11', '41', '69']...
# Success: Saved output/feather_files/predict_total_pp_DT_more_restricted.feather with Total_PP as the last column.
# Saving DataFrame for method 'FR' with exclusion type 'more_restricted_regression':
# - Number of features: 50
# - Shape of DataFrame: (7890, 51)
# - First few columns: ['23', '37', '133', '41', '35']...
# Success: Saved output/feather_files/predict_total_pp_FR_more_restricted_regression.feather with Total_PP as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'more_restricted_regression':
# - Number of features: 58
# - Shape of DataFrame: (7890, 59)
# - First few columns: ['23', '37', '2_11', '133', '41']...
# Success: Saved output/feather_files/predict_total_pp_RF_more_restricted_regression.feather with Total_PP as the last column.
# Saving DataFrame for method 'Lasso' with exclusion type 'more_restricted_regression':
# - Number of features: 62
# - Shape of DataFrame: (7890, 63)
# - First few columns: ['23', '37', '2_11', '133', '41']...
# Success: Saved output/feather_files/predict_total_pp_Lasso_more_restricted_regression.feather with Total_PP as the last column.
# Saving DataFrame for method 'MI' with exclusion type 'restricted':
# - Number of features: 107
# - Shape of DataFrame: (7890, 108)
# - First few columns: ['23', '114', '133', '70', '41']...
# Success: Saved output/feather_files/predict_total_pp_MI_restricted.feather with Total_PP as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'restricted':
# - Number of features: 117
# - Shape of DataFrame: (7890, 118)
# - First few columns: ['23', '114', '41', '70', '104']...
# Success: Saved output/feather_files/predict_total_pp_RF_restricted.feather with Total_PP as the last column.
# Saving DataFrame for method 'DT' with exclusion type 'restricted':
# - Number of features: 108
# - Shape of DataFrame: (7890, 109)
# - First few columns: ['23', '114', '41', '70', '104']...
# Success: Saved output/feather_files/predict_total_pp_DT_restricted.feather with Total_PP as the last column.
# Saving DataFrame for method 'MI' with exclusion type 'less_restricted':
# - Number of features: 151
# - Shape of DataFrame: (7890, 152)
# - First few columns: ['23', '114', '133', 'PP2_4', '70']...
# Success: Saved output/feather_files/predict_total_pp_MI_less_restricted.feather with Total_PP as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'less_restricted':
# - Number of features: 143
# - Shape of DataFrame: (7890, 144)
# - First few columns: ['23', '114', 'PP2_4', '70', 'Week1_AP']...
# Success: Saved output/feather_files/predict_total_pp_RF_less_restricted.feather with Total_PP as the last column.
# Saving DataFrame for method 'DT' with exclusion type 'less_restricted':
# - Number of features: 145
# - Shape of DataFrame: (7890, 146)
# - First few columns: ['23', '114', 'PP2_4', '70', 'Week1_AP']...
# Success: Saved output/feather_files/predict_total_pp_DT_less_restricted.feather with Total_PP as the last column.
# Saving DataFrame for method 'MI' with exclusion type 'more_restricted':
# - Number of features: 62
# - Shape of DataFrame: (7890, 63)
# - First few columns: ['23', '37', '133', '70', '41']...
# Success: Saved output/feather_files/predict_total_spa_MI_more_restricted.feather with Total_SPA as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'more_restricted':
# - Number of features: 61
# - Shape of DataFrame: (7890, 62)
# - First few columns: ['23', '37', '2_11', '133', '41']...
# Success: Saved output/feather_files/predict_total_spa_RF_more_restricted.feather with Total_SPA as the last column.
# Saving DataFrame for method 'DT' with exclusion type 'more_restricted':
# - Number of features: 59
# - Shape of DataFrame: (7890, 60)
# - First few columns: ['23', '37', '133', '41', '75']...
# Success: Saved output/feather_files/predict_total_spa_DT_more_restricted.feather with Total_SPA as the last column.
# Saving DataFrame for method 'FR' with exclusion type 'more_restricted_regression':
# - Number of features: 50
# - Shape of DataFrame: (7890, 51)
# - First few columns: ['23', '37', '133', '41', '35']...
# Success: Saved output/feather_files/predict_total_spa_FR_more_restricted_regression.feather with Total_SPA as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'more_restricted_regression':
# - Number of features: 58
# - Shape of DataFrame: (7890, 59)
# - First few columns: ['23', '37', '2_11', '133', '41']...
# Success: Saved output/feather_files/predict_total_spa_RF_more_restricted_regression.feather with Total_SPA as the last column.
# Saving DataFrame for method 'Lasso' with exclusion type 'more_restricted_regression':
# - Number of features: 60
# - Shape of DataFrame: (7890, 61)
# - First few columns: ['23', '37', '133', '41', '11']...
# Success: Saved output/feather_files/predict_total_spa_Lasso_more_restricted_regression.feather with Total_SPA as the last column.
# Saving DataFrame for method 'MI' with exclusion type 'restricted':
# - Number of features: 116
# - Shape of DataFrame: (7890, 117)
# - First few columns: ['23', '114', '133', '70', '41']...
# Success: Saved output/feather_files/predict_total_spa_MI_restricted.feather with Total_SPA as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'restricted':
# - Number of features: 112
# - Shape of DataFrame: (7890, 113)
# - First few columns: ['23', '114', '133', '41', '70']...
# Success: Saved output/feather_files/predict_total_spa_RF_restricted.feather with Total_SPA as the last column.
# Saving DataFrame for method 'DT' with exclusion type 'restricted':
# - Number of features: 107
# - Shape of DataFrame: (7890, 108)
# - First few columns: ['23', '114', '133', '41', '70']...
# Success: Saved output/feather_files/predict_total_spa_DT_restricted.feather with Total_SPA as the last column.
# Saving DataFrame for method 'MI' with exclusion type 'less_restricted':
# - Number of features: 116
# - Shape of DataFrame: (7890, 117)
# - First few columns: ['23', '114', '133', '70', '41']...
# Success: Saved output/feather_files/predict_total_spa_MI_less_restricted.feather with Total_SPA as the last column.
# Saving DataFrame for method 'RF' with exclusion type 'less_restricted':
# - Number of features: 112
# - Shape of DataFrame: (7890, 113)
# - First few columns: ['23', '114', '133', '41', '70']...
# Success: Saved output/feather_files/predict_total_spa_RF_less_restricted.feather with Total_SPA as the last column.
# Saving DataFrame for method 'DT' with exclusion type 'less_restricted':
# - Number of features: 107
# - Shape of DataFrame: (7890, 108)
# - First few columns: ['23', '114', '133', '41', '70']...
# Success: Saved output/feather_files/predict_total_spa_DT_less_restricted.feather with Total_SPA as the last column.

# %%
doc.add_heading('Selected Features', 3)
doc.add_heading('More Restricted Results', 4)
print("For predicting 'Passed'")
print(extract_common_features(selected_features_predict_passed_more_restricted))
print(extract_common_features(combined_features_passed_more_restricted))
print("For predicting 'FinalGrade' from students that passed")
print(extract_common_features(selected_features_finalgrade_more_restricted))
print(extract_common_features(combined_features_finalgrade_more_restricted))
print("For predicting 'Total_AP'")
print(extract_common_features(selected_features_total_ap_more_restricted))
print(extract_common_features(combined_features_total_ap_regression_more_restricted))
print("For predicting 'Total_PP'")
print(extract_common_features(selected_features_total_pp_more_restricted))
print(extract_common_features(combined_features_total_pp_regression_more_restricted))
print("For predicting 'Total_SPA'")
print(extract_common_features(selected_features_total_spa_more_restricted))
print(extract_common_features(combined_features_total_spa_regression_more_restricted))
print("")
doc.add_heading('Restricted Results', 4)
print("For predicting 'Passed'")
print(extract_common_features(selected_features_predict_passed_restricted))
print(extract_common_features(combined_features_passed_restricted))
print("For predicting 'FinalGrade' from students that passed")
print(extract_common_features(selected_features_finalgrade_restricted))
print(extract_common_features(combined_features_finalgrade_restricted))
print("For predicting 'Total_AP'")
print(extract_common_features(selected_features_total_ap_restricted))
print(extract_common_features(combined_features_total_ap_restricted))
print("For predicting 'Total_PP'")
print(extract_common_features(selected_features_total_pp_restricted))
print(extract_common_features(combined_features_total_pp_restricted))
print("For predicting 'Total_SPA'")
print(extract_common_features(selected_features_total_spa_restricted))
print(extract_common_features(combined_features_total_spa_restricted))
print("")
doc.add_heading('Less Restricted Results', 4)
print("For predicting 'Passed'")
print(extract_common_features(selected_features_predict_passed_less_restricted))
print(extract_common_features(combined_features_passed_less_restricted))
print("For predicting 'FinalGrade' from students that passed")
print(extract_common_features(selected_features_finalgrade_less_restricted))
print(extract_common_features(combined_features_finalgrade_less_restricted))
print("For predicting 'Total_AP'")
print(extract_common_features(selected_features_total_ap_less_restricted))
print(extract_common_features(combined_features_total_ap_less_restricted))
print("For predicting 'Total_PP'")
print(extract_common_features(selected_features_total_pp_less_restricted))
print(extract_common_features(combined_features_total_pp_less_restricted))
print("For predicting 'Total_SPA'")
print(extract_common_features(selected_features_total_spa_less_restricted))
print(extract_common_features(combined_features_total_spa_less_restricted))
# Out:
# For predicting 'Passed'
# {'MI': ['38', '31', '34', '42', '10', '35', '30', '50', '20', '12', '32'], 'RF': ['31', '10', '35', '12', '30'], 'DT': []}
# {'MI': [], 'RF': [], 'DT': []}
# For predicting 'FinalGrade' from students that passed
# {'MI': [], 'RF': ['38', '34', '31', '11', '35', '10', '30', '50', '32'], 'DT': []}
# {'MI': [], 'RF': [], 'DT': []}
# For predicting 'Total_AP'
# {'MI': ['38', '31', '34', '42', '10', '35', '30', '50', '20', '12', '32', '1', '36'], 'RF': ['38', '31', '34', '32', '11', '35', '10', '12', '30'], 'DT': ['38', '32', '34', '30']}
# {'MI': [], 'RF': [], 'DT': []}
# For predicting 'Total_PP'
# {'MI': ['38', '31', '34', '42', '32', '10', '35', '50', '12', '30', '1', '36'], 'RF': ['38', '34', '31', '11', '35', '10', '30', '32'], 'DT': ['38', '34', '31', '32', '11', '35', '10', '30']}
# {'MI': [], 'RF': [], 'DT': []}
# For predicting 'Total_SPA'
# {'MI': ['34', '31', '42', '10', '35', '30', '12', '32', '1', '36'], 'RF': ['38', '31', '34', '32', '11', '35', '10', '30'], 'DT': ['38', '31', '32', '11', '35', '10', '30']}
# {'MI': [], 'RF': [], 'DT': []}
#
# For predicting 'Passed'
# {'MI': ['38', '31', '34', '72', '10', '30', '50', '20', '12', '32', '36'], 'RF': ['72'], 'DT': []}
# {'MI': [], 'RF': [], 'DT': []}
# For predicting 'FinalGrade' from students that passed
# {'MI': [], 'RF': ['38', '31', '34', '10', '35', '30', '50', '32'], 'DT': []}
# {'MI': [], 'RF': [], 'DT': []}
# For predicting 'Total_AP'
# {'MI': ['38', '31', '34', '42', '72', '35', '10', '30', '50', '20', '12', '32', '1', '36'], 'RF': ['38', '31', '34', '35', '30', '32'], 'DT': ['30', '10', '38']}
# {'MI': [], 'RF': [], 'DT': []}
# For predicting 'Total_PP'
# {'MI': ['38', '31', '34', '42', '72', '35', '10', '30', '50', '20', '12', '32', '1', '36'], 'RF': ['38', '31', '34', '11', '35', '10', '30', '32'], 'DT': ['38', '31', '34', '11', '10', '30', '32', '1']}
# {'MI': [], 'RF': [], 'DT': []}
# For predicting 'Total_SPA'
# {'MI': ['38', '31', '34', '42', '72', '35', '30', '50', '12', '32'], 'RF': ['38', '31', '34', '10', '11', '35', '30', '32'], 'DT': ['10', '11', '31']}
# {'MI': [], 'RF': [], 'DT': []}
#
# For predicting 'Passed'
# {'MI': ['Week1_AP', 'SPA2', '35', 'Total_PP', 'SPA3', 'Week3_PP', 'FinalGrade', '42', '72', 'Week1_PP', 'PP3_1', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', '36', 'Total_AP', 'FinalGradeInteger', 'Week3_AP', '31', 'Week2_PP', 'PP2_3', 'Week2_AP', '10', 'PTP1', 'SPA1', '20', '32', '38', 'PP1_3', '34', 'PP2_2', '12', '30'], 'RF': ['FinalGradeInteger', 'FinalGrade'], 'DT': []}
# {'MI': [], 'RF': [], 'DT': []}
# For predicting 'FinalGrade' from students that passed
# {'MI': [], 'RF': ['PTP2', 'Bon', 'SPA2', 'Week1_AP', '11', '35', 'Total_PP', 'SPA3', 'Week3_PP', 'Week1_PP', 'PP3_1', 'PP1_2', 'Total_AP', 'FinalGradeInteger', 'Week3_AP', '31', 'Week2_PP', 'Week2_AP', '10', 'SPA1', '32', '38', 'PTP3', 'Total_SPA', '34', '30'], 'DT': []}
# {'MI': [], 'RF': [], 'DT': []}
# For predicting 'Total_AP'
# {'MI': ['Week1_AP', 'SPA2', '35', 'Total_PP', 'SPA3', 'FinalGrade', 'Week3_PP', '42', '72', 'Week1_PP', 'PP3_1', '50', 'PP3_2', 'PP2_1', 'Passed', 'PP3_3', '1', '36', 'FinalGradeInteger', 'Week3_AP', '31', 'Week2_PP', 'Week2_AP', 'SPA1', '32', '38', 'Total_SPA', '34', 'PP2_2', '12', '30'], 'RF': ['FinalGradeInteger', '38', 'Week3_AP', 'Total_SPA', 'FinalGrade', 'Week3_PP', 'Week1_AP', 'SPA2', 'PP2_3', 'Week2_PP', 'Week2_AP', '35', '30', 'Total_PP', 'SPA3', '32'], 'DT': ['38', 'PTP3', 'Week3_AP', 'Total_SPA', 'FinalGrade', 'Week3_PP', 'Week1_AP', '31', 'Week2_AP', '11', 'Week1_PP', '30', 'Total_PP', 'SPA1', '32']}
# {'MI': [], 'RF': [], 'DT': []}
# For predicting 'Total_PP'
# {'MI': ['PTP2', 'Week1_AP', 'SPA2', '35', 'SPA3', 'PP1_1', 'Week3_PP', 'FinalGrade', '42', '72', 'Week1_PP', 'PP3_1', '50', 'PP3_2', 'PP1_2', 'Passed', 'PP2_1', '1', '36', 'PP3_3', 'Total_AP', 'FinalGradeInteger', 'Week3_AP', '31', 'Week2_PP', 'PP2_3', 'Week2_AP', '10', 'PTP1', 'SPA1', '20', '32', '38', 'PTP3', 'PP1_3', 'Total_SPA', 'PP2_2', '12', '30'], 'RF': ['PTP2', 'Week1_AP', 'SPA2', '11', '35', 'SPA3', 'PP1_1', 'FinalGrade', 'Week3_PP', 'Week1_PP', 'PP3_2', 'PP1_2', 'PP2_1', 'PP3_3', 'Total_AP', 'FinalGradeInteger', 'Week3_AP', '31', 'PP2_3', 'Week2_PP', 'Week2_AP', '10', 'PTP1', 'SPA1', '32', '38', 'PP1_3', 'PTP3', 'Total_SPA', 'PP2_2', '30'], 'DT': ['PTP2', 'Total_AP', 'PTP3', 'Week3_AP', 'PP1_3', 'Week3_PP', 'FinalGrade', 'Week1_AP', 'Week2_PP', 'Total_SPA', 'Week2_AP', 'Week1_PP', 'SPA3', 'PP1_2', '30']}
# {'MI': [], 'RF': [], 'DT': []}
# For predicting 'Total_SPA'
# {'MI': ['38', '31', '34', '42', '72', '35', '30', '50', '12', '32'], 'RF': ['38', '31', '34', '10', '11', '35', '30', '32'], 'DT': ['10', '11', '31']}
# {'MI': [], 'RF': [], 'DT': []}

# %%
print(get_activity_name_by_id(38, dataset_params, 2016))
print(get_activity_name_by_id(31, dataset_params, 2016))
print(get_activity_name_by_id(34, dataset_params, 2016))
print(get_activity_name_by_id(42, dataset_params, 2016))
print(get_activity_name_by_id(10, dataset_params, 2016))
print(get_activity_name_by_id(35, dataset_params, 2016))
print(get_activity_name_by_id(30, dataset_params, 2016))
print(get_activity_name_by_id(50, dataset_params, 2016))
print(get_activity_name_by_id(20, dataset_params, 2016))
print(get_activity_name_by_id(12, dataset_params, 2016))
print(get_activity_name_by_id(32, dataset_params, 2016))
# Out:
# Parking
# Maria's dashboard
# Wolis
# Leading is ...
# Analysis of 3 CVs of candidates
# 4x100m freestyle
# SMART goals
# Assessment of the week
# Assessment of the week
# Psychotechnical test (Moodle)
# Submission of CV on Moodle

# %%
# Save the document at the end
save_document('feature_selection_output.docx')
# Out:
# Document saved as feature_selection_output.docx

# %% [markdown]
# # 6. Clustering Analysis

# %%
doc = Document()
doc.add_heading('Output of Clustering Report', 0)

# %% [markdown]
# ## 6.1 Methods

# %%
# Elbow Method for determining the optimal number of clusters
def plot_elbow_method(X, year, max_clusters=10, save_path='Charts/Elbow'):
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    distortions = []
    for i in range(1, max_clusters + 1):
        kmeans = KMeans(n_clusters=i, random_state=0, n_init=10)
        kmeans.fit(X)
        distortions.append(kmeans.inertia_)

    plt.figure()
    plt.plot(range(1, max_clusters + 1), distortions, marker='o')
    plt.title(f'Elbow Method for Optimal Number of Clusters ({year})')
    plt.xlabel('Number of Clusters')
    plt.ylabel('Distortion')
    plt.savefig(f'{save_path}/Elbow_Method_{year}.png')
    plt.close()

# Display PCA components and their contribution to the Principal Components
def display_pca_components(pca, feature_names):
    components_df = pd.DataFrame(pca.components_, columns=feature_names, index=[f'PC{i+1}' for i in range(pca.n_components_)])
    explained_variance = pca.explained_variance_ratio_
    print("PCA Components and their contribution to the Principal Components:")
    print(components_df)
    print("\nExplained variance ratio per Principal Component:")
    for i, variance in enumerate(explained_variance):
        print(f"PC{i+1}: {variance:.4f}")

# Perform K-Means clustering with optional PCA
def perform_kmeans_clustering(df, features, year, num_clusters, use_pca=True, save_path='Charts/Clustering'):
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    # Data preparation
    X = df[features].values
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    if use_pca:
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(X_scaled)
        display_pca_components(pca, features)

    # K-Means Clustering
    kmeans = KMeans(n_clusters=num_clusters, init='k-means++', random_state=0, n_init=10)
    y_kmeans = kmeans.fit_predict(X_scaled)

    # Evaluate clustering
    silhouette_avg = silhouette_score(X_scaled, y_kmeans)
    davies_bouldin = davies_bouldin_score(X_scaled, y_kmeans)
    calinski_harabasz = calinski_harabasz_score(X_scaled, y_kmeans)

    print(f"Silhouette Score for {num_clusters} clusters: {silhouette_avg:.3f}")
    print(f"Davies-Bouldin Index for {num_clusters} clusters: {davies_bouldin:.3f}")
    print(f"Calinski-Harabasz Index for {num_clusters} clusters: {calinski_harabasz:.3f}")

    # Plotting the clusters with PCA-reduced data if PCA is used
    if use_pca:
        centroids = kmeans.cluster_centers_
        centroids_pca = pca.transform(centroids)
        plt.figure()
        colors = ['red', 'green', 'blue', 'purple', 'orange', 'brown']  # Extend this list if needed
        for i in range(num_clusters):
            plt.scatter(X_pca[y_kmeans == i, 0], X_pca[y_kmeans == i, 1], color=colors[i % len(colors)], label=f'Cluster {i+1}')
        plt.scatter(centroids_pca[:, 0], centroids_pca[:, 1], s=100, c='yellow', label='Centroids', marker='x')
        plt.title(f'PCA-Reduced K-Means Clustering of {num_clusters} Clusters ({year})')
        plt.xlabel('Principal Component 1')
        plt.ylabel('Principal Component 2')
        plt.legend()
        plt.savefig(f'{save_path}/PCA_KMeans_{num_clusters}_Clusters_{year}.png')
        plt.close()
    elif X_scaled.shape[1] == 2:  # If no PCA and only 2 features, plot directly
        plt.figure()
        colors = ['red', 'green', 'blue', 'purple', 'orange', 'brown']
        for i in range(num_clusters):
            plt.scatter(X_scaled[y_kmeans == i, 0], X_scaled[y_kmeans == i, 1], color=colors[i % len(colors)], label=f'Cluster {i+1}')
        plt.title(f'K-Means Clustering of {num_clusters} Clusters ({year})')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.legend()
        plt.savefig(f'{save_path}/KMeans_{num_clusters}_Clusters_{year}.png')
        plt.close()

# Perform Hierarchical Clustering with optional PCA
def perform_hierarchical_clustering(df, features, year, num_clusters, use_pca=True, save_path='output/Clustering'):
    if not os.path.exists(save_path):
        os.makedirs(save_path)

    X = df[features].values
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    if use_pca:
        pca = PCA(n_components=2)
        X_pca = pca.fit_transform(X_scaled)
        display_pca_components(pca, features)

    # Hierarchical Clustering
    hc = AgglomerativeClustering(n_clusters=num_clusters, linkage='ward')
    y_hc = hc.fit_predict(X_scaled)

    # Evaluate clustering
    silhouette_avg = silhouette_score(X_scaled, y_hc)
    davies_bouldin = davies_bouldin_score(X_scaled, y_hc)
    calinski_harabasz = calinski_harabasz_score(X_scaled, y_hc)

    print(f"Silhouette Score for {num_clusters} clusters: {silhouette_avg:.3f}")
    print(f"Davies-Bouldin Index for {num_clusters} clusters: {davies_bouldin:.3f}")
    print(f"Calinski-Harabasz Index for {num_clusters} clusters: {calinski_harabasz:.3f}")

    # Plotting the clusters with PCA-reduced data if PCA is used
    if use_pca:
        plt.figure()
        colors = ['red', 'blue', 'green', 'purple', 'orange', 'brown']  # Extend this list if needed
        for i in range(num_clusters):
            plt.scatter(X_pca[y_hc == i, 0], X_pca[y_hc == i, 1], color=colors[i % len(colors)], label=f'Cluster {i+1}')
        plt.title(f'PCA-Reduced Hierarchical Clustering of Students ({year})')
        plt.xlabel('Principal Component 1')
        plt.ylabel('Principal Component 2')
        plt.legend()
        plt.savefig(f'{save_path}/PCA_Hierarchical_Clusters_{year}.png')
        plt.close()

        # Plotting the Dendrogram without labels on the x-axis
        plt.figure()
        dendrogram = sch.dendrogram(sch.linkage(X_scaled, method='ward'), no_labels=True)
        plt.title(f'Dendrogram for Hierarchical Clustering ({year})')
        plt.xlabel('Students')
        plt.ylabel('Euclidean distances')
        plt.savefig(f'{save_path}/Dendrogram_{year}.png')
        plt.close()

        # Plotting centroids for Hierarchical Clustering
        cluster_centers = np.array([X_scaled[y_hc == i].mean(axis=0) for i in range(num_clusters)])
        centroids_pca = pca.transform(cluster_centers)
        plt.figure()
        for i in range(num_clusters):
            plt.scatter(X_pca[y_hc == i, 0], X_pca[y_hc == i, 1], color=colors[i % len(colors)], label=f'Cluster {i+1}')
        plt.scatter(centroids_pca[:, 0], centroids_pca[:, 1], s=100, c='yellow', label='Cluster Centers', marker='x')
        plt.title(f'PCA-Reduced Hierarchical Clustering with Cluster Centers ({year})')
        plt.xlabel('Principal Component 1')
        plt.ylabel('Principal Component 2')
        plt.legend()
        plt.savefig(f'{save_path}/PCA_Hierarchical_Centers_{year}.png')
        plt.close()
    elif X_scaled.shape[1] == 2:  # If no PCA and only 2 features, plot directly
        plt.figure()
        colors = ['red', 'blue', 'green', 'purple', 'orange', 'brown']
        for i in range(num_clusters):
            plt.scatter(X_scaled[y_hc == i, 0], X_scaled[y_hc == i, 1], color=colors[i % len(colors)], label=f'Cluster {i+1}')
        plt.title(f'Hierarchical Clustering of Students ({year})')
        plt.xlabel('Feature 1')
        plt.ylabel('Feature 2')
        plt.legend()
        plt.savefig(f'{save_path}/Hierarchical_Clusters_{year}.png')
        plt.close()

# %% [markdown]
# ## 6.2. Methods Application

# %% [markdown]
# ### 6.3.1. Clustering Features: Totals

# %%
doc.add_heading('Clustering Features: Totals', 1)
doc.add_heading('For each year', 2)

# %%
for year in dataset_years:
    clustering_features_totals = [
        col for col in all_lists[str(year)]['created_columns']['TotalColumns']
    ]

    # Prepare the data for clustering
    if all(feature in datasets[year].columns for feature in clustering_features_totals):
        available_features = [feature for feature in clustering_features_totals if feature in datasets[year].columns]
        df = datasets[year][available_features]
        X = StandardScaler().fit_transform(df)

        # Apply Elbow Method
        print(f"Applying Elbow Method for year {year}")
        plot_elbow_method(X, year)

        # Perform clustering and PCA
        for n_clusters in [2, 3, 4]:
            print(f"Running KMeans for {n_clusters} clusters in {year}")
            perform_kmeans_clustering(datasets[year], available_features, year, n_clusters, use_pca=False)

            print(f"Running Hierarchical Clustering for {n_clusters} clusters in {year}")
            perform_hierarchical_clustering(datasets[year], available_features, year, n_clusters, use_pca=False)
    else:
        print(f"Skipping year {year}: Required columns not found in dataset.")
# Out:
# Applying Elbow Method for year 2016
# Running KMeans for 2 clusters in 2016
# Silhouette Score for 2 clusters: 0.809
# Davies-Bouldin Index for 2 clusters: 0.322
# Calinski-Harabasz Index for 2 clusters: 1542.388
# Running Hierarchical Clustering for 2 clusters in 2016
# Silhouette Score for 2 clusters: 0.819
# Davies-Bouldin Index for 2 clusters: 0.141
# Calinski-Harabasz Index for 2 clusters: 1512.526
# Calinski-Harabasz Index for 3 clusters: 1660.461
# Running KMeans for 4 clusters in 2023
# Silhouette Score for 4 clusters: 0.326
# Davies-Bouldin Index for 4 clusters: 0.739
# Calinski-Harabasz Index for 4 clusters: 1623.461
# Running Hierarchical Clustering for 4 clusters in 2023
# Silhouette Score for 4 clusters: 0.319
# Davies-Bouldin Index for 4 clusters: 0.811
# Calinski-Harabasz Index for 4 clusters: 1463.431
# Applying Elbow Method for year 2024
# Running KMeans for 2 clusters in 2024
# Silhouette Score for 2 clusters: 0.764
# Davies-Bouldin Index for 2 clusters: 0.393
# Calinski-Harabasz Index for 2 clusters: 1289.933
# Running Hierarchical Clustering for 2 clusters in 2024
# Silhouette Score for 2 clusters: 0.754
# Davies-Bouldin Index for 2 clusters: 0.506
# Calinski-Harabasz Index for 2 clusters: 1258.797
# Running KMeans for 3 clusters in 2024
# Silhouette Score for 3 clusters: 0.756
# Davies-Bouldin Index for 3 clusters: 0.363
# Calinski-Harabasz Index for 3 clusters: 2036.112
# Running Hierarchical Clustering for 3 clusters in 2024
# Silhouette Score for 3 clusters: 0.756
# Davies-Bouldin Index for 3 clusters: 0.431
# Calinski-Harabasz Index for 3 clusters: 1967.977
# Running KMeans for 4 clusters in 2024
# Silhouette Score for 4 clusters: 0.428
# Davies-Bouldin Index for 4 clusters: 0.689
# Calinski-Harabasz Index for 4 clusters: 2010.887
# Running Hierarchical Clustering for 4 clusters in 2024
# Silhouette Score for 4 clusters: 0.752
# Davies-Bouldin Index for 4 clusters: 0.793
# Calinski-Harabasz Index for 4 clusters: 1786.779

# %%
dataset_years = datasets.keys()
for year in dataset_years:
    clustering_features_totals = [
        col for col in all_lists[str(year)]['created_columns']['TotalColumns']
    ]

    # Prepare the data for clustering
    if all(feature in datasets[year].columns for feature in clustering_features_totals):
        available_features = [feature for feature in clustering_features_totals if feature in datasets[year].columns]
        df = datasets[year][available_features]
        X = StandardScaler().fit_transform(df)

        # Apply Elbow Method
        print(f"Applying Elbow Method for year {year}")
        plot_elbow_method(X, year)

        # Perform clustering and PCA
        for n_clusters in [2, 3, 4]:
            print(f"Running KMeans for {n_clusters} clusters in {year}")
            perform_kmeans_clustering(datasets[year], available_features, year, n_clusters, use_pca=True)

            print(f"Running Hierarchical Clustering for {n_clusters} clusters in {year}")
            perform_hierarchical_clustering(datasets[year], available_features, year, n_clusters, use_pca=True)
    else:
        print(f"Skipping year {year}: Required columns not found in dataset.")
# Out:
# Applying Elbow Method for year 2016
# Running KMeans for 2 clusters in 2016
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.582978 -0.580650  -0.568298   0.004496
# PC2 -0.030514  0.015002   0.023879   0.999136
#
# Explained variance ratio per Principal Component:
# PC1: 0.6786
# PC2: 0.2504
# Silhouette Score for 2 clusters: 0.809
# Davies-Bouldin Index for 2 clusters: 0.322
# Calinski-Harabasz Index for 2 clusters: 1542.388
# Running Hierarchical Clustering for 2 clusters in 2016
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.582978 -0.580650  -0.568298   0.004496
# PC2 -0.030514  0.015002   0.023879   0.999136
#
# Explained variance ratio per Principal Component:
# PC1: 0.6786
# PC2: 0.2504
# Silhouette Score for 2 clusters: 0.819
# Davies-Bouldin Index for 2 clusters: 0.141
# Calinski-Harabasz Index for 2 clusters: 1512.526
# Running KMeans for 3 clusters in 2016
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.582978 -0.580650  -0.568298   0.004496
# PC2 -0.030514  0.015002   0.023879   0.999136
#
# Explained variance ratio per Principal Component:
# PC1: 0.6786
# PC2: 0.2504
# Silhouette Score for 3 clusters: 0.836
# Davies-Bouldin Index for 3 clusters: 0.279
# Calinski-Harabasz Index for 3 clusters: 2665.552
# Running Hierarchical Clustering for 3 clusters in 2016
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.582978 -0.580650  -0.568298   0.004496
# PC2 -0.030514  0.015002   0.023879   0.999136
#
# Explained variance ratio per Principal Component:
# PC1: 0.6786
# PC2: 0.2504
# Silhouette Score for 3 clusters: 0.836
# Davies-Bouldin Index for 3 clusters: 0.213
# Calinski-Harabasz Index for 3 clusters: 2578.661
# Running KMeans for 4 clusters in 2016
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.582978 -0.580650  -0.568298   0.004496
# PC2 -0.030514  0.015002   0.023879   0.999136
#
# Explained variance ratio per Principal Component:
# PC1: 0.6786
# PC2: 0.2504
# Silhouette Score for 4 clusters: 0.419
# Davies-Bouldin Index for 4 clusters: 0.625
# Calinski-Harabasz Index for 4 clusters: 2750.951
# Running Hierarchical Clustering for 4 clusters in 2016
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.582978 -0.580650  -0.568298   0.004496
# PC2 -0.030514  0.015002   0.023879   0.999136
#
# Explained variance ratio per Principal Component:
# PC1: 0.6786
# PC2: 0.2504
# Silhouette Score for 4 clusters: 0.441
# Davies-Bouldin Index for 4 clusters: 0.625
# Calinski-Harabasz Index for 4 clusters: 2673.296
# Applying Elbow Method for year 2017
# Running KMeans for 2 clusters in 2017
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.591244 -0.592596  -0.547041  -0.002706
# PC2 -0.005006  0.053430  -0.057401   0.996908
#
# Explained variance ratio per Principal Component:
# PC1: 0.6468
# PC2: 0.2512
# Silhouette Score for 2 clusters: 0.793
# Davies-Bouldin Index for 2 clusters: 0.295
# Calinski-Harabasz Index for 2 clusters: 1440.347
# Running Hierarchical Clustering for 2 clusters in 2017
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.591244 -0.592596  -0.547041  -0.002706
# PC2 -0.005006  0.053430  -0.057401   0.996908
#
# Explained variance ratio per Principal Component:
# PC1: 0.6468
# PC2: 0.2512
# Silhouette Score for 2 clusters: 0.791
# Davies-Bouldin Index for 2 clusters: 0.282
# Calinski-Harabasz Index for 2 clusters: 1413.282
# Running KMeans for 3 clusters in 2017
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.591244 -0.592596  -0.547041  -0.002706
# PC2 -0.005006  0.053430  -0.057401   0.996908
#
# Explained variance ratio per Principal Component:
# PC1: 0.6468
# PC2: 0.2512
# Silhouette Score for 3 clusters: 0.830
# Davies-Bouldin Index for 3 clusters: 0.267
# Calinski-Harabasz Index for 3 clusters: 2353.784
# Running Hierarchical Clustering for 3 clusters in 2017
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.591244 -0.592596  -0.547041  -0.002706
# PC2 -0.005006  0.053430  -0.057401   0.996908
#
# Explained variance ratio per Principal Component:
# PC1: 0.6468
# PC2: 0.2512
# Silhouette Score for 3 clusters: 0.830
# Davies-Bouldin Index for 3 clusters: 0.273
# Calinski-Harabasz Index for 3 clusters: 2338.163
# Running KMeans for 4 clusters in 2017
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.591244 -0.592596  -0.547041  -0.002706
# PC2 -0.005006  0.053430  -0.057401   0.996908
#
# Explained variance ratio per Principal Component:
# PC1: 0.6468
# PC2: 0.2512
# Silhouette Score for 4 clusters: 0.774
# Davies-Bouldin Index for 4 clusters: 0.284
# Calinski-Harabasz Index for 4 clusters: 2942.418
# Running Hierarchical Clustering for 4 clusters in 2017
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.591244 -0.592596  -0.547041  -0.002706
# PC2 -0.005006  0.053430  -0.057401   0.996908
#
# Explained variance ratio per Principal Component:
# PC1: 0.6468
# PC2: 0.2512
# Silhouette Score for 4 clusters: 0.774
# Davies-Bouldin Index for 4 clusters: 0.291
# Calinski-Harabasz Index for 4 clusters: 2912.722
# Applying Elbow Method for year 2018
# Running KMeans for 2 clusters in 2018
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.595853 -0.595529  -0.538780  -0.004568
# PC2 -0.049628  0.011320   0.033909   0.998128
#
# Explained variance ratio per Principal Component:
# PC1: 0.5786
# PC2: 0.2506
# Silhouette Score for 2 clusters: 0.785
# Davies-Bouldin Index for 2 clusters: 0.481
# Calinski-Harabasz Index for 2 clusters: 859.538
# Running Hierarchical Clustering for 2 clusters in 2018
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.595853 -0.595529  -0.538780  -0.004568
# PC2 -0.049628  0.011320   0.033909   0.998128
#
# Explained variance ratio per Principal Component:
# PC1: 0.5786
# PC2: 0.2506
# Silhouette Score for 2 clusters: 0.780
# Davies-Bouldin Index for 2 clusters: 0.518
# Calinski-Harabasz Index for 2 clusters: 814.967
# Running KMeans for 3 clusters in 2018
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.595853 -0.595529  -0.538780  -0.004568
# PC2 -0.049628  0.011320   0.033909   0.998128
#
# Explained variance ratio per Principal Component:
# PC1: 0.5786
# PC2: 0.2506
# Silhouette Score for 3 clusters: 0.810
# Davies-Bouldin Index for 3 clusters: 0.399
# Calinski-Harabasz Index for 3 clusters: 1160.151
# Running Hierarchical Clustering for 3 clusters in 2018
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.595853 -0.595529  -0.538780  -0.004568
# PC2 -0.049628  0.011320   0.033909   0.998128
#
# Explained variance ratio per Principal Component:
# PC1: 0.5786
# PC2: 0.2506
# Silhouette Score for 3 clusters: 0.808
# Davies-Bouldin Index for 3 clusters: 0.441
# Calinski-Harabasz Index for 3 clusters: 1146.982
# Running KMeans for 4 clusters in 2018
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.595853 -0.595529  -0.538780  -0.004568
# PC2 -0.049628  0.011320   0.033909   0.998128
#
# Explained variance ratio per Principal Component:
# PC1: 0.5786
# PC2: 0.2506
# Silhouette Score for 4 clusters: 0.758
# Davies-Bouldin Index for 4 clusters: 0.448
# Calinski-Harabasz Index for 4 clusters: 1560.940
# Running Hierarchical Clustering for 4 clusters in 2018
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.595853 -0.595529  -0.538780  -0.004568
# PC2 -0.049628  0.011320   0.033909   0.998128
#
# Explained variance ratio per Principal Component:
# PC1: 0.5786
# PC2: 0.2506
# Silhouette Score for 4 clusters: 0.759
# Davies-Bouldin Index for 4 clusters: 0.480
# Calinski-Harabasz Index for 4 clusters: 1536.102
# Applying Elbow Method for year 2019
# Running KMeans for 2 clusters in 2019
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.593749 -0.586502  -0.550874  -0.003991
# PC2 -0.048715  0.034441   0.008605   0.998182
#
# Explained variance ratio per Principal Component:
# PC1: 0.6144
# PC2: 0.2507
# Silhouette Score for 2 clusters: 0.786
# Davies-Bouldin Index for 2 clusters: 0.411
# Calinski-Harabasz Index for 2 clusters: 937.800
# Running Hierarchical Clustering for 2 clusters in 2019
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.593749 -0.586502  -0.550874  -0.003991
# PC2 -0.048715  0.034441   0.008605   0.998182
#
# Explained variance ratio per Principal Component:
# PC1: 0.6144
# PC2: 0.2507
# Silhouette Score for 2 clusters: 0.778
# Davies-Bouldin Index for 2 clusters: 0.405
# Calinski-Harabasz Index for 2 clusters: 903.825
# Running KMeans for 3 clusters in 2019
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.593749 -0.586502  -0.550874  -0.003991
# PC2 -0.048715  0.034441   0.008605   0.998182
#
# Explained variance ratio per Principal Component:
# PC1: 0.6144
# PC2: 0.2507
# Silhouette Score for 3 clusters: 0.816
# Davies-Bouldin Index for 3 clusters: 0.307
# Calinski-Harabasz Index for 3 clusters: 1323.234
# Running Hierarchical Clustering for 3 clusters in 2019
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.593749 -0.586502  -0.550874  -0.003991
# PC2 -0.048715  0.034441   0.008605   0.998182
#
# Explained variance ratio per Principal Component:
# PC1: 0.6144
# PC2: 0.2507
# Silhouette Score for 3 clusters: 0.811
# Davies-Bouldin Index for 3 clusters: 0.360
# Calinski-Harabasz Index for 3 clusters: 1305.294
# Running KMeans for 4 clusters in 2019
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.593749 -0.586502  -0.550874  -0.003991
# PC2 -0.048715  0.034441   0.008605   0.998182
#
# Explained variance ratio per Principal Component:
# PC1: 0.6144
# PC2: 0.2507
# Silhouette Score for 4 clusters: 0.764
# Davies-Bouldin Index for 4 clusters: 0.298
# Calinski-Harabasz Index for 4 clusters: 1715.257
# Running Hierarchical Clustering for 4 clusters in 2019
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.593749 -0.586502  -0.550874  -0.003991
# PC2 -0.048715  0.034441   0.008605   0.998182
#
# Explained variance ratio per Principal Component:
# PC1: 0.6144
# PC2: 0.2507
# Silhouette Score for 4 clusters: 0.765
# Davies-Bouldin Index for 4 clusters: 0.379
# Calinski-Harabasz Index for 4 clusters: 1685.897
# Applying Elbow Method for year 2022
# Running KMeans for 2 clusters in 2022
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.581066 -0.578931  -0.572015       -0.0
# PC2  0.318864  0.484711  -0.814482       -0.0
#
# Explained variance ratio per Principal Component:
# PC1: 0.8304
# PC2: 0.0918
# Silhouette Score for 2 clusters: 0.782
# Davies-Bouldin Index for 2 clusters: 0.486
# Calinski-Harabasz Index for 2 clusters: 2527.851
# Running Hierarchical Clustering for 2 clusters in 2022
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.581066 -0.578931  -0.572015       -0.0
# PC2  0.318864  0.484711  -0.814482       -0.0
#
# Explained variance ratio per Principal Component:
# PC1: 0.8304
# PC2: 0.0918
# Silhouette Score for 2 clusters: 0.770
# Davies-Bouldin Index for 2 clusters: 0.606
# Calinski-Harabasz Index for 2 clusters: 2385.140
# Running KMeans for 3 clusters in 2022
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.581066 -0.578931  -0.572015       -0.0
# PC2  0.318864  0.484711  -0.814482       -0.0
#
# Explained variance ratio per Principal Component:
# PC1: 0.8304
# PC2: 0.0918
# Silhouette Score for 3 clusters: 0.746
# Davies-Bouldin Index for 3 clusters: 0.770
# Calinski-Harabasz Index for 3 clusters: 1968.432
# Running Hierarchical Clustering for 3 clusters in 2022
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.581066 -0.578931  -0.572015       -0.0
# PC2  0.318864  0.484711  -0.814482       -0.0
#
# Explained variance ratio per Principal Component:
# PC1: 0.8304
# PC2: 0.0918
# Silhouette Score for 3 clusters: 0.746
# Davies-Bouldin Index for 3 clusters: 0.770
# Calinski-Harabasz Index for 3 clusters: 1968.432
# Running KMeans for 4 clusters in 2022
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.581066 -0.578931  -0.572015       -0.0
# PC2  0.318864  0.484711  -0.814482       -0.0
#
# Explained variance ratio per Principal Component:
# PC1: 0.8304
# PC2: 0.0918
# Silhouette Score for 4 clusters: 0.357
# Davies-Bouldin Index for 4 clusters: 0.952
# Calinski-Harabasz Index for 4 clusters: 1853.781
# Running Hierarchical Clustering for 4 clusters in 2022
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.581066 -0.578931  -0.572015       -0.0
# PC2  0.318864  0.484711  -0.814482       -0.0
#
# Explained variance ratio per Principal Component:
# PC1: 0.8304
# PC2: 0.0918
# Silhouette Score for 4 clusters: 0.736
# Davies-Bouldin Index for 4 clusters: 0.504
# Calinski-Harabasz Index for 4 clusters: 1843.474
# Applying Elbow Method for year 2023
# Running KMeans for 2 clusters in 2023
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.582003 -0.571635  -0.578363   0.001217
# PC2 -0.047100  0.051497  -0.001401   0.997561
#
# Explained variance ratio per Principal Component:
# PC1: 0.6277
# PC2: 0.2509
# Silhouette Score for 2 clusters: 0.782
# Davies-Bouldin Index for 2 clusters: 0.431
# Calinski-Harabasz Index for 2 clusters: 1122.895
# Running Hierarchical Clustering for 2 clusters in 2023
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.582003 -0.571635  -0.578363   0.001217
# PC2 -0.047100  0.051497  -0.001401   0.997561
#
# Explained variance ratio per Principal Component:
# PC1: 0.6277
# PC2: 0.2509
# Silhouette Score for 2 clusters: 0.777
# Davies-Bouldin Index for 2 clusters: 0.490
# Calinski-Harabasz Index for 2 clusters: 1102.802
# Running KMeans for 3 clusters in 2023
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.582003 -0.571635  -0.578363   0.001217
# PC2 -0.047100  0.051497  -0.001401   0.997561
#
# Explained variance ratio per Principal Component:
# PC1: 0.6277
# PC2: 0.2509
# Silhouette Score for 3 clusters: 0.809
# Davies-Bouldin Index for 3 clusters: 0.362
# Calinski-Harabasz Index for 3 clusters: 1700.979
# Running Hierarchical Clustering for 3 clusters in 2023
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.582003 -0.571635  -0.578363   0.001217
# PC2 -0.047100  0.051497  -0.001401   0.997561
#
# Explained variance ratio per Principal Component:
# PC1: 0.6277
# PC2: 0.2509
# Silhouette Score for 3 clusters: 0.805
# Davies-Bouldin Index for 3 clusters: 0.411
# Calinski-Harabasz Index for 3 clusters: 1660.461
# Running KMeans for 4 clusters in 2023
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.582003 -0.571635  -0.578363   0.001217
# PC2 -0.047100  0.051497  -0.001401   0.997561
#
# Explained variance ratio per Principal Component:
# PC1: 0.6277
# PC2: 0.2509
# Silhouette Score for 4 clusters: 0.326
# Davies-Bouldin Index for 4 clusters: 0.739
# Calinski-Harabasz Index for 4 clusters: 1623.461
# Running Hierarchical Clustering for 4 clusters in 2023
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.582003 -0.571635  -0.578363   0.001217
# PC2 -0.047100  0.051497  -0.001401   0.997561
#
# Explained variance ratio per Principal Component:
# PC1: 0.6277
# PC2: 0.2509
# Silhouette Score for 4 clusters: 0.319
# Davies-Bouldin Index for 4 clusters: 0.811
# Calinski-Harabasz Index for 4 clusters: 1463.431
# Applying Elbow Method for year 2024
# Running KMeans for 2 clusters in 2024
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1  -0.57566 -0.587260  -0.564242  -0.073297
# PC2  -0.09040 -0.004787  -0.032091   0.995377
#
# Explained variance ratio per Principal Component:
# PC1: 0.6628
# PC2: 0.2486
# Silhouette Score for 2 clusters: 0.764
# Davies-Bouldin Index for 2 clusters: 0.393
# Calinski-Harabasz Index for 2 clusters: 1289.933
# Running Hierarchical Clustering for 2 clusters in 2024
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1  -0.57566 -0.587260  -0.564242  -0.073297
# PC2  -0.09040 -0.004787  -0.032091   0.995377
#
# Explained variance ratio per Principal Component:
# PC1: 0.6628
# PC2: 0.2486
# Silhouette Score for 2 clusters: 0.754
# Davies-Bouldin Index for 2 clusters: 0.506
# Calinski-Harabasz Index for 2 clusters: 1258.797
# Running KMeans for 3 clusters in 2024
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1  -0.57566 -0.587260  -0.564242  -0.073297
# PC2  -0.09040 -0.004787  -0.032091   0.995377
#
# Explained variance ratio per Principal Component:
# PC1: 0.6628
# PC2: 0.2486
# Silhouette Score for 3 clusters: 0.756
# Davies-Bouldin Index for 3 clusters: 0.363
# Calinski-Harabasz Index for 3 clusters: 2036.112
# Running Hierarchical Clustering for 3 clusters in 2024
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1  -0.57566 -0.587260  -0.564242  -0.073297
# PC2  -0.09040 -0.004787  -0.032091   0.995377
#
# Explained variance ratio per Principal Component:
# PC1: 0.6628
# PC2: 0.2486
# Silhouette Score for 3 clusters: 0.756
# Davies-Bouldin Index for 3 clusters: 0.431
# Calinski-Harabasz Index for 3 clusters: 1967.977
# Running KMeans for 4 clusters in 2024
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1  -0.57566 -0.587260  -0.564242  -0.073297
# PC2  -0.09040 -0.004787  -0.032091   0.995377
#
# Explained variance ratio per Principal Component:
# PC1: 0.6628
# PC2: 0.2486
# Silhouette Score for 4 clusters: 0.428
# Davies-Bouldin Index for 4 clusters: 0.689
# Calinski-Harabasz Index for 4 clusters: 2010.887
# Running Hierarchical Clustering for 4 clusters in 2024
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1  -0.57566 -0.587260  -0.564242  -0.073297
# PC2  -0.09040 -0.004787  -0.032091   0.995377
#
# Explained variance ratio per Principal Component:
# PC1: 0.6628
# PC2: 0.2486
# Silhouette Score for 4 clusters: 0.752
# Davies-Bouldin Index for 4 clusters: 0.793
# Calinski-Harabasz Index for 4 clusters: 1786.779

# %%
doc.add_heading('For dataset_complete with no missing data', 2)

# %%
# Prepare the data for clustering
if all(feature in dataset_complete.columns for feature in clustering_features_totals):
    available_features = [feature for feature in clustering_features_totals if feature in dataset_complete.columns]
    df = dataset_complete[available_features]
    X = StandardScaler().fit_transform(df)

    # Apply Elbow Method
    print(f"Applying Elbow Method for dataset_complete with no Missing Data")
    plot_elbow_method(X, year)

    # Perform clustering and PCA
    for n_clusters in [2, 3, 4]:
        print(f"Running KMeans for {n_clusters} clusters for dataset_complete")
        perform_kmeans_clustering(dataset_complete, available_features, year, n_clusters, use_pca=True)

        print(f"Running Hierarchical Clustering for {n_clusters} clusters for dataset_complete")
        perform_hierarchical_clustering(dataset_complete, available_features, year, n_clusters, use_pca=True)
else:
    print(f"Skipping year {year}: Required columns not found in dataset.")
# Out:
# Applying Elbow Method for dataset_complete with no Missing Data
# Running KMeans for 2 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.618094 -0.692477  -0.366236  -0.065634
# PC2 -0.065837  0.003859  -0.074505   0.995037
#
# Explained variance ratio per Principal Component:
# PC1: 0.4729
# PC2: 0.2500
# Silhouette Score for 2 clusters: 0.662
# Davies-Bouldin Index for 2 clusters: 0.492
# Calinski-Harabasz Index for 2 clusters: 4546.664
# Running Hierarchical Clustering for 2 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.618094 -0.692477  -0.366236  -0.065634
# PC2 -0.065837  0.003859  -0.074505   0.995037
#
# Explained variance ratio per Principal Component:
# PC1: 0.4729
# PC2: 0.2500
# Silhouette Score for 2 clusters: 0.660
# Davies-Bouldin Index for 2 clusters: 0.469
# Calinski-Harabasz Index for 2 clusters: 4474.117
# Running KMeans for 3 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.618094 -0.692477  -0.366236  -0.065634
# PC2 -0.065837  0.003859  -0.074505   0.995037
#
# Explained variance ratio per Principal Component:
# PC1: 0.4729
# PC2: 0.2500
# Silhouette Score for 3 clusters: 0.559
# Davies-Bouldin Index for 3 clusters: 0.692
# Calinski-Harabasz Index for 3 clusters: 5744.141
# Running Hierarchical Clustering for 3 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.618094 -0.692477  -0.366236  -0.065634
# PC2 -0.065837  0.003859  -0.074505   0.995037
#
# Explained variance ratio per Principal Component:
# PC1: 0.4729
# PC2: 0.2500
# Silhouette Score for 3 clusters: 0.699
# Davies-Bouldin Index for 3 clusters: 0.426
# Calinski-Harabasz Index for 3 clusters: 6230.010
# Running KMeans for 4 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.618094 -0.692477  -0.366236  -0.065634
# PC2 -0.065837  0.003859  -0.074505   0.995037
#
# Explained variance ratio per Principal Component:
# PC1: 0.4729
# PC2: 0.2500
# Silhouette Score for 4 clusters: 0.616
# Davies-Bouldin Index for 4 clusters: 0.498
# Calinski-Harabasz Index for 4 clusters: 13399.484
# Running Hierarchical Clustering for 4 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#      Total_AP  Total_PP  Total_SPA  Total_Bon
# PC1 -0.618094 -0.692477  -0.366236  -0.065634
# PC2 -0.065837  0.003859  -0.074505   0.995037
#
# Explained variance ratio per Principal Component:
# PC1: 0.4729
# PC2: 0.2500
# Silhouette Score for 4 clusters: 0.615
# Davies-Bouldin Index for 4 clusters: 0.503
# Calinski-Harabasz Index for 4 clusters: 13155.699

# %%
doc.add_heading('All Columns of dataset_complete', 2)

# %%
dataset_complete.columns
# Out:
# Index(['Course', 'Class', 'Sex', '1', '12', '20', '10', '11', '32', '38', '42',
#        '35', '50', '30', '31', '36', '34', '72', 'SPA1', 'SPA2', 'SPA3', 'Bon',
#        'PP1_1', 'PP1_2', 'PP1_3', 'PP2_1', 'PP2_2', 'PP2_3', 'PP3_1', 'PP3_2',
#        'PP3_3', 'PTP1', 'PTP2', 'PTP3', 'FinalGradeInteger', 'Total_AP',
#        'Total_PP', 'Total_SPA', 'Total_Bon', 'Year'],
#       dtype='object')

# %%
get_activity_name_by_id(1, dataset_params, 2024)
# Out:
# 'Submission of CV on Moodle'

# %%
get_activity_name_by_id(12, dataset_params, 2024)
# Out:
# 'Psychotechnical test (Moodle)'

# %%
get_activity_name_by_id(20, dataset_params, 2024)
# Out:
# 'Assessment of the week'

# %%
get_activity_name_by_id(10, dataset_params, 2024)
# Out:
# 'Analysis of 3 CVs of candidates'

# %%
get_activity_name_by_id(11, dataset_params, 2024)
# Out:
# 'Presentation on the analyzed CVs'

# %%
get_activity_name_by_id(32, dataset_params, 2024)
# Out:
# 'Project execution'

# %%
get_activity_name_by_id(38, dataset_params, 2024)
# Out:
# 'Parking'

# %%
get_activity_name_by_id(42, dataset_params, 2024)
# Out:
# 'Leading is ...'

# %%
get_activity_name_by_id(35, dataset_params, 2024)
# Out:
# '4x100m freestyle'

# %%
get_activity_name_by_id(50, dataset_params, 2024)
# Out:
# 'Assessment of the week'

# %%
get_activity_name_by_id(30, dataset_params, 2024)
# Out:
# 'SMART goals'

# %%
get_activity_name_by_id(31, dataset_params, 2024)
# Out:
# "Maria's dashboard"

# %%
get_activity_name_by_id(36, dataset_params, 2024)
# Out:
# 'Forced landing - individual'

# %%
get_activity_name_by_id(34, dataset_params, 2024)
# Out:
# 'Wolis'

# %%
get_activity_name_by_id(72, dataset_params, 2024)
# Out:
# 'Ethical dilemmas'

# %%
doc.add_heading('Results', 3)

clustering_features_complete = [
    col for col in dataset_complete.columns
    if col not in all_lists[str(2024)]['basic_lists']['listCategorical']
]

# Prepare the data for clustering
if all(feature in dataset_complete.columns for feature in clustering_features_complete):
    available_features = [feature for feature in clustering_features_complete if feature in dataset_complete.columns]
    df = dataset_complete[available_features]
    X = StandardScaler().fit_transform(df)

    # Apply Elbow Method
    print(f"Applying Elbow Method for dataset_complete with no Missing Data")
    plot_elbow_method(X, year)

    # Perform clustering and PCA
    for n_clusters in [2, 3, 4]:
        print(f"Running KMeans for {n_clusters} clusters for dataset_complete")
        perform_kmeans_clustering(dataset_complete, available_features, year, n_clusters, use_pca=True)

        print(f"Running Hierarchical Clustering for {n_clusters} clusters for dataset_complete")
        perform_hierarchical_clustering(dataset_complete, available_features, year, n_clusters, use_pca=True)
else:
    print(f"Skipping year {year}: Required columns not found in dataset.")
# Out:
# Applying Elbow Method for dataset_complete with no Missing Data
# Running KMeans for 2 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.179745 -0.202526 -0.179495 -0.178856 -0.030966 -0.172219 -0.163184
# PC2 -0.023103 -0.083435 -0.080291 -0.050100 -0.157664 -0.070887 -0.093581
#
#            42        35        50  ...     PP3_3      PTP1      PTP2  \
# PC1 -0.195360 -0.190516 -0.153512  ... -0.156435 -0.150852 -0.142019
# PC2 -0.091478 -0.005609 -0.118530  ... -0.055284 -0.026712 -0.057104
#
#          PTP3  FinalGradeInteger  Total_AP  Total_PP  Total_SPA  Total_Bon  \
# PC1 -0.127102          -0.260779 -0.208512 -0.235982  -0.159710  -0.005578
# PC2 -0.047740          -0.054497 -0.226406 -0.074916   0.348729  -0.013166
#
#          Year
# PC1  0.057130
# PC2 -0.417744
#
# [2 rows x 37 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3427
# PC2: 0.1275
# Silhouette Score for 2 clusters: 0.552
# Davies-Bouldin Index for 2 clusters: 0.567
# Calinski-Harabasz Index for 2 clusters: 2828.071
# Running Hierarchical Clustering for 2 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.179745 -0.202526 -0.179495 -0.178856 -0.030966 -0.172219 -0.163184
# PC2 -0.023103 -0.083435 -0.080291 -0.050100 -0.157664 -0.070887 -0.093581
#
#            42        35        50  ...     PP3_3      PTP1      PTP2  \
# PC1 -0.195360 -0.190516 -0.153512  ... -0.156435 -0.150852 -0.142019
# PC2 -0.091478 -0.005609 -0.118530  ... -0.055284 -0.026712 -0.057104
#
#          PTP3  FinalGradeInteger  Total_AP  Total_PP  Total_SPA  Total_Bon  \
# PC1 -0.127102          -0.260779 -0.208512 -0.235982  -0.159710  -0.005578
# PC2 -0.047740          -0.054497 -0.226406 -0.074916   0.348729  -0.013166
#
#          Year
# PC1  0.057130
# PC2 -0.417744
#
# [2 rows x 37 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3427
# PC2: 0.1275
# Silhouette Score for 2 clusters: 0.562
# Davies-Bouldin Index for 2 clusters: 0.430
# Calinski-Harabasz Index for 2 clusters: 2670.986
# Running KMeans for 3 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.179745 -0.202526 -0.179495 -0.178856 -0.030966 -0.172219 -0.163184
# PC2 -0.023103 -0.083435 -0.080290 -0.050100 -0.157664 -0.070887 -0.093581
#
#            42        35        50  ...     PP3_3      PTP1      PTP2  \
# PC1 -0.195360 -0.190516 -0.153512  ... -0.156435 -0.150852 -0.142019
# PC2 -0.091478 -0.005609 -0.118530  ... -0.055284 -0.026712 -0.057104
#
#          PTP3  FinalGradeInteger  Total_AP  Total_PP  Total_SPA  Total_Bon  \
# PC1 -0.127102          -0.260779 -0.208512 -0.235982  -0.159710  -0.005578
# PC2 -0.047740          -0.054497 -0.226406 -0.074916   0.348729  -0.013166
#
#          Year
# PC1  0.057130
# PC2 -0.417744
#
# [2 rows x 37 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3427
# PC2: 0.1275
# Silhouette Score for 3 clusters: 0.237
# Davies-Bouldin Index for 3 clusters: 1.439
# Calinski-Harabasz Index for 3 clusters: 2601.654
# Running Hierarchical Clustering for 3 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.179745 -0.202526 -0.179495 -0.178856 -0.030966 -0.172219 -0.163184
# PC2 -0.023103 -0.083435 -0.080291 -0.050100 -0.157664 -0.070887 -0.093581
#
#            42        35        50  ...     PP3_3      PTP1      PTP2  \
# PC1 -0.195360 -0.190516 -0.153512  ... -0.156435 -0.150852 -0.142019
# PC2 -0.091478 -0.005609 -0.118530  ... -0.055284 -0.026712 -0.057104
#
#          PTP3  FinalGradeInteger  Total_AP  Total_PP  Total_SPA  Total_Bon  \
# PC1 -0.127102          -0.260779 -0.208512 -0.235982  -0.159710  -0.005578
# PC2 -0.047740          -0.054497 -0.226406 -0.074916   0.348729  -0.013166
#
#          Year
# PC1  0.057130
# PC2 -0.417744
#
# [2 rows x 37 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3427
# PC2: 0.1275
# Silhouette Score for 3 clusters: 0.209
# Davies-Bouldin Index for 3 clusters: 1.598
# Calinski-Harabasz Index for 3 clusters: 2250.285
# Running KMeans for 4 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.179745 -0.202526 -0.179495 -0.178856 -0.030966 -0.172219 -0.163184
# PC2 -0.023103 -0.083435 -0.080291 -0.050100 -0.157664 -0.070887 -0.093581
#
#            42        35        50  ...     PP3_3      PTP1      PTP2  \
# PC1 -0.195360 -0.190516 -0.153512  ... -0.156435 -0.150852 -0.142019
# PC2 -0.091478 -0.005609 -0.118530  ... -0.055284 -0.026712 -0.057104
#
#          PTP3  FinalGradeInteger  Total_AP  Total_PP  Total_SPA  Total_Bon  \
# PC1 -0.127102          -0.260779 -0.208512 -0.235982  -0.159710  -0.005578
# PC2 -0.047740          -0.054497 -0.226406 -0.074916   0.348729  -0.013166
#
#          Year
# PC1  0.057130
# PC2 -0.417744
#
# [2 rows x 37 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3427
# PC2: 0.1275
# Silhouette Score for 4 clusters: 0.248
# Davies-Bouldin Index for 4 clusters: 1.310
# Calinski-Harabasz Index for 4 clusters: 2126.847
# Running Hierarchical Clustering for 4 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.179745 -0.202526 -0.179495 -0.178856 -0.030966 -0.172219 -0.163184
# PC2 -0.023103 -0.083435 -0.080291 -0.050100 -0.157664 -0.070887 -0.093581
#
#            42        35        50  ...     PP3_3      PTP1      PTP2  \
# PC1 -0.195360 -0.190516 -0.153512  ... -0.156435 -0.150852 -0.142019
# PC2 -0.091478 -0.005609 -0.118530  ... -0.055284 -0.026712 -0.057104
#
#          PTP3  FinalGradeInteger  Total_AP  Total_PP  Total_SPA  Total_Bon  \
# PC1 -0.127102          -0.260779 -0.208512 -0.235982  -0.159710  -0.005578
# PC2 -0.047740          -0.054497 -0.226406 -0.074916   0.348729  -0.013166
#
#          Year
# PC1  0.057130
# PC2 -0.417744
#
# [2 rows x 37 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3427
# PC2: 0.1275
# Silhouette Score for 4 clusters: 0.224
# Davies-Bouldin Index for 4 clusters: 1.423
# Calinski-Harabasz Index for 4 clusters: 1884.328

# %%
clustering_features_complete = [
    col for col in dataset_complete.columns
    if col not in all_lists[str(2024)]['basic_lists']['listCategorical']
]

# Prepare the data for clustering
if all(feature in dataset_complete.columns for feature in clustering_features_complete):
    available_features = [feature for feature in clustering_features_complete if feature in dataset_complete.columns]
    df = dataset_complete[available_features]
    X = StandardScaler().fit_transform(df)

    # Apply Elbow Method
    print(f"Applying Elbow Method for dataset_complete with no Missing Data")
    plot_elbow_method(X, year)

    # Perform clustering and PCA
    for n_clusters in [2, 3, 4]:
        print(f"Running KMeans for {n_clusters} clusters for dataset_complete")
        perform_kmeans_clustering(dataset_complete, available_features, year, n_clusters, use_pca=False)

        print(f"Running Hierarchical Clustering for {n_clusters} clusters for dataset_complete")
        perform_hierarchical_clustering(dataset_complete, available_features, year, n_clusters, use_pca=False)
else:
    print(f"Skipping year {year}: Required columns not found in dataset.")
# Out:
# Applying Elbow Method for dataset_complete with no Missing Data
# Running KMeans for 2 clusters for dataset_complete
# Silhouette Score for 2 clusters: 0.552
# Davies-Bouldin Index for 2 clusters: 0.567
# Calinski-Harabasz Index for 2 clusters: 2828.071
# Running Hierarchical Clustering for 2 clusters for dataset_complete
# Silhouette Score for 2 clusters: 0.562
# Davies-Bouldin Index for 2 clusters: 0.430
# Calinski-Harabasz Index for 2 clusters: 2670.986
# Running KMeans for 3 clusters for dataset_complete
# Silhouette Score for 3 clusters: 0.237
# Davies-Bouldin Index for 3 clusters: 1.439
# Calinski-Harabasz Index for 3 clusters: 2601.654
# Running Hierarchical Clustering for 3 clusters for dataset_complete
# Silhouette Score for 3 clusters: 0.209
# Davies-Bouldin Index for 3 clusters: 1.598
# Calinski-Harabasz Index for 3 clusters: 2250.285
# Running KMeans for 4 clusters for dataset_complete
# Silhouette Score for 4 clusters: 0.248
# Davies-Bouldin Index for 4 clusters: 1.310
# Calinski-Harabasz Index for 4 clusters: 2126.847
# Running Hierarchical Clustering for 4 clusters for dataset_complete
# Silhouette Score for 4 clusters: 0.224
# Davies-Bouldin Index for 4 clusters: 1.423
# Calinski-Harabasz Index for 4 clusters: 1884.328

# %% [markdown]
# ### 6.3.2. Clustering Features: Activities Results (AP per activity)

# %%
doc.add_heading('Clustering Features: Week1 and Week2 Activities', 1)

# %%
dataset_years = datasets.keys()
clustering_features = {}
for year in dataset_years:
    clustering_features[year] = [
        col for col in all_lists[str(year)]['basic_lists']['listSyncNumericColumns']
        if col not in all_lists[str(year)]['created_columns']['TotalColumns']
        and col not in ['Week3_AP', 'Week4_AP', 'Week5_AP']
        and col not in all_lists[str(year)]['created_columns']['WeeklyPP']
        and col not in all_lists[str(year)]['created_columns']['OtherColumns']
        and col not in all_lists[str(year)]['basic_lists']['listPPointsColumns']
        and col not in all_lists[str(year)]['basic_lists']['listBonColumns']
        and col not in all_lists[str(year)]['basic_lists']['listSPAColumns']
        and col not in all_lists[str(year)]['basic_lists']['listGrades']
        and col not in all_lists[str(year)]['weekly_and_participation_lists']['listWeek3']
        and col not in all_lists[str(year)]['weekly_and_participation_lists']['listWeek4']
        and col not in all_lists[str(year)]['weekly_and_participation_lists']['listWeek5']
    ]

# %% [markdown]
# #### Hierarchichal Clustering Analysis with PCA Reduction

# %%
doc.add_heading('Hierarchichal Clustering Analysis with PCA Reduction', 2)

# %%
for year in dataset_years:
    print(f"Hierarchical Clustering Analysis for {year}")

    missing_features = [feature for feature in clustering_features[year] if feature not in datasets[year].columns]

    if not missing_features:
        available_features = [feature for feature in clustering_features[year] if feature in datasets[year].columns]
        for n_clusters in [2, 3, 4]:
            print(f"Running Hierarchical Clustering for {n_clusters} clusters in {year}")
            perform_hierarchical_clustering(datasets[year], available_features, year, n_clusters)
    else:
        print(f"Skipping year {year}: Required columns not found in dataset.")
        print(f"Missing features for year {year}: {missing_features}")
        #print(f"Available columns {year}: {datasets[year].columns}")
# Out:
# Hierarchical Clustering Analysis for 2016
# Running Hierarchical Clustering for 2 clusters in 2016
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.179904 -0.012209 -0.183065 -0.200765 -0.190110 -0.037618 -0.009857
# PC2 -0.056332 -0.038523 -0.137883 -0.144589 -0.315897 -0.109929 -0.038128
#
#            25        10        11  ...       31        52        28        53  \
# PC1 -0.202083 -0.167513 -0.043020  ... -0.17933 -0.209058 -0.180563 -0.158269
# PC2 -0.114724 -0.048462 -0.024662  ...  0.17076  0.182594  0.007046 -0.021394
#
#            36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.221647 -0.220566 -0.220441 -0.195696 -0.216606 -0.251935
# PC2  0.206367  0.206129  0.206020  0.199742 -0.204952  0.195830
#
# [2 rows x 34 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3869
# PC2: 0.0672
# Silhouette Score for 2 clusters: 0.600
# Davies-Bouldin Index for 2 clusters: 0.312
# Calinski-Harabasz Index for 2 clusters: 467.855
# Running Hierarchical Clustering for 3 clusters in 2016
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.179904 -0.012209 -0.183065 -0.200765 -0.190110 -0.037618 -0.009857
# PC2 -0.056362 -0.038687 -0.137788 -0.144529 -0.315856 -0.109964 -0.038460
#
#            25        10        11  ...        31        52        28  \
# PC1 -0.202083 -0.167513 -0.043020  ... -0.179330 -0.209058 -0.180563
# PC2 -0.114794 -0.048641 -0.024604  ...  0.170776  0.182604  0.006887
#
#            53        36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.158269 -0.221647 -0.220566 -0.220441 -0.195696 -0.216606 -0.251935
# PC2 -0.021554  0.206403  0.206169  0.206056  0.199763 -0.204995  0.195812
#
# [2 rows x 34 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3869
# PC2: 0.0672
# Silhouette Score for 3 clusters: 0.409
# Davies-Bouldin Index for 3 clusters: 1.542
# Calinski-Harabasz Index for 3 clusters: 328.710
# Running Hierarchical Clustering for 4 clusters in 2016
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.179904 -0.012209 -0.183065 -0.200765 -0.190110 -0.037618 -0.009857
# PC2 -0.056393 -0.038530 -0.137781 -0.144541 -0.315843 -0.109956 -0.038358
#
#            25        10        11  ...       31        52        28        53  \
# PC1 -0.202083 -0.167513 -0.043020  ... -0.17933 -0.209058 -0.180563 -0.158269
# PC2 -0.114851 -0.048733 -0.024582  ...  0.17078  0.182593  0.006966 -0.021473
#
#            36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.221647 -0.220566 -0.220441 -0.195696 -0.216606 -0.251935
# PC2  0.206382  0.206148  0.206035  0.199735 -0.204986  0.195821
#
# [2 rows x 34 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3869
# PC2: 0.0672
# Silhouette Score for 4 clusters: 0.402
# Davies-Bouldin Index for 4 clusters: 1.127
# Calinski-Harabasz Index for 4 clusters: 275.422
# Hierarchical Clustering Analysis for 2017
# Running Hierarchical Clustering for 2 clusters in 2017
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.207294 -0.020410 -0.180244 -0.218344 -0.204269 -0.042903 -0.010093
# PC2 -0.041674  0.029015  0.169155  0.091239  0.324345  0.143981  0.014268
#
#            25        10        11  ...        31        52        28  \
# PC1 -0.205943 -0.191518 -0.041829  ... -0.173102 -0.201073 -0.202428
# PC2 -0.006501  0.037220  0.026136  ...  0.004147 -0.221456 -0.053008
#
#            53        36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.171730 -0.211033 -0.211033 -0.211870 -0.175000 -0.213840 -0.235148
# PC2 -0.069645 -0.267559 -0.267559 -0.266029 -0.271585  0.167099 -0.141057
#
# [2 rows x 33 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4749
# PC2: 0.0599
# Silhouette Score for 2 clusters: 0.617
# Davies-Bouldin Index for 2 clusters: 0.328
# Calinski-Harabasz Index for 2 clusters: 738.874
# Running Hierarchical Clustering for 3 clusters in 2017
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.207294 -0.020410 -0.180244 -0.218344 -0.204269 -0.042903 -0.010093
# PC2 -0.041673  0.029025  0.169148  0.091227  0.324340  0.143990  0.014277
#
#            25        10        11  ...        31        52        28  \
# PC1 -0.205943 -0.191518 -0.041829  ... -0.173102 -0.201073 -0.202428
# PC2 -0.006509  0.037200  0.026142  ...  0.004140 -0.221453 -0.052997
#
#            53        36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.171730 -0.211033 -0.211033 -0.211870 -0.175000  -0.21384 -0.235148
# PC2 -0.069628 -0.267562 -0.267562 -0.266031 -0.271595   0.16710 -0.141058
#
# [2 rows x 33 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4749
# PC2: 0.0599
# Silhouette Score for 3 clusters: 0.411
# Davies-Bouldin Index for 3 clusters: 1.136
# Calinski-Harabasz Index for 3 clusters: 485.318
# Running Hierarchical Clustering for 4 clusters in 2017
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.207294 -0.020410 -0.180244 -0.218344 -0.204269 -0.042903 -0.010093
# PC2 -0.041674  0.029013  0.169157  0.091221  0.324328  0.144015  0.014271
#
#            25        10        11  ...        31        52        28  \
# PC1 -0.205943 -0.191518 -0.041829  ... -0.173102 -0.201073 -0.202428
# PC2 -0.006505  0.037198  0.026160  ...  0.004141 -0.221449 -0.053028
#
#            53        36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.171730 -0.211033 -0.211033 -0.211870 -0.175000 -0.213840 -0.235148
# PC2 -0.069671 -0.267564 -0.267564 -0.266033 -0.271598  0.167113 -0.141055
#
# [2 rows x 33 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4749
# PC2: 0.0599
# Silhouette Score for 4 clusters: 0.417
# Davies-Bouldin Index for 4 clusters: 1.130
# Calinski-Harabasz Index for 4 clusters: 391.673
# Hierarchical Clustering Analysis for 2018
# Running Hierarchical Clustering for 2 clusters in 2018
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.213879 -0.012544 -0.182194 -0.224029 -0.187897 -0.043419 -0.008179
# PC2 -0.026637 -0.007613  0.123919  0.075653  0.345507  0.135185  0.018254
#
#            25        10        11  ...        31        52        28  \
# PC1 -0.158754 -0.174292 -0.026947  ... -0.172769 -0.214637 -0.174955
# PC2 -0.039028 -0.029658 -0.020142  ... -0.162062 -0.083670 -0.089824
#
#            53        36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.157178 -0.224534 -0.224534 -0.224534 -0.180895 -0.220471 -0.247906
# PC2 -0.088769 -0.048660 -0.048660 -0.048660 -0.078676  0.159297 -0.224470
#
# [2 rows x 34 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3683
# PC2: 0.0763
# Silhouette Score for 2 clusters: 0.674
# Davies-Bouldin Index for 2 clusters: 0.294
# Calinski-Harabasz Index for 2 clusters: 409.921
# Running Hierarchical Clustering for 3 clusters in 2018
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.213879 -0.012544 -0.182194 -0.224029 -0.187897 -0.043419 -0.008179
# PC2 -0.026624 -0.007646  0.123952  0.075678  0.345488  0.135180  0.018280
#
#            25        10        11  ...        31        52        28  \
# PC1 -0.158754 -0.174292 -0.026947  ... -0.172769 -0.214637 -0.174955
# PC2 -0.039014 -0.029684 -0.020177  ... -0.162084 -0.083669 -0.089808
#
#            53        36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.157178 -0.224534 -0.224534 -0.224534 -0.180895 -0.220471 -0.247906
# PC2 -0.088765 -0.048657 -0.048657 -0.048657 -0.078677  0.159305 -0.224468
#
# [2 rows x 34 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3683
# PC2: 0.0763
# Silhouette Score for 3 clusters: 0.457
# Davies-Bouldin Index for 3 clusters: 1.379
# Calinski-Harabasz Index for 3 clusters: 310.310
# Running Hierarchical Clustering for 4 clusters in 2018
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.213879 -0.012544 -0.182194 -0.224029 -0.187897 -0.043419 -0.008179
# PC2 -0.026632 -0.007449  0.123890  0.075649  0.345510  0.135224  0.018147
#
#            25        10        11  ...        31        52        28  \
# PC1 -0.158754 -0.174292 -0.026947  ... -0.172769 -0.214637 -0.174955
# PC2 -0.039043 -0.029619 -0.020162  ... -0.162074 -0.083673 -0.089805
#
#            53        36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.157178 -0.224534 -0.224534 -0.224534 -0.180895 -0.220471 -0.247906
# PC2 -0.088752 -0.048660 -0.048660 -0.048660 -0.078691  0.159322 -0.224466
#
# [2 rows x 34 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3683
# PC2: 0.0763
# Silhouette Score for 4 clusters: 0.433
# Davies-Bouldin Index for 4 clusters: 1.016
# Calinski-Harabasz Index for 4 clusters: 264.430
# Hierarchical Clustering Analysis for 2019
# Running Hierarchical Clustering for 2 clusters in 2019
# PCA Components and their contribution to the Principal Components:
columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4441
# PC2: 0.0543
# Silhouette Score for 2 clusters: 0.637
# Davies-Bouldin Index for 2 clusters: 0.345
# Calinski-Harabasz Index for 2 clusters: 627.499
# Running Hierarchical Clustering for 3 clusters in 2022
# PCA Components and their contribution to the Principal Components:
#             1        23       133       134       135        19       137  \
# PC1 -0.135136 -0.157496 -0.153971 -0.048253 -0.163300 -0.162031 -0.170230
# PC2 -0.022924  0.098332  0.102496 -0.144667  0.085637  0.105601  0.243889
#
#           138        32       144  ...        33        36        37  \
# PC1 -0.039624 -0.130660 -0.160617  ... -0.130139 -0.166141 -0.163616
# PC2  0.254257  0.217596  0.226356  ...  0.037834  0.065286  0.060190
#
#            34        38        44        42        43  Week1_AP  Week2_AP
# PC1 -0.125711 -0.142792 -0.163888 -0.159183 -0.043680 -0.199382 -0.209734
# PC2 -0.145307 -0.152403 -0.110327 -0.125511 -0.036184  0.176006 -0.126855
#
# [2 rows x 47 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4441
# PC2: 0.0543
# Silhouette Score for 3 clusters: 0.415
# Davies-Bouldin Index for 3 clusters: 1.786
# Calinski-Harabasz Index for 3 clusters: 406.347
# Running Hierarchical Clustering for 4 clusters in 2022
# PCA Components and their contribution to the Principal Components:
#             1        23       133       134       135        19       137  \
# PC1 -0.135136 -0.157496 -0.153971 -0.048253 -0.163300 -0.162031 -0.170230
# PC2 -0.022897  0.098293  0.102455 -0.144662  0.085684  0.105638  0.243889
#
#           138        32       144  ...        33        36        37  \
# PC1 -0.039624 -0.130660 -0.160617  ... -0.130139 -0.166141 -0.163616
# PC2  0.254246  0.217622  0.226349  ...  0.037843  0.065280  0.060186
#
#            34        38        44        42        43  Week1_AP  Week2_AP
# PC1 -0.125711 -0.142792 -0.163888 -0.159183 -0.043680 -0.199382 -0.209734
# PC2 -0.145292 -0.152391 -0.110351 -0.125541 -0.036183  0.176004 -0.126850
#
# [2 rows x 47 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4441
# PC2: 0.0543
# Silhouette Score for 4 clusters: 0.393
# Davies-Bouldin Index for 4 clusters: 1.627
# Calinski-Harabasz Index for 4 clusters: 315.654
# Hierarchical Clustering Analysis for 2023
# Running Hierarchical Clustering for 2 clusters in 2023
# PCA Components and their contribution to the Principal Components:
#             1      1_11        18        19        20         7        25  \
# PC1 -0.130358 -0.167696 -0.170605 -0.170890 -0.169797 -0.154473 -0.152902
# PC2 -0.148020 -0.326413 -0.323775 -0.193891 -0.325120 -0.215172 -0.190917
#
#            10        11        12  ...       147        32        33  \
# PC1 -0.143042 -0.050138 -0.156410  ... -0.164284 -0.168975 -0.168581
# PC2 -0.213777 -0.059902 -0.178303  ... -0.031332  0.078761 -0.034251
#
#            34        35        36        37        38  Week1_AP  Week2_AP
# PC1 -0.149292 -0.172026 -0.204148 -0.203305 -0.158198 -0.209889 -0.247051
# PC2  0.103098  0.099906  0.068682  0.067816  0.103970 -0.298004  0.170534
#
# [2 rows x 35 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4107
# PC2: 0.0857
# Silhouette Score for 2 clusters: 0.565
# Davies-Bouldin Index for 2 clusters: 1.081
# Calinski-Harabasz Index for 2 clusters: 457.694
# Running Hierarchical Clustering for 3 clusters in 2023
# PCA Components and their contribution to the Principal Components:
#             1      1_11        18        19        20         7        25  \
# PC1 -0.130358 -0.167696 -0.170605 -0.170890 -0.169797 -0.154473 -0.152902
# PC2 -0.148020 -0.326413 -0.323775 -0.193892 -0.325120 -0.215172 -0.190917
#
#            10        11        12  ...       147        32        33  \
# PC1 -0.143042 -0.050138 -0.156410  ... -0.164284 -0.168975 -0.168581
# PC2 -0.213777 -0.059902 -0.178304  ... -0.031331  0.078761 -0.034251
#
#            34        35        36        37        38  Week1_AP  Week2_AP
# PC1 -0.149292 -0.172026 -0.204148 -0.203305 -0.158198 -0.209889 -0.247051
# PC2  0.103098  0.099906  0.068682  0.067816  0.103970 -0.298004  0.170534
#
# [2 rows x 35 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4107
# PC2: 0.0857
# Silhouette Score for 3 clusters: 0.496
# Davies-Bouldin Index for 3 clusters: 1.010
# Calinski-Harabasz Index for 3 clusters: 352.751
# Running Hierarchical Clustering for 4 clusters in 2023
# PCA Components and their contribution to the Principal Components:
#             1      1_11        18        19        20         7        25  \
# PC1 -0.130358 -0.167696 -0.170605 -0.170890 -0.169797 -0.154473 -0.152902
# PC2 -0.148020 -0.326413 -0.323775 -0.193891 -0.325120 -0.215172 -0.190917
#
#            10        11        12  ...       147        32        33  \
# PC1 -0.143042 -0.050138 -0.156410  ... -0.164284 -0.168975 -0.168581
# PC2 -0.213777 -0.059902 -0.178302  ... -0.031332  0.078761 -0.034251
#
#            34        35        36        37        38  Week1_AP  Week2_AP
# PC1 -0.149292 -0.172026 -0.204148 -0.203305 -0.158198 -0.209889 -0.247051
# PC2  0.103098  0.099906  0.068682  0.067816  0.103970 -0.298004  0.170534
#
# [2 rows x 35 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4107
# PC2: 0.0857
# Silhouette Score for 4 clusters: 0.384
# Davies-Bouldin Index for 4 clusters: 1.815
# Calinski-Harabasz Index for 4 clusters: 289.723
# Hierarchical Clustering Analysis for 2024
# Running Hierarchical Clustering for 2 clusters in 2024
# PCA Components and their contribution to the Principal Components:
#             1         2        15        18        19        20         5  \
# PC1 -0.126057 -0.132002 -0.043343 -0.180179 -0.164858 -0.179868 -0.167217
# PC2  0.015789  0.044179 -0.002555 -0.014114 -0.055096 -0.019227  0.025302
#
#             7         8         9  ...        31        32        33  \
# PC1 -0.173624 -0.169076 -0.151071  ... -0.150965 -0.147507 -0.146154
# PC2  0.024838  0.005649  0.026239  ...  0.342540  0.361323  0.030495
#
#            34        35        36        37        38  Week1_AP  Week2_AP
# PC1 -0.146864 -0.160903 -0.196863 -0.192392 -0.148045 -0.219148 -0.231868
# PC2  0.334448 -0.044451 -0.059288 -0.053850 -0.053858  0.035440  0.083399
#
# [2 rows x 36 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4640
# PC2: 0.0639
# Silhouette Score for 2 clusters: 0.680
# Davies-Bouldin Index for 2 clusters: 0.229
# Calinski-Harabasz Index for 2 clusters: 619.943
# Running Hierarchical Clustering for 3 clusters in 2024
# PCA Components and their contribution to the Principal Components:
#             1         2        15        18        19        20         5  \
# PC1 -0.126057 -0.132002 -0.043343 -0.180179 -0.164858 -0.179868 -0.167217
# PC2  0.015785  0.044176 -0.002555 -0.014116 -0.055090 -0.019229  0.025301
#
#             7         8         9  ...        31        32        33  \
# PC1 -0.173624 -0.169076 -0.151071  ... -0.150965 -0.147507 -0.146154
# PC2  0.024837  0.005648  0.026241  ...  0.342539  0.361322  0.030517
#
#            34        35        36        37        38  Week1_AP  Week2_AP
# PC1 -0.146864 -0.160903 -0.196863 -0.192392 -0.148045 -0.219148 -0.231868
# PC2  0.334448 -0.044449 -0.059287 -0.053849 -0.053860  0.035440  0.083401
#
# [2 rows x 36 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4640
# PC2: 0.0639
# Silhouette Score for 3 clusters: 0.438
# Davies-Bouldin Index for 3 clusters: 1.615
# Calinski-Harabasz Index for 3 clusters: 429.471
# Running Hierarchical Clustering for 4 clusters in 2024
# PCA Components and their contribution to the Principal Components:
#             1         2        15        18        19        20         5  \
# PC1 -0.126057 -0.132002 -0.043343 -0.180179 -0.164858 -0.179868 -0.167217
# PC2  0.015785  0.044176 -0.002555 -0.014115 -0.055090 -0.019229  0.025299
#
#             7         8         9  ...        31        32        33  \
# PC1 -0.173624 -0.169076 -0.151071  ... -0.150965 -0.147507 -0.146154
# PC2  0.024837  0.005649  0.026243  ...  0.342539  0.361322  0.030519
#
#            34        35        36        37        38  Week1_AP  Week2_AP
# PC1 -0.146864 -0.160903 -0.196863 -0.192392 -0.148045 -0.219148 -0.231868
# PC2  0.334449 -0.044449 -0.059287 -0.053849 -0.053860  0.035440  0.083401
#
# [2 rows x 36 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4640
# PC2: 0.0639
# Silhouette Score for 4 clusters: 0.410
# Davies-Bouldin Index for 4 clusters: 1.575
# Calinski-Harabasz Index for 4 clusters: 343.688

# %% [markdown]
# #### K-Means Clustering Analysis with PCA Reduction

# %%
doc.add_heading('K-Means Clustering Analysis with PCA Reduction', 2)

# %%
for year in dataset_years:

    # Prepare the data for clustering
    if all(feature in datasets[year].columns for feature in clustering_features[year]):
        available_features = [feature for feature in clustering_features[year] if feature in datasets[year].columns]
        df = datasets[year][available_features]
        X = StandardScaler().fit_transform(df)

        # Apply Elbow Method
        print(f"Applying Elbow Method for year {year}")
        plot_elbow_method(X, year)

        # Perform clustering and PCA
        for n_clusters in [2, 3, 4]:
            print(f"Running KMeans for {n_clusters} clusters in {year}")
            perform_kmeans_clustering(datasets[year], available_features, year, n_clusters)
    else:
        print(f"Skipping year {year}: Required columns not found in dataset.")
# Out:
# Applying Elbow Method for year 2016
# Running KMeans for 2 clusters in 2016
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.179904 -0.012209 -0.183065 -0.200765 -0.190110 -0.037618 -0.009857
# PC2 -0.056304 -0.038610 -0.137708 -0.144458 -0.315856 -0.110085 -0.038334
#
#            25        10       11  ...        31        52        28        53  \
# PC1 -0.202083 -0.167513 -0.04302  ... -0.179330 -0.209058 -0.180563 -0.158269
# PC2 -0.114773 -0.048688 -0.02461  ...  0.170776  0.182590  0.006954 -0.021501
#
#            36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.221647 -0.220566 -0.220441 -0.195696 -0.216606 -0.251935
# PC2  0.206376  0.206141  0.206029  0.199738 -0.205030  0.195816
#
# [2 rows x 34 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3869
# PC2: 0.0672
# Silhouette Score for 2 clusters: 0.584
# Davies-Bouldin Index for 2 clusters: 0.576
# Calinski-Harabasz Index for 2 clusters: 501.710
# Running KMeans for 3 clusters in 2016
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.179904 -0.012209 -0.183065 -0.200765 -0.190110 -0.037618 -0.009857
# PC2 -0.056346 -0.038432 -0.137568 -0.144362 -0.315829 -0.110090 -0.038637
#
#            25        10        11  ...       31        52        28        53  \
# PC1 -0.202083 -0.167513 -0.043020  ... -0.17933 -0.209058 -0.180563 -0.158269
# PC2 -0.114867 -0.048925 -0.024559  ...  0.17077  0.182588  0.006890 -0.021567
#
#            36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.221647 -0.220566 -0.220441 -0.195696 -0.216606 -0.251935
# PC2  0.206391  0.206157  0.206043  0.199748 -0.205072  0.195805
#
# [2 rows x 34 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3869
# PC2: 0.0672
# Silhouette Score for 3 clusters: 0.380
# Davies-Bouldin Index for 3 clusters: 1.801
# Calinski-Harabasz Index for 3 clusters: 338.361
# Running KMeans for 4 clusters in 2016
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.179904 -0.012209 -0.183065 -0.200765 -0.190110 -0.037618 -0.009857
# PC2 -0.056425 -0.038582 -0.137883 -0.144613 -0.315848 -0.109900 -0.038482
#
#            25        10        11  ...        31        52        28  \
# PC1 -0.202083 -0.167513 -0.043020  ... -0.179330 -0.209058 -0.180563
# PC2 -0.114839 -0.048632 -0.024529  ...  0.170761  0.182589  0.006986
#
#            53        36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.158269 -0.221647 -0.220566 -0.220441 -0.195696 -0.216606 -0.251935
# PC2 -0.021420  0.206391  0.206158  0.206044  0.199761 -0.204992  0.195831
#
# [2 rows x 34 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3869
# PC2: 0.0672
# Silhouette Score for 4 clusters: 0.397
# Davies-Bouldin Index for 4 clusters: 1.489
# Calinski-Harabasz Index for 4 clusters: 284.002
# Applying Elbow Method for year 2017
# Running KMeans for 2 clusters in 2017
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.207294 -0.020410 -0.180244 -0.218344 -0.204269 -0.042903 -0.010093
# PC2 -0.041658  0.029024  0.169138  0.091236  0.324344  0.143975  0.014268
#
#            25        10        11  ...        31        52        28  \
# PC1 -0.205943 -0.191518 -0.041829  ... -0.173102 -0.201073 -0.202428
# PC2 -0.006488  0.037238  0.026122  ...  0.004138 -0.221457 -0.052987
#
#            53        36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.171730 -0.211033 -0.211033 -0.211870 -0.175000 -0.213840 -0.235148
# PC2 -0.069616 -0.267564 -0.267564 -0.266034 -0.271592  0.167101 -0.141062
#
# [2 rows x 33 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4749
# PC2: 0.0599
# Silhouette Score for 2 clusters: 0.616
# Davies-Bouldin Index for 2 clusters: 0.406
# Calinski-Harabasz Index for 2 clusters: 788.513
# Running KMeans for 3 clusters in 2017
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.207294 -0.020410 -0.180244 -0.218344 -0.204269 -0.042903 -0.010093
# PC2 -0.041630  0.028999  0.169133  0.091194  0.324279  0.144059  0.014239
#
#            25        10        11  ...        31        52        28  \
# PC1 -0.205943 -0.191518 -0.041829  ... -0.173102 -0.201073 -0.202428
# PC2 -0.006451  0.037251  0.026279  ...  0.004120 -0.221445 -0.053088
#
#            53        36        55        56       34  Week1_AP  Week2_AP
# PC1 -0.171730 -0.211033 -0.211033 -0.211870 -0.17500 -0.213840 -0.235148
# PC2 -0.069756 -0.267583 -0.267583 -0.266051 -0.27163  0.167181 -0.141067
#
# [2 rows x 33 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4749
# PC2: 0.0599
# Silhouette Score for 3 clusters: 0.383
# Davies-Bouldin Index for 3 clusters: 1.835
# Calinski-Harabasz Index for 3 clusters: 498.516
# Running KMeans for 4 clusters in 2017
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0.207294 -0.020410 -0.180244 -0.218344 -0.204269 -0.042903 -0.010093
# PC2 -0.041672  0.028994  0.169142  0.091243  0.324375  0.143783  0.014338
#
#            25        10        11  ...        31        52        28  \
# PC1 -0.205943 -0.191518 -0.041829  ... -0.173102 -0.201073 -0.202428
# PC2 -0.006532  0.037145  0.026007  ...  0.004114 -0.221470 -0.052877
#
#            53        36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.171730 -0.211033 -0.211033 -0.211870 -0.175000 -0.213840 -0.235148
# PC2 -0.069471 -0.267573 -0.267573 -0.266044 -0.271614  0.166958 -0.141051
#
# [2 rows x 33 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4749
# PC2: 0.0599
# Silhouette Score for 4 clusters: 0.396
# Davies-Bouldin Index for 4 clusters: 1.475
# Calinski-Harabasz Index for 4 clusters: 402.683
# Applying Elbow Method for year 2018
# Running KMeans for 2 clusters in 2018
# PCA Components and their contribution to the Principal Components:
#             1         3        24        12        20        22         4  \
# PC1 -0
clusters in 2019
# PCA Components and their contribution to the Principal Components:
#             1         3        18        24        20        22         4  \
# PC1 -0.208870 -0.016810 -0.182224 -0.173962 -0.186900 -0.048098 -0.008626
# PC2 -0.071147  0.016841 -0.177011 -0.165745 -0.209935 -0.217880 -0.038833
#
#            25        10        11  ...        31        52        28  \
# PC1 -0.165888 -0.190599 -0.034408  ... -0.182001 -0.195906 -0.206694
# PC2 -0.125339 -0.113865 -0.088531  ... -0.049023  0.118878 -0.004393
#
#            53        36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.203633 -0.229858 -0.231602 -0.231388 -0.198828 -0.221860 -0.261640
# PC2 -0.008704  0.169023  0.164371  0.169285  0.162887 -0.290011  0.146523
#
# [2 rows x 34 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3587
# PC2: 0.0755
# Silhouette Score for 3 clusters: 0.455
# Davies-Bouldin Index for 3 clusters: 1.042
# Calinski-Harabasz Index for 3 clusters: 278.908
# Running KMeans for 4 clusters in 2019
# PCA Components and their contribution to the Principal Components:
#             1        3        18        24        20        22         4  \
# PC1 -0.208870 -0.01681 -0.182224 -0.173962 -0.186900 -0.048098 -0.008626
# PC2 -0.071152  0.01683 -0.177028 -0.165762 -0.209906 -0.217884 -0.038836
#
#            25        10        11  ...        31        52        28  \
# PC1 -0.165888 -0.190599 -0.034408  ... -0.182001 -0.195906 -0.206694
# PC2 -0.125362 -0.113878 -0.088536  ... -0.049021  0.118869 -0.004384
#
#            53        36        55        56        34  Week1_AP  Week2_AP
# PC1 -0.203633 -0.229858 -0.231602 -0.231388 -0.198828 -0.221860 -0.261640
# PC2 -0.008694  0.169025  0.164374  0.169288  0.162884 -0.290015  0.146527
#
# [2 rows x 34 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.3587
# PC2: 0.0755
# Silhouette Score for 4 clusters: 0.336
# Davies-Bouldin Index for 4 clusters: 1.769
# Calinski-Harabasz Index for 4 clusters: 227.773
# Applying Elbow Method for year 2022
# Running KMeans for 2 clusters in 2022
# PCA Components and their contribution to the Principal Components:
#             1        23       133       134       135        19      137  \
# PC1 -0.135136 -0.157496 -0.153971 -0.048253 -0.163300 -0.162031 -0.17023
# PC2 -0.022889  0.098290  0.102453 -0.144661  0.085681  0.105634  0.24389
#
#           138        32       144  ...        33        36        37  \
# PC1 -0.039624 -0.130660 -0.160617  ... -0.130139 -0.166141 -0.163616
# PC2  0.254246  0.217611  0.226353  ...  0.037833  0.065284  0.060190
#
#            34        38        44        42        43  Week1_AP  Week2_AP
# PC1 -0.125711 -0.142792 -0.163888 -0.159183 -0.043680 -0.199382 -0.209734
# PC2 -0.145302 -0.152394 -0.110342 -0.125530 -0.036182  0.176000 -0.126852
#
# [2 rows x 47 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4441
# PC2: 0.0543
# Silhouette Score for 2 clusters: 0.627
# Davies-Bouldin Index for 2 clusters: 0.540
# Calinski-Harabasz Index for 2 clusters: 685.127
# Running KMeans for 3 clusters in 2022
# PCA Components and their contribution to the Principal Components:
#             1        23       133       134       135        19       137  \
# PC1 -0.135136 -0.157496 -0.153971 -0.048253 -0.163300 -0.162031 -0.170230
# PC2 -0.022895  0.098294  0.102457 -0.144663  0.085674  0.105628  0.243889
#
#           138        32       144  ...        33        36        37  \
# PC1 -0.039624 -0.130660 -0.160617  ... -0.130139 -0.166141 -0.163616
# PC2  0.254246  0.217615  0.226352  ...  0.037837  0.065282  0.060188
#
#            34        38        44        42        43  Week1_AP  Week2_AP
# PC1 -0.125711 -0.142792 -0.163888 -0.159183 -0.043680 -0.199382 -0.209734
# PC2 -0.145293 -0.152392 -0.110347 -0.125537 -0.036183  0.176002 -0.126850
#
# [2 rows x 47 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4441
# PC2: 0.0543
# Silhouette Score for 3 clusters: 0.398
# Davies-Bouldin Index for 3 clusters: 1.980
# Calinski-Harabasz Index for 3 clusters: 423.082
# Running KMeans for 4 clusters in 2022
# PCA Components and their contribution to the Principal Components:
#             1        23       133       134       135        19       137  \
# PC1 -0.135136 -0.157496 -0.153971 -0.048253 -0.163300 -0.162031 -0.170230
# PC2 -0.022916  0.098322  0.102490 -0.144656  0.085672  0.105628  0.243888
#
#           138        32       144  ...        33        36        37  \
# PC1 -0.039624 -0.130660 -0.160617  ... -0.130139 -0.166141 -0.163616
# PC2  0.254254  0.217611  0.226358  ...  0.037769  0.065293  0.060199
#
#            34        38        44        42        43  Week1_AP  Week2_AP
# PC1 -0.125711 -0.142792 -0.163888 -0.159183 -0.043680 -0.199382 -0.209734
# PC2 -0.145321 -0.152403 -0.110326 -0.125512 -0.036186  0.175994 -0.126852
#
# [2 rows x 47 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4441
# PC2: 0.0543
# Silhouette Score for 4 clusters: 0.112
# Davies-Bouldin Index for 4 clusters: 2.322
# Calinski-Harabasz Index for 4 clusters: 322.171
# Applying Elbow Method for year 2023
# Running KMeans for 2 clusters in 2023
# PCA Components and their contribution to the Principal Components:
#             1      1_11        18        19        20         7        25  \
# PC1 -0.130358 -0.167696 -0.170605 -0.170890 -0.169797 -0.154473 -0.152902
# PC2 -0.148020 -0.326413 -0.323775 -0.193892 -0.325120 -0.215172 -0.190918
#
#            10        11        12  ...       147        32        33  \
# PC1 -0.143042 -0.050138 -0.156410  ... -0.164284 -0.168975 -0.168581
# PC2 -0.213777 -0.059902 -0.178304  ... -0.031331  0.078761 -0.034251
#
#            34        35        36        37        38  Week1_AP  Week2_AP
# PC1 -0.149292 -0.172026 -0.204148 -0.203305 -0.158198 -0.209889 -0.247051
# PC2  0.103098  0.099906  0.068682  0.067816  0.103970 -0.298004  0.170534
#
# [2 rows x 35 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4107
# PC2: 0.0857
# Silhouette Score for 2 clusters: 0.632
# Davies-Bouldin Index for 2 clusters: 0.676
# Calinski-Harabasz Index for 2 clusters: 520.540
# Running KMeans for 3 clusters in 2023
# PCA Components and their contribution to the Principal Components:
#             1      1_11        18        19        20         7        25  \
# PC1 -0.130358 -0.167696 -0.170605 -0.170890 -0.169797 -0.154473 -0.152902
# PC2 -0.148020 -0.326413 -0.323775 -0.193892 -0.325120 -0.215172 -0.190917
#
#            10        11        12  ...       147        32        33  \
# PC1 -0.143042 -0.050138 -0.156410  ... -0.164284 -0.168975 -0.168581
# PC2 -0.213777 -0.059902 -0.178302  ... -0.031332  0.078761 -0.034251
#
#            34        35        36        37        38  Week1_AP  Week2_AP
# PC1 -0.149292 -0.172026 -0.204148 -0.203305 -0.158198 -0.209889 -0.247051
# PC2  0.103098  0.099906  0.068681  0.067816  0.103971 -0.298004  0.170534
#
# [2 rows x 35 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4107
# PC2: 0.0857
# Silhouette Score for 3 clusters: 0.488
# Davies-Bouldin Index for 3 clusters: 1.007
# Calinski-Harabasz Index for 3 clusters: 359.328
# Running KMeans for 4 clusters in 2023
# PCA Components and their contribution to the Principal Components:
#             1      1_11        18        19        20         7        25  \
# PC1 -0.130358 -0.167696 -0.170605 -0.170890 -0.169797 -0.154473 -0.152902
# PC2 -0.148020 -0.326413 -0.323775 -0.193891 -0.325120 -0.215172 -0.190917
#
#            10        11        12  ...       147        32        33  \
# PC1 -0.143042 -0.050138 -0.156410  ... -0.164284 -0.168975 -0.168581
# PC2 -0.213777 -0.059902 -0.178303  ... -0.031332  0.078761 -0.034251
#
#            34        35        36        37        38  Week1_AP  Week2_AP
# PC1 -0.149292 -0.172026 -0.204148 -0.203305 -0.158198 -0.209889 -0.247051
# PC2  0.103098  0.099906  0.068682  0.067816  0.103970 -0.298004  0.170534
#
# [2 rows x 35 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4107
# PC2: 0.0857
# Silhouette Score for 4 clusters: 0.406
# Davies-Bouldin Index for 4 clusters: 1.153
# Calinski-Harabasz Index for 4 clusters: 300.527
# Applying Elbow Method for year 2024
# Running KMeans for 2 clusters in 2024
# PCA Components and their contribution to the Principal Components:
#             1         2        15        18        19        20         5  \
# PC1 -0.126057 -0.132002 -0.043343 -0.180179 -0.164858 -0.179868 -0.167217
# PC2  0.015785  0.044176 -0.002555 -0.014115 -0.055092 -0.019228  0.025297
#
#             7         8         9  ...        31        32        33  \
# PC1 -0.173624 -0.169076 -0.151071  ... -0.150965 -0.147507 -0.146154
# PC2  0.024837  0.005649  0.026243  ...  0.342539  0.361322  0.030522
#
#            34        35        36        37        38  Week1_AP  Week2_AP
# PC1 -0.146864 -0.160903 -0.196863 -0.192392 -0.148045 -0.219148 -0.231868
# PC2  0.334449 -0.044449 -0.059287 -0.053849 -0.053861  0.035440  0.083401
#
# [2 rows x 36 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4640
# PC2: 0.0639
# Silhouette Score for 2 clusters: 0.673
# Davies-Bouldin Index for 2 clusters: 0.437
# Calinski-Harabasz Index for 2 clusters: 701.798
# Running KMeans for 3 clusters in 2024
# PCA Components and their contribution to the Principal Components:
#             1         2        15        18        19        20         5  \
# PC1 -0.126057 -0.132002 -0.043343 -0.180179 -0.164858 -0.179868 -0.167217
# PC2  0.015785  0.044175 -0.002555 -0.014115 -0.055088 -0.019229  0.025299
#
#             7         8         9  ...        31        32        33  \
# PC1 -0.173624 -0.169076 -0.151071  ... -0.150965 -0.147507 -0.146154
# PC2  0.024836  0.005648  0.026244  ...  0.342538  0.361320  0.030518
#
#            34        35        36        37        38  Week1_AP  Week2_AP
# PC1 -0.146864 -0.160903 -0.196863 -0.192392 -0.148045 -0.219148 -0.231868
# PC2  0.334452 -0.044448 -0.059287 -0.053849 -0.053862  0.035439  0.083401
#
# [2 rows x 36 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4640
# PC2: 0.0639
# Silhouette Score for 3 clusters: 0.429
# Davies-Bouldin Index for 3 clusters: 1.734
# Calinski-Harabasz Index for 3 clusters: 450.043
# Running KMeans for 4 clusters in 2024
# PCA Components and their contribution to the Principal Components:
#             1         2        15        18        19        20         5  \
# PC1 -0.126057 -0.132002 -0.043343 -0.180179 -0.164858 -0.179868 -0.167217
# PC2  0.015785  0.044178 -0.002554 -0.014115 -0.055097 -0.019228  0.025300
#
#             7         8         9  ...        31        32        33  \
# PC1 -0.173624 -0.169076 -0.151071  ... -0.150965 -0.147507 -0.146154
# PC2  0.024838  0.005648  0.026240  ...  0.342540  0.361323  0.030522
#
#            34        35        36        37        38  Week1_AP  Week2_AP
# PC1 -0.146864 -0.160903 -0.196863 -0.192392 -0.148045 -0.219148 -0.231868
# PC2  0.334448 -0.044450 -0.059287 -0.053850 -0.053858  0.035440  0.083401
#
# [2 rows x 36 columns]
#
# Explained variance ratio per Principal Component:
# PC1: 0.4640
# PC2: 0.0639
# Silhouette Score for 4 clusters: 0.406
# Davies-Bouldin Index for 4 clusters: 1.740
# Calinski-Harabasz Index for 4 clusters: 361.619

# %% [markdown]
# #### Clustering analysis of dataset_complete with no missing data

# %%
doc.add_heading('Clustering analysis of dataset_complete with no missing data', 3)

clustering_features_complete = [
    col for col in dataset_complete.columns
    if col not in all_lists[str(2024)]['created_columns']['TotalColumns']
    and col not in ['Week3_AP', 'Week4_AP', 'Week5_AP']
    and col not in all_lists[str(2024)]['created_columns']['WeeklyPP']
    and col not in all_lists[str(2024)]['created_columns']['OtherColumns']
    and col not in all_lists[str(2024)]['basic_lists']['listPPointsColumns']
    and col not in all_lists[str(2024)]['basic_lists']['listBonColumns']
    and col not in all_lists[str(2024)]['basic_lists']['listSPAColumns']
    and col not in all_lists[str(2024)]['basic_lists']['listGrades']
    and col not in all_lists[str(2024)]['weekly_and_participation_lists']['listWeek3']
    and col not in all_lists[str(2024)]['weekly_and_participation_lists']['listWeek4']
    and dataset_complete[col].dtype in [np.float64, np.int64]  # Ensure the column is numeric
]

# Prepare the data for clustering
if all(feature in dataset_complete.columns for feature in clustering_features_complete):
    available_features = [feature for feature in clustering_features_complete if feature in dataset_complete.columns]
    df = dataset_complete[available_features]
    X = StandardScaler().fit_transform(df)

    # Apply Elbow Method
    print(f"Applying Elbow Method for dataset_complete with no Missing Data")
    plot_elbow_method(X, 'dataset_complete')

    # Perform clustering and PCA
    for n_clusters in [2, 3, 4, 5, 6]:
        print(f"Running KMeans for {n_clusters} clusters for dataset_complete")
        perform_kmeans_clustering(dataset_complete, available_features, 'dataset_complete', n_clusters)

        print(f"Running Hierarchical Clustering for {n_clusters} clusters for dataset_complete")
        perform_hierarchical_clustering(dataset_complete, available_features, 'dataset_complete', n_clusters)
else:
    print(f"Skipping dataset_complete: Required columns not found in dataset.")
# Out:
# Applying Elbow Method for dataset_complete with no Missing Data
# Running KMeans for 2 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.264925 -0.302193 -0.265575 -0.265504 -0.062973 -0.274174 -0.270257
# PC2 -0.056915 -0.050052 -0.033205  0.024873 -0.194736  0.403442 -0.364503
#
#            42        35        50       30        31        36        34
# PC1 -0.302874 -0.293176 -0.231694 -0.24948 -0.280804 -0.314861 -0.271478
# PC2 -0.327767 -0.267319 -0.200442  0.48831  0.420329 -0.068753  0.141654
#
# Explained variance ratio per Principal Component:
# PC1: 0.4343
# PC2: 0.0923
# Silhouette Score for 2 clusters: 0.622
# Davies-Bouldin Index for 2 clusters: 0.529
# Calinski-Harabasz Index for 2 clusters: 3936.276
# Running Hierarchical Clustering for 2 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.264925 -0.302193 -0.265575 -0.265504 -0.062973 -0.274174 -0.270257
# PC2 -0.056897 -0.050084 -0.033190  0.024827 -0.194742  0.403520 -0.364694
#
#            42        35        50        30        31        36        34
# PC1 -0.302874 -0.293176 -0.231694 -0.249480 -0.280804 -0.314861 -0.271478
# PC2 -0.327783 -0.267065 -0.200429  0.488191  0.420355 -0.068815  0.141704
#
# Explained variance ratio per Principal Component:
# PC1: 0.4343
# PC2: 0.0922
# Silhouette Score for 2 clusters: 0.633
# Davies-Bouldin Index for 2 clusters: 0.326
# Calinski-Harabasz Index for 2 clusters: 3675.204
# Running KMeans for 3 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.264925 -0.302194 -0.265575 -0.265504 -0.062973 -0.274174 -0.270257
# PC2 -0.057168 -0.049689 -0.033128  0.024821 -0.194682  0.403192 -0.364231
#
#            42        35        50        30        31        36        34
# PC1 -0.302874 -0.293176 -0.231694 -0.249480 -0.280804 -0.314860 -0.271478
# PC2 -0.327700 -0.267650 -0.200571  0.488367  0.420400 -0.069013  0.142008
#
# Explained variance ratio per Principal Component:
# PC1: 0.4343
# PC2: 0.0922
# Silhouette Score for 3 clusters: 0.353
# Davies-Bouldin Index for 3 clusters: 1.810
# Calinski-Harabasz Index for 3 clusters: 2661.198
# Running Hierarchical Clustering for 3 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.264925 -0.302193 -0.265575 -0.265504 -0.062973 -0.274174 -0.270257
# PC2 -0.056704 -0.050098 -0.033116  0.024826 -0.194732  0.402727 -0.364748
#
#            42        35        50        30        31        36        34
# PC1 -0.302874 -0.293176 -0.231694 -0.249480 -0.280804 -0.314861 -0.271478
# PC2 -0.327487 -0.267285 -0.200501  0.488056  0.421255 -0.069066  0.141765
#
# Explained variance ratio per Principal Component:
# PC1: 0.4343
# PC2: 0.0922
# Silhouette Score for 3 clusters: 0.432
# Davies-Bouldin Index for 3 clusters: 1.227
# Calinski-Harabasz Index for 3 clusters: 2480.823
# Running KMeans for 4 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.264925 -0.302193 -0.265575 -0.265504 -0.062973 -0.274174 -0.270257
# PC2 -0.057521 -0.049016 -0.033953  0.025147 -0.194464  0.403965 -0.364950
#
#            42        35        50        30        31        36        34
# PC1 -0.302874 -0.293176 -0.231694 -0.249481 -0.280804 -0.314861 -0.271478
# PC2 -0.326440 -0.267741 -0.200563  0.489200  0.418538 -0.070014  0.142984
#
# Explained variance ratio per Principal Component:
# PC1: 0.4343
# PC2: 0.0922
# Silhouette Score for 4 clusters: 0.194
# Davies-Bouldin Index for 4 clusters: 1.704
# Calinski-Harabasz Index for 4 clusters: 2261.190
# Running Hierarchical Clustering for 4 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.264925 -0.302193 -0.265575 -0.265504 -0.062973 -0.274174 -0.270257
# PC2 -0.056878 -0.050131 -0.033143  0.024810 -0.194792  0.403339 -0.364765
#
#            42        35        50        30        31        36        34
# PC1 -0.302873 -0.293176 -0.231694 -0.249480 -0.280804 -0.314861 -0.271478
# PC2 -0.327607 -0.267286 -0.200419  0.488009  0.420678 -0.068696  0.141703
#
# Explained variance ratio per Principal Component:
# PC1: 0.4343
# PC2: 0.0922
# Silhouette Score for 4 clusters: 0.360
# Davies-Bouldin Index for 4 clusters: 2.030
# Calinski-Harabasz Index for 4 clusters: 2036.395
# Running KMeans for 5 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.264925 -0.302193 -0.265575 -0.265504 -0.062973 -0.274174 -0.270257
# PC2 -0.056991 -0.050691 -0.032965  0.025123 -0.194818  0.404364 -0.364652
#
#            42        35        50       30        31        36        34
# PC1 -0.302873 -0.293176 -0.231694 -0.24948 -0.280803 -0.314861 -0.271478
# PC2 -0.328264 -0.266752 -0.200340  0.48799  0.419623 -0.068431  0.141702
#
# Explained variance ratio per Principal Component:
# PC1: 0.4343
# PC2: 0.0922
# Silhouette Score for 5 clusters: 0.212
# Davies-Bouldin Index for 5 clusters: 1.523
# Calinski-Harabasz Index for 5 clusters: 2109.967
# Running Hierarchical Clustering for 5 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.264925 -0.302193 -0.265575 -0.265504 -0.062973 -0.274174 -0.270257
# PC2 -0.057040 -0.049971 -0.033218  0.024667 -0.194729  0.403463 -0.365067
#
#            42        35        50        30        31        36        34
# PC1 -0.302874 -0.293176 -0.231694 -0.249480 -0.280804 -0.314861 -0.271478
# PC2 -0.327551 -0.266964 -0.200472  0.488188  0.420457 -0.068456  0.141475
#
# Explained variance ratio per Principal Component:
# PC1: 0.4343
# PC2: 0.0922
# Silhouette Score for 5 clusters: 0.161
# Davies-Bouldin Index for 5 clusters: 2.015
# Calinski-Harabasz Index for 5 clusters: 1820.012
# Running KMeans for 6 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.264925 -0.302193 -0.265575 -0.265504 -0.062973 -0.274175 -0.270257
# PC2 -0.056912 -0.050054 -0.033221  0.024880 -0.194738  0.403504 -0.364467
#
#            42        35        50        30        31        36        34
# PC1 -0.302873 -0.293176 -0.231694 -0.249480 -0.280803 -0.314861 -0.271478
# PC2 -0.327768 -0.267368 -0.200456  0.488338  0.420251 -0.068694  0.141616
#
# Explained variance ratio per Principal Component:
# PC1: 0.4343
# PC2: 0.0923
# Silhouette Score for 6 clusters: 0.226
# Davies-Bouldin Index for 6 clusters: 1.456
# Calinski-Harabasz Index for 6 clusters: 1945.911
# Running Hierarchical Clustering for 6 clusters for dataset_complete
# PCA Components and their contribution to the Principal Components:
#             1        12        20        10        11        32        38  \
# PC1 -0.264925 -0.302193 -0.265575 -0.265504 -0.062973 -0.274174 -0.270257
# PC2 -0.056936 -0.050024 -0.033247  0.024840 -0.194764  0.403750 -0.364531
#
#            42        35        50        30        31        36        34
# PC1 -0.302874 -0.293176 -0.231694 -0.249480 -0.280804 -0.314861 -0.271478
# PC2 -0.327519 -0.267473 -0.200498  0.488259  0.420126 -0.068761  0.141644
#
# Explained variance ratio per Principal Component:
# PC1: 0.4343
# PC2: 0.0922
# Silhouette Score for 6 clusters: 0.174
# Davies-Bouldin Index for 6 clusters: 1.855
# Calinski-Harabasz Index for 6 clusters: 1670.109

# %% [markdown]
# # Save Files

# %%
directory_to_zip = 'Charts'
output_zip_file = 'Charts_clustering.zip'

# Create the zip file
shutil.make_archive(output_zip_file.replace('.zip', ''), 'zip', directory_to_zip)

# Download the zip file
files.download(output_zip_file)

# Save the document at the end
save_document('clustering_output.docx')
# Out:
# Document saved as clustering_output.docx

# %%
directory_to_zip = 'output'
output_zip_file = 'output_feature_selection_clustering.zip'

# Create the zip file
shutil.make_archive(output_zip_file.replace('.zip', ''), 'zip', directory_to_zip)

# Download the zip file
files.download(output_zip_file)
